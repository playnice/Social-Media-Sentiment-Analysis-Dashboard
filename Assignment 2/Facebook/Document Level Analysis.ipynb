# %%
import pandas as pd
import numpy

# %%
df = pd.read_json('muayfit_sentiment.json', orient='record')
df = df[df['Sentiment'] != 0]

# %%
df2 = pd.read_json('chi_fitness_sentiment.json', orient='record')
df3 = pd.read_json('fitness_first_sentiment.json', orient='record')

# %%
final_df = pd.concat([df,df2,df3], ignore_index=True)
negative = len(final_df[final_df['Sentiment'] < 0])
positive = len(final_df[final_df['Sentiment'] > 0])

# %%
print(negative)
print(positive)
# Out:
# 118
# 238

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Negative', 'Positive'
sizes = numpy.array([negative, positive])

def absolute_value(val):
    a  = numpy.round(val/100.*sizes.sum(), 0)
    return a

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, colors=['red','lightblue'], startangle=90, autopct=absolute_value)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
fig1.savefig('document_level.png')
plt.close()

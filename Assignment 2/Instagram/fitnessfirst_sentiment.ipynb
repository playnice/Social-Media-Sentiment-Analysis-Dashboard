# %%
import re
import json
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag
import string
import pandas as pd
import mtranslate

# %%
RE_EMOJI = re.compile('[^\U00000000-\U0000d7ff\U0000e000-\U0000ffff]', flags=re.UNICODE)

def strip_emoji(text):
    return RE_EMOJI.sub(r'', text)

# %%
def penn_to_wn(tag):
    """
    Convert between the PennTreebank tags to simple Wordnet tags
    """
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB
    return None

# %%
df = pd.DataFrame(columns=['Post', 'Comment', 'Topic', 'Sentiment', 'Source'])
lemmatizer = WordNetLemmatizer()

#For some reason, please returns positive sentiment because it assumes 'pleasing' but normally people just asking politely
weird_sentiment_words = ['la', 'please', 'lah']

file = json.load(open('instagram_fitnessfirst6months.json', encoding="utf8"))
for line in file['data']:
    try:
        print("New comment")
        print('---------------------------------------')
        sentence = line['comment']

        #Translate to English
        sentence = mtranslate.translate(sentence, 'en', 'auto')

        #Split a single comment into multiple sentences
        sentences = sent_tokenize(sentence)
        #print(sentences)

        #Sentiment for each sentence
        for s in sentences:

            s = s.lower()
            s = s.replace('fitnessfirstmalaysia', ' ')
            s = s.replace('fitness first', ' ')
            s = s.replace('fitness_first', ' ')
            s = s.replace('fitness-first', ' ')
            s = re.sub(r"\byin\b", "", s)
            s = re.sub(r"\byang\b", "", s)

            print("Sentence: ", s)
            sentiment = 0.0
            #print(s)

            tokenized = word_tokenize(s)
            #print(tokenized)

            new_tokenized = [x for x in tokenized if x not in weird_sentiment_words]
            tokenized = new_tokenized

            #POS tag each word
            tagged = pos_tag(tokenized)
            print(tagged)

            previous_word = ""
            list_of_nouns = []

            #Get the sentiment for each word
            for w, t in tagged:


                sentiment_added = False

                #Convert Penn Treebank POS tag to Wordnet POS tag
                wn_tag = penn_to_wn(t)

                #If successfully converted, lemmatize using the Wordnet POS tag
                #If not successfully converted, lemmatize without any POS tags
                if wn_tag is None:
                    lemma = lemmatizer.lemmatize(w)
                else:
                    lemma = lemmatizer.lemmatize(w, pos=wn_tag)

                #If can't lemmatize, set the word to be passed into SentiWordnet as the initial word, w
                #If can lemmatize, set the word to be passed into Sentiwordnet as the lemmatized word, lemma
                if not lemma:
                    print("Can't lemmatize: ", w)
                    final_word = w
                else:
                    print("Lemmatized word: ", lemma)
                    final_word = lemma

                #Make cool and wow positive words
                if (final_word in ['cool', 'wow', 'glad']) and (previous_word == 'not'):
                    print('Not is the previous word')
                    sentiment = sentiment - 0.5
                    previous_word = final_word
                    sentiment_added = True
                elif (final_word in ['cool', 'wow', 'glad', 'lose', 'lost']):
                    print(final_word, " has a score of 0.5")
                    sentiment = sentiment + 0.5
                    previous_word = final_word
                    sentiment_added = True
                elif (final_word == 'nice') and (previous_word == 'not'):
                    print('Not is the previous word')
                    sentiment = sentiment - 0.875
                    previous_word = final_word
                    sentiment_added = True
                elif (final_word == 'nice'):
                    print(final_word, " has a score of 0.875")
                    sentiment = sentiment + 0.875
                    previous_word = final_word
                    sentiment_added = True
                elif (final_word == 'job') and (previous_word == 'great'):    
                    print(final_word, " has a score of 0.875")
                    sentiment = sentiment + 0.875
                    previous_word = final_word
                    sentiment_added = True
                elif (final_word in ['terminate', 'stop', 'halt', 'cancel']) and (previous_word == 'not'):
                    sentiment = sentiment + 0.75
                    print("The word terminate, stop or halt is detected and the sentiment is +0.75")
                    previous_word = final_word
                    sentiment_added = True
                elif (final_word in ['terminate', 'stop', 'halt', 'cancel']):
                    sentiment = sentiment - 0.75
                    print("The word terminate, stop or halt is detected and the sentiment is -0.75")
                    previous_word = final_word
                    sentiment_added = True

                #If the Wordnet POS tag exists, use it to get the synset of the word
                if wn_tag is None:
                    synsets = wn.synsets(final_word)
                else:
                    synsets = wn.synsets(final_word, pos=wn_tag)

                #If no synsets found, skip the word
                if not synsets:
                    print("Synset not found")
                    continue

                # Take the first sense of the word which is the most common
                synset = synsets[0]
                swn_synset = swn.senti_synset(synset.name())

                if sentiment_added == False:
                    if final_word != 'fitness' and previous_word == 'not':      
                        print(final_word, " | ", synset, " | ", swn_synset, " | ", synset.definition())
                        sentiment = sentiment - swn_synset.pos_score() - swn_synset.neg_score()
                    elif final_word != 'fitness':
                        print(final_word, " | ", synset, " | ", swn_synset, " | ", synset.definition())
                        sentiment = sentiment + swn_synset.pos_score() - swn_synset.neg_score()
                    else:
                        print("The word fitness is not considered as a sentiment")

                previous_word = final_word

                #Extract nouns
                if t.startswith('N') or w == 'post':
                    if w != 'i' and w != 'la' and w != 'hi':
                        list_of_nouns.append(w)

            try:
                df2 = pd.DataFrame([[line['post'], s, ','.join(list_of_nouns), sentiment, 'Instagram Comment Fitness First']],columns=['Post', 'Comment', 'Topic', 'Sentiment', 'Source'])
            except Exception:
                df2 = pd.DataFrame([['No message', s, ','.join(list_of_nouns), sentiment, 'Instagram Comment Fitness First']],columns=['Post', 'Comment', 'Topic', 'Sentiment', 'Source'])

            df = pd.concat([df2,df], ignore_index=True)

            # sum greater than 0 => positive sentiment
            if sentiment >= 0:
                print("This sentence has a positive sentiment: " + str(sentiment))
            elif sentiment < 0:
                print("This sentence has a negative sentiment: " + str(sentiment))
        print()
    except:
        continue
# Out:
# New comment
# ---------------------------------------
# Sentence:  hi @  why rpm class take off from ff ioi club?
# [('hi', 'NN'), ('@', 'NNP'), ('why', 'WRB'), ('rpm', 'JJ'), ('class', 'NN'), ('take', 'VB'), ('off', 'RP'), ('from', 'IN'), ('ff', 'NN'), ('ioi', 'NN'), ('club', 'NN'), ('?', '.')]
# Lemmatized word:  hi
# hi  |  Synset('hello.n.01')  |  <hello.n.01: PosScore=0.0 NegScore=0.0>  |  an expression of greeting
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  why
# why  |  Synset('why.n.01')  |  <why.n.01: PosScore=0.0 NegScore=0.0>  |  the cause or intention underlying an action or situation, especially in the phrase `the whys and wherefores'
# Lemmatized word:  rpm
# Synset not found
# Lemmatized word:  class
# class  |  Synset('class.n.01')  |  <class.n.01: PosScore=0.0 NegScore=0.0>  |  a collection of things sharing a common attribute
# Lemmatized word:  take
# take  |  Synset('take.v.01')  |  <take.v.01: PosScore=0.0 NegScore=0.0>  |  carry out
# Lemmatized word:  off
# off  |  Synset('away.r.01')  |  <away.r.01: PosScore=0.0 NegScore=0.0>  |  from a particular thing or place or position (`forth' is obsolete)
# Lemmatized word:  from
# Synset not found
# Lemmatized word:  ff
# Synset not found
# Lemmatized word:  ioi
# Synset not found
# Lemmatized word:  club
# club  |  Synset('baseball_club.n.01')  |  <baseball_club.n.01: PosScore=0.0 NegScore=0.0>  |  a team of professional baseball players who play and travel together
# Lemmatized word:  ?
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  :)
# [(':', ':'), (')', ')')]
# Lemmatized word:  :
# Synset not found
# Lemmatized word:  )
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  how about ak?
# [('how', 'WRB'), ('about', 'IN'), ('ak', 'NN'), ('?', '.')]
# Lemmatized word:  how
# Synset not found
# Lemmatized word:  about
# about  |  Synset('about.s.01')  |  <about.s.01: PosScore=0.0 NegScore=0.0>  |  on the move
# Lemmatized word:  ak
# ak  |  Synset('alaska.n.01')  |  <alaska.n.01: PosScore=0.0 NegScore=0.0>  |  a state in northwestern North America; the 49th state admitted to the union
# Lemmatized word:  ?
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  nice!
# [('nice', 'JJ'), ('!', '.')]
# Lemmatized word:  nice
# nice  has a score of 0.875
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.875
# Sentence:  can't wait to try this programme
# [('ca', 'MD'), ("n't", 'RB'), ('wait', 'VB'), ('to', 'TO'), ('try', 'VB'), ('this', 'DT'), ('programme', 'NN')]
# Lemmatized word:  ca
# ca  |  Synset('calcium.n.01')  |  <calcium.n.01: PosScore=0.0 NegScore=0.0>  |  a white metallic element that burns with a brilliant light; the fifth most abundant element in the earth's crust; an important component of most plants and animals
# Lemmatized word:  n't
# Synset not found
# Lemmatized word:  wait
# wait  |  Synset('wait.v.01')  |  <wait.v.01: PosScore=0.0 NegScore=0.0>  |  stay in one place and anticipate or expect something
# Lemmatized word:  to
# Synset not found
# Lemmatized word:  try
# try  |  Synset('try.v.01')  |  <try.v.01: PosScore=0.0 NegScore=0.0>  |  make an effort or attempt
# Lemmatized word:  this
# Synset not found
# Lemmatized word:  programme
# programme  |  Synset('program.n.05')  |  <program.n.05: PosScore=0.0 NegScore=0.0>  |  an announcement of the events that will occur as part of a theatrical or sporting event
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  what a sweet picture💚
# [('what', 'WP'), ('a', 'DT'), ('sweet', 'JJ'), ('picture💚', 'NN')]
# Lemmatized word:  what
# Synset not found
# Lemmatized word:  a
# a  |  Synset('angstrom.n.01')  |  <angstrom.n.01: PosScore=0.0 NegScore=0.0>  |  a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# Lemmatized word:  sweet
# sweet  |  Synset('sweet.a.01')  |  <sweet.a.01: PosScore=0.0 NegScore=0.0>  |  having or denoting the characteristic taste of sugar
# Lemmatized word:  picture💚
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  very cool stuff :) continue with interesting content :)
# [('very', 'RB'), ('cool', 'JJ'), ('stuff', 'NN'), (':', ':'), (')', ')'), ('continue', 'VBP'), ('with', 'IN'), ('interesting', 'JJ'), ('content', 'NN'), (':', ':'), (')', ')')]
# Lemmatized word:  very
# very  |  Synset('very.r.01')  |  <very.r.01: PosScore=0.25 NegScore=0.25>  |  used as intensifiers; `real' is sometimes used informally for `really'; `rattling' is informal
# Lemmatized word:  cool
# cool  has a score of 0.5
# Lemmatized word:  stuff
# stuff  |  Synset('material.n.01')  |  <material.n.01: PosScore=0.0 NegScore=0.0>  |  the tangible substance that goes into the makeup of a physical object
# Lemmatized word:  :
# Synset not found
# Lemmatized word:  )
# Synset not found
# Lemmatized word:  continue
# continue  |  Synset('continue.v.01')  |  <continue.v.01: PosScore=0.0 NegScore=0.0>  |  continue a certain state, condition, or activity
# Lemmatized word:  with
# Synset not found
# Lemmatized word:  interesting
# interesting  |  Synset('interesting.a.01')  |  <interesting.a.01: PosScore=0.375 NegScore=0.0>  |  arousing or holding the attention
# Lemmatized word:  content
# content  |  Synset('content.n.01')  |  <content.n.01: PosScore=0.0 NegScore=0.0>  |  everything that is included in a collection and that is held or included in something
# Lemmatized word:  :
# Synset not found
# Lemmatized word:  )
# Synset not found
# This sentence has a positive sentiment: 0.875
#
# New comment
# ---------------------------------------
# Sentence:  💪💪💪💪💪
# [('💪💪💪💪💪', 'NN')]
# Lemmatized word:  💪💪💪💪💪
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  😊
# [('😊', 'NN')]
# Lemmatized word:  😊
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @adah_hasan
# [('@', 'NN'), ('adah_hasan', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  adah_hasan
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @missundra 😌
# [('@', 'JJ'), ('missundra', 'NN'), ('😌', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  missundra
# Synset not found
# Lemmatized word:  😌
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @ fdz_1
# [('@', 'NN'), ('fdz_1', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  fdz_1
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @jaden_ee 😍😍
# [('@', 'JJ'), ('jaden_ee', 'NN'), ('😍😍', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  jaden_ee
# Synset not found
# Lemmatized word:  😍😍
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  this is sh’bam😂lol.....
# [('this', 'DT'), ('is', 'VBZ'), ('sh', 'JJ'), ('’', 'JJ'), ('bam😂lol', 'NN'), ('...', ':'), ('..', 'NN')]
# Lemmatized word:  this
# Synset not found
# Lemmatized word:  be
# be  |  Synset('be.v.01')  |  <be.v.01: PosScore=0.25 NegScore=0.125>  |  have the quality of being; (copula, used with an adjective or a predicate noun)
# Lemmatized word:  sh
# Synset not found
# Lemmatized word:  ’
# Synset not found
# Lemmatized word:  bam😂lol
# Synset not found
# Lemmatized word:  ...
# Synset not found
# Lemmatized word:  ..
# Synset not found
# This sentence has a positive sentiment: 0.125
#
# New comment
# ---------------------------------------
# Sentence:  @wazlina_wati
# [('@', 'NN'), ('wazlina_wati', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  wazlina_wati
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @damnputracy i introduce to u my favorite dance instructor 😁😂😂😂
# [('@', 'JJ'), ('damnputracy', 'NN'), ('i', 'NN'), ('introduce', 'VBP'), ('to', 'TO'), ('u', 'VB'), ('my', 'PRP$'), ('favorite', 'JJ'), ('dance', 'NN'), ('instructor', 'NN'), ('😁😂😂😂', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  damnputracy
# Synset not found
# Lemmatized word:  i
# i  |  Synset('iodine.n.01')  |  <iodine.n.01: PosScore=0.0 NegScore=0.0>  |  a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks)
# Lemmatized word:  introduce
# introduce  |  Synset('introduce.v.01')  |  <introduce.v.01: PosScore=0.0 NegScore=0.0>  |  cause to come to know personally
# Lemmatized word:  to
# Synset not found
# Lemmatized word:  u
# Synset not found
# Lemmatized word:  my
# Synset not found
# Lemmatized word:  favorite
# favorite  |  Synset('favorite.s.01')  |  <favorite.s.01: PosScore=0.125 NegScore=0.0>  |  appealing to the general public
# Lemmatized word:  dance
# dance  |  Synset('dance.n.01')  |  <dance.n.01: PosScore=0.0 NegScore=0.0>  |  an artistic form of nonverbal communication
# Lemmatized word:  instructor
# instructor  |  Synset('teacher.n.01')  |  <teacher.n.01: PosScore=0.0 NegScore=0.0>  |  a person whose occupation is teaching
# Lemmatized word:  😁😂😂😂
# Synset not found
# This sentence has a positive sentiment: 0.125
#
# New comment
# ---------------------------------------
# Sentence:  woohoo @jaden_ee 😘
# [('woohoo', 'NN'), ('@', 'NNP'), ('jaden_ee', 'NN'), ('😘', 'NN')]
# Lemmatized word:  woohoo
# Synset not found
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  jaden_ee
# Synset not found
# Lemmatized word:  😘
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  today close or open?
# [('today', 'NN'), ('close', 'RB'), ('or', 'CC'), ('open', 'VB'), ('?', '.')]
# Lemmatized word:  today
# today  |  Synset('today.n.01')  |  <today.n.01: PosScore=0.125 NegScore=0.0>  |  the present time or age
# Lemmatized word:  close
# close  |  Synset('near.r.01')  |  <near.r.01: PosScore=0.0 NegScore=0.0>  |  near in time or place or relationship
# Lemmatized word:  or
# or  |  Synset('oregon.n.01')  |  <oregon.n.01: PosScore=0.0 NegScore=0.0>  |  a state in northwestern United States on the Pacific
# Lemmatized word:  open
# open  |  Synset('open.v.01')  |  <open.v.01: PosScore=0.0 NegScore=0.0>  |  cause to open or to become open
# Lemmatized word:  ?
# Synset not found
# This sentence has a positive sentiment: 0.125
#
# New comment
# ---------------------------------------
# Sentence:  love it!
# [('love', 'VB'), ('it', 'PRP'), ('!', '.')]
# Lemmatized word:  love
# love  |  Synset('love.v.01')  |  <love.v.01: PosScore=0.5 NegScore=0.0>  |  have a great affection or liking for
# Lemmatized word:  it
# it  |  Synset('information_technology.n.01')  |  <information_technology.n.01: PosScore=0.0 NegScore=0.0>  |  the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.5
#
# New comment
# ---------------------------------------
# Sentence:  nice
# [('nice', 'JJ')]
# Lemmatized word:  nice
# nice  has a score of 0.875
# This sentence has a positive sentiment: 0.875
#
# New comment
# ---------------------------------------
# Sentence:  aww!
# [('aww', 'NN'), ('!', '.')]
# Lemmatized word:  aww
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @ noeyedear88 😸
# [('@', 'JJ'), ('noeyedear88', 'NN'), ('😸', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  noeyedear88
# Synset not found
# Lemmatized word:  😸
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  nice
# [('nice', 'JJ')]
# Lemmatized word:  nice
# nice  has a score of 0.875
# This sentence has a positive sentiment: 0.875
#
# New comment
# ---------------------------------------
# Sentence:  hi  , are you iphone user?ada problem contact us okay ;)
# [('hi', 'NN'), (',', ','), ('are', 'VBP'), ('you', 'PRP'), ('iphone', 'VBP'), ('user', 'RB'), ('?', '.'), ('ada', 'NN'), ('problem', 'NN'), ('contact', 'NN'), ('us', 'PRP'), ('okay', 'VBP'), (';', ':'), (')', ')')]
# Lemmatized word:  hi
# hi  |  Synset('hello.n.01')  |  <hello.n.01: PosScore=0.0 NegScore=0.0>  |  an expression of greeting
# Lemmatized word:  ,
# Synset not found
# Lemmatized word:  be
# be  |  Synset('be.v.01')  |  <be.v.01: PosScore=0.25 NegScore=0.125>  |  have the quality of being; (copula, used with an adjective or a predicate noun)
# Lemmatized word:  you
# Synset not found
# Lemmatized word:  iphone
# Synset not found
# Lemmatized word:  user
# Synset not found
# Lemmatized word:  ?
# Synset not found
# Lemmatized word:  ada
# ada  |  Synset('adenosine_deaminase.n.01')  |  <adenosine_deaminase.n.01: PosScore=0.0 NegScore=0.0>  |  an enzyme found in mammals that can catalyze the deamination of adenosine into inosine and ammonia
# Lemmatized word:  problem
# problem  |  Synset('problem.n.01')  |  <problem.n.01: PosScore=0.0 NegScore=0.625>  |  a state of difficulty that needs to be resolved
# Lemmatized word:  contact
# contact  |  Synset('contact.n.01')  |  <contact.n.01: PosScore=0.375 NegScore=0.0>  |  close interaction
# Lemmatized word:  u
# u  |  Synset('uracil.n.01')  |  <uracil.n.01: PosScore=0.0 NegScore=0.0>  |  a base containing nitrogen that is found in RNA (but not in DNA) and derived from pyrimidine; pairs with adenine
# Lemmatized word:  okay
# okay  |  Synset('approve.v.01')  |  <approve.v.01: PosScore=0.0 NegScore=0.0>  |  give sanction to
# Lemmatized word:  ;
# Synset not found
# Lemmatized word:  )
# Synset not found
# This sentence has a negative sentiment: -0.125
#
# New comment
# ---------------------------------------
# Sentence:  @dana_campari
# [('@', 'NN'), ('dana_campari', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  dana_campari
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  how to participate?
# [('how', 'WRB'), ('to', 'TO'), ('participate', 'VB'), ('?', '.')]
# Lemmatized word:  how
# Synset not found
# Lemmatized word:  to
# Synset not found
# Lemmatized word:  participate
# participate  |  Synset('participate.v.01')  |  <participate.v.01: PosScore=0.0 NegScore=0.0>  |  share in something
# Lemmatized word:  ?
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @ sam.ngg fuhhhyooo
# [('@', 'JJ'), ('sam.ngg', 'NN'), ('fuhhhyooo', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  sam.ngg
# Synset not found
# Lemmatized word:  fuhhhyooo
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  a big shoutout to everyone at @  and @celebrityfitness!
# [('a', 'DT'), ('big', 'JJ'), ('shoutout', 'NN'), ('to', 'TO'), ('everyone', 'NN'), ('at', 'IN'), ('@', 'NNP'), ('and', 'CC'), ('@', 'NNP'), ('celebrityfitness', 'NN'), ('!', '.')]
# Lemmatized word:  a
# a  |  Synset('angstrom.n.01')  |  <angstrom.n.01: PosScore=0.0 NegScore=0.0>  |  a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# Lemmatized word:  big
# big  |  Synset('large.a.01')  |  <large.a.01: PosScore=0.25 NegScore=0.125>  |  above average in size or number or quantity or magnitude or extent
# Lemmatized word:  shoutout
# Synset not found
# Lemmatized word:  to
# Synset not found
# Lemmatized word:  everyone
# Synset not found
# Lemmatized word:  at
# at  |  Synset('astatine.n.01')  |  <astatine.n.01: PosScore=0.0 NegScore=0.0>  |  a highly unstable radioactive element (the heaviest of the halogen series); a decay product of uranium and thorium
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  and
# Synset not found
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  celebrityfitness
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.125
# Sentence:  the event was smooth going.
# [('the', 'DT'), ('event', 'NN'), ('was', 'VBD'), ('smooth', 'JJ'), ('going', 'VBG'), ('.', '.')]
# Lemmatized word:  the
# Synset not found
# Lemmatized word:  event
# event  |  Synset('event.n.01')  |  <event.n.01: PosScore=0.0 NegScore=0.0>  |  something that happens at a given place and time
# Lemmatized word:  be
# be  |  Synset('be.v.01')  |  <be.v.01: PosScore=0.25 NegScore=0.125>  |  have the quality of being; (copula, used with an adjective or a predicate noun)
# Lemmatized word:  smooth
# smooth  |  Synset('smooth.a.01')  |  <smooth.a.01: PosScore=0.25 NegScore=0.0>  |  having a surface free from roughness or bumps or ridges or irregularities
# Lemmatized word:  go
# go  |  Synset('travel.v.01')  |  <travel.v.01: PosScore=0.0 NegScore=0.0>  |  change location; move, travel, or proceed, also metaphorically
# Lemmatized word:  .
# Synset not found
# This sentence has a positive sentiment: 0.375
# Sentence:  the instructors were very helpful demonstrating what to do.
# [('the', 'DT'), ('instructors', 'NNS'), ('were', 'VBD'), ('very', 'RB'), ('helpful', 'JJ'), ('demonstrating', 'VBG'), ('what', 'WP'), ('to', 'TO'), ('do', 'VB'), ('.', '.')]
# Lemmatized word:  the
# Synset not found
# Lemmatized word:  instructor
# instructor  |  Synset('teacher.n.01')  |  <teacher.n.01: PosScore=0.0 NegScore=0.0>  |  a person whose occupation is teaching
# Lemmatized word:  be
# be  |  Synset('be.v.01')  |  <be.v.01: PosScore=0.25 NegScore=0.125>  |  have the quality of being; (copula, used with an adjective or a predicate noun)
# Lemmatized word:  very
# very  |  Synset('very.r.01')  |  <very.r.01: PosScore=0.25 NegScore=0.25>  |  used as intensifiers; `real' is sometimes used informally for `really'; `rattling' is informal
# Lemmatized word:  helpful
# helpful  |  Synset('helpful.a.01')  |  <helpful.a.01: PosScore=0.25 NegScore=0.0>  |  providing assistance or serving a useful function
# Lemmatized word:  demonstrate
# demonstrate  |  Synset('show.v.01')  |  <show.v.01: PosScore=0.0 NegScore=0.0>  |  give an exhibition of to an interested audience
# Lemmatized word:  what
# Synset not found
# Lemmatized word:  to
# Synset not found
# Lemmatized word:  do
# do  |  Synset('make.v.01')  |  <make.v.01: PosScore=0.0 NegScore=0.0>  |  engage in
# Lemmatized word:  .
# Synset not found
# This sentence has a positive sentiment: 0.375
# Sentence:  thank you for pushing us!
# [('thank', 'NN'), ('you', 'PRP'), ('for', 'IN'), ('pushing', 'VBG'), ('us', 'PRP'), ('!', '.')]
# Lemmatized word:  thank
# Synset not found
# Lemmatized word:  you
# Synset not found
# Lemmatized word:  for
# Synset not found
# Lemmatized word:  push
# push  |  Synset('push.v.01')  |  <push.v.01: PosScore=0.0 NegScore=0.0>  |  move with force, "He pushed the table into a corner"
# Lemmatized word:  u
# u  |  Synset('uracil.n.01')  |  <uracil.n.01: PosScore=0.0 NegScore=0.0>  |  a base containing nitrogen that is found in RNA (but not in DNA) and derived from pyrimidine; pairs with adenine
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  it's my first obstacle course and it's a blast!
# [('it', 'PRP'), ("'s", 'VBZ'), ('my', 'PRP$'), ('first', 'JJ'), ('obstacle', 'NN'), ('course', 'NN'), ('and', 'CC'), ('it', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('blast', 'NN'), ('!', '.')]
# Lemmatized word:  it
# it  |  Synset('information_technology.n.01')  |  <information_technology.n.01: PosScore=0.0 NegScore=0.0>  |  the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# Lemmatized word:  's
# Synset not found
# Lemmatized word:  my
# Synset not found
# Lemmatized word:  first
# first  |  Synset('first.a.01')  |  <first.a.01: PosScore=0.0 NegScore=0.0>  |  preceding all others in time or space or degree
# Lemmatized word:  obstacle
# obstacle  |  Synset('obstacle.n.01')  |  <obstacle.n.01: PosScore=0.0 NegScore=0.0>  |  something immaterial that stands in the way and must be circumvented or surmounted
# Lemmatized word:  course
# course  |  Synset('course.n.01')  |  <course.n.01: PosScore=0.0 NegScore=0.0>  |  education imparted in a series of lessons or meetings
# Lemmatized word:  and
# Synset not found
# Lemmatized word:  it
# it  |  Synset('information_technology.n.01')  |  <information_technology.n.01: PosScore=0.0 NegScore=0.0>  |  the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# Lemmatized word:  's
# Synset not found
# Lemmatized word:  a
# a  |  Synset('angstrom.n.01')  |  <angstrom.n.01: PosScore=0.0 NegScore=0.0>  |  a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# Lemmatized word:  blast
# blast  |  Synset('blast.n.01')  |  <blast.n.01: PosScore=0.0 NegScore=0.125>  |  a very long fly ball
# Lemmatized word:  !
# Synset not found
# This sentence has a negative sentiment: -0.125
# Sentence:  thank you!
# [('thank', 'NN'), ('you', 'PRP'), ('!', '.')]
# Lemmatized word:  thank
# Synset not found
# Lemmatized word:  you
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  💪 💪 💪
# [('💪', 'JJ'), ('💪', 'NNP'), ('💪', 'NN')]
# Lemmatized word:  💪
# Synset not found
# Lemmatized word:  💪
# Synset not found
# Lemmatized word:  💪
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  hi,
# [('hi', 'NN'), (',', ',')]
# Lemmatized word:  hi
# hi  |  Synset('hello.n.01')  |  <hello.n.01: PosScore=0.0 NegScore=0.0>  |  an expression of greeting
# Lemmatized word:  ,
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  natashaseah118hi, i got urgent enquiry need inform!!!!!!!!!!!!!!!!
# [('natashaseah118hi', 'NN'), (',', ','), ('i', 'NN'), ('got', 'VBD'), ('urgent', 'JJ'), ('enquiry', 'NNS'), ('need', 'VBP'), ('inform', 'NN'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.')]
# Lemmatized word:  natashaseah118hi
# Synset not found
# Lemmatized word:  ,
# Synset not found
# Lemmatized word:  i
# i  |  Synset('iodine.n.01')  |  <iodine.n.01: PosScore=0.0 NegScore=0.0>  |  a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks)
# Lemmatized word:  get
# get  |  Synset('get.v.01')  |  <get.v.01: PosScore=0.125 NegScore=0.0>  |  come into the possession of something concrete or abstract
# Lemmatized word:  urgent
# urgent  |  Synset('pressing.s.01')  |  <pressing.s.01: PosScore=0.0 NegScore=0.0>  |  compelling immediate action
# Lemmatized word:  enquiry
# enquiry  |  Synset('question.n.01')  |  <question.n.01: PosScore=0.125 NegScore=0.25>  |  an instance of questioning
# Lemmatized word:  need
# need  |  Synset('necessitate.v.01')  |  <necessitate.v.01: PosScore=0.25 NegScore=0.25>  |  require as useful, just, or proper
# Lemmatized word:  inform
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  thank provide professional service to me, at the sametime other people don't fuckty find case to me too!!!!!!!!!!!!
# [('thank', 'NN'), ('provide', 'VBP'), ('professional', 'JJ'), ('service', 'NN'), ('to', 'TO'), ('me', 'PRP'), (',', ','), ('at', 'IN'), ('the', 'DT'), ('sametime', 'NN'), ('other', 'JJ'), ('people', 'NNS'), ('do', 'VBP'), ("n't", 'RB'), ('fuckty', 'VB'), ('find', 'VB'), ('case', 'NN'), ('to', 'TO'), ('me', 'PRP'), ('too', 'RB'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.')]
# Lemmatized word:  thank
# Synset not found
# Lemmatized word:  provide
# provide  |  Synset('supply.v.01')  |  <supply.v.01: PosScore=0.0 NegScore=0.0>  |  give something useful or necessary to
# Lemmatized word:  professional
# professional  |  Synset('professional.a.01')  |  <professional.a.01: PosScore=0.0 NegScore=0.0>  |  engaged in a profession or engaging in as a profession or means of livelihood
# Lemmatized word:  service
# service  |  Synset('service.n.01')  |  <service.n.01: PosScore=0.0 NegScore=0.0>  |  work done by one person or group that benefits another
# Lemmatized word:  to
# Synset not found
# Lemmatized word:  me
# me  |  Synset('maine.n.01')  |  <maine.n.01: PosScore=0.0 NegScore=0.0>  |  a state in New England
# Lemmatized word:  ,
# Synset not found
# Lemmatized word:  at
# at  |  Synset('astatine.n.01')  |  <astatine.n.01: PosScore=0.0 NegScore=0.0>  |  a highly unstable radioactive element (the heaviest of the halogen series); a decay product of uranium and thorium
# Lemmatized word:  the
# Synset not found
# Lemmatized word:  sametime
# Synset not found
# Lemmatized word:  other
# other  |  Synset('other.a.01')  |  <other.a.01: PosScore=0.0 NegScore=0.625>  |  not the same one or ones already mentioned or implied
# Lemmatized word:  people
# people  |  Synset('people.n.01')  |  <people.n.01: PosScore=0.0 NegScore=0.0>  |  (plural) any group of human beings (men or women or children) collectively
# Lemmatized word:  do
# do  |  Synset('make.v.01')  |  <make.v.01: PosScore=0.0 NegScore=0.0>  |  engage in
# Lemmatized word:  n't
# Synset not found
# Lemmatized word:  fuckty
# Synset not found
# Lemmatized word:  find
# find  |  Synset('find.v.01')  |  <find.v.01: PosScore=0.0 NegScore=0.0>  |  come upon, as if by accident; meet with
# Lemmatized word:  case
# case  |  Synset('case.n.01')  |  <case.n.01: PosScore=0.0 NegScore=0.0>  |  an occurrence of something
# Lemmatized word:  to
# Synset not found
# Lemmatized word:  me
# me  |  Synset('maine.n.01')  |  <maine.n.01: PosScore=0.0 NegScore=0.0>  |  a state in New England
# Lemmatized word:  too
# too  |  Synset('excessively.r.01')  |  <excessively.r.01: PosScore=0.125 NegScore=0.25>  |  to a degree exceeding normal or proper limits
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a negative sentiment: -0.75
# Sentence:  moreover not matter is i also recognize people!!!!!!!!!!!!
# [('moreover', 'RB'), ('not', 'RB'), ('matter', 'NN'), ('is', 'VBZ'), ('i', 'RB'), ('also', 'RB'), ('recognize', 'VBP'), ('people', 'NNS'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.')]
# Lemmatized word:  moreover
# moreover  |  Synset('furthermore.r.01')  |  <furthermore.r.01: PosScore=0.0 NegScore=0.0>  |  in addition; furthermore, their quality is improving"; moreover, mice nested there"
# Lemmatized word:  not
# not  |  Synset('not.r.01')  |  <not.r.01: PosScore=0.0 NegScore=0.625>  |  negation of a word or group of words
# Lemmatized word:  matter
# matter  |  Synset('matter.n.01')  |  <matter.n.01: PosScore=0.125 NegScore=0.25>  |  a vaguely specified concern
# Lemmatized word:  be
# be  |  Synset('be.v.01')  |  <be.v.01: PosScore=0.25 NegScore=0.125>  |  have the quality of being; (copula, used with an adjective or a predicate noun)
# Lemmatized word:  i
# Synset not found
# Lemmatized word:  also
# also  |  Synset('besides.r.02')  |  <besides.r.02: PosScore=0.0 NegScore=0.0>  |  in addition
# Lemmatized word:  recognize
# recognize  |  Synset('acknowledge.v.06')  |  <acknowledge.v.06: PosScore=0.0 NegScore=0.0>  |  accept (someone) to be what is claimed or accept his power and authority
# Lemmatized word:  people
# people  |  Synset('people.n.01')  |  <people.n.01: PosScore=0.0 NegScore=0.0>  |  (plural) any group of human beings (men or women or children) collectively
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a negative sentiment: -0.875
# Sentence:  !
# [('!', '.')]
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @yingshukhoo
# [('@', 'NN'), ('yingshukhoo', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  yingshukhoo
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  sounds like fun - free for all?
# [('sounds', 'NNS'), ('like', 'IN'), ('fun', 'NN'), ('-', ':'), ('free', 'JJ'), ('for', 'IN'), ('all', 'DT'), ('?', '.')]
# Lemmatized word:  sound
# sound  |  Synset('sound.n.01')  |  <sound.n.01: PosScore=0.0 NegScore=0.0>  |  the particular auditory effect produced by a given cause
# Lemmatized word:  like
# like  |  Synset('like.n.01')  |  <like.n.01: PosScore=0.125 NegScore=0.0>  |  a similar kind
# Lemmatized word:  fun
# fun  |  Synset('fun.n.01')  |  <fun.n.01: PosScore=0.375 NegScore=0.0>  |  activities that are enjoyable or amusing
# Lemmatized word:  -
# Synset not found
# Lemmatized word:  free
# free  |  Synset('free.a.01')  |  <free.a.01: PosScore=0.375 NegScore=0.0>  |  able to act at will; not hampered; not under compulsion or restraint
# Lemmatized word:  for
# Synset not found
# Lemmatized word:  all
# all  |  Synset('all.a.01')  |  <all.a.01: PosScore=0.0 NegScore=0.0>  |  quantifier; used with either mass or count nouns to indicate the whole number or amount of or every one of a class
# Lemmatized word:  ?
# Synset not found
# This sentence has a positive sentiment: 0.875
# Sentence:  how do we enroll for this @reebokmalaysia event ?
# [('how', 'WRB'), ('do', 'VBP'), ('we', 'PRP'), ('enroll', 'VB'), ('for', 'IN'), ('this', 'DT'), ('@', 'JJ'), ('reebokmalaysia', 'NN'), ('event', 'NN'), ('?', '.')]
# Lemmatized word:  how
# Synset not found
# Lemmatized word:  do
# do  |  Synset('make.v.01')  |  <make.v.01: PosScore=0.0 NegScore=0.0>  |  engage in
# Lemmatized word:  we
# Synset not found
# Lemmatized word:  enroll
# enroll  |  Synset('enroll.v.01')  |  <enroll.v.01: PosScore=0.0 NegScore=0.0>  |  register formally as a participant or member
# Lemmatized word:  for
# Synset not found
# Lemmatized word:  this
# Synset not found
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  reebokmalaysia
# Synset not found
# Lemmatized word:  event
# event  |  Synset('event.n.01')  |  <event.n.01: PosScore=0.0 NegScore=0.0>  |  something that happens at a given place and time
# Lemmatized word:  ?
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @dailymuscle http://www.heyjom.com/events/details/422/fit-in-the-city
# [('@', 'JJ'), ('dailymuscle', 'NN'), ('http', 'NN'), (':', ':'), ('//www.heyjom.com/events/details/422/fit-in-the-city', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  dailymuscle
# Synset not found
# Lemmatized word:  http
# http  |  Synset('hypertext_transfer_protocol.n.01')  |  <hypertext_transfer_protocol.n.01: PosScore=0.0 NegScore=0.0>  |  a protocol (utilizing TCP) to transfer hypertext requests and information between servers and browsers
# Lemmatized word:  :
# Synset not found
# Lemmatized word:  //www.heyjom.com/events/details/422/fit-in-the-city
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  kurusss @ealdwine_z
# [('kurusss', 'NN'), ('@', 'CD'), ('ealdwine_z', 'NN')]
# Lemmatized word:  kurus
# kurus  |  Synset('kurus.n.01')  |  <kurus.n.01: PosScore=0.0 NegScore=0.0>  |  100 kurus equal 1 lira in Turkey
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  ealdwine_z
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @lized_zed loll....
# [('@', 'NNS'), ('lized_zed', 'VBD'), ('loll', 'NN'), ('...', ':'), ('.', '.')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  lized_zed
# Synset not found
# Lemmatized word:  loll
# Synset not found
# Lemmatized word:  ...
# Synset not found
# Lemmatized word:  .
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  wow very awesome😍😍😍
# [('wow', 'JJ'), ('very', 'RB'), ('awesome😍😍😍', 'RB')]
# Lemmatized word:  wow
# wow  has a score of 0.5
# Synset not found
# Lemmatized word:  very
# very  |  Synset('very.r.01')  |  <very.r.01: PosScore=0.25 NegScore=0.25>  |  used as intensifiers; `real' is sometimes used informally for `really'; `rattling' is informal
# Lemmatized word:  awesome😍😍😍
# Synset not found
# This sentence has a positive sentiment: 0.5
#
# New comment
# ---------------------------------------
# Sentence:  omg i miss this!
# [('omg', 'NN'), ('i', 'NN'), ('miss', 'VBP'), ('this', 'DT'), ('!', '.')]
# Lemmatized word:  omg
# Synset not found
# Lemmatized word:  i
# i  |  Synset('iodine.n.01')  |  <iodine.n.01: PosScore=0.0 NegScore=0.0>  |  a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks)
# Lemmatized word:  miss
# miss  |  Synset('miss.v.01')  |  <miss.v.01: PosScore=0.0 NegScore=0.25>  |  fail to perceive or to catch with the senses or the mind
# Lemmatized word:  this
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a negative sentiment: -0.25
# Sentence:  !
# [('!', '.')]
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  i’ll be in malaysia 🇲🇾 in a few weeks
# [('i', 'NN'), ('’', 'VBP'), ('ll', 'NN'), ('be', 'VB'), ('in', 'IN'), ('malaysia', 'NN'), ('🇲🇾', 'NN'), ('in', 'IN'), ('a', 'DT'), ('few', 'JJ'), ('weeks', 'NNS')]
# Lemmatized word:  i
# i  |  Synset('iodine.n.01')  |  <iodine.n.01: PosScore=0.0 NegScore=0.0>  |  a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks)
# Lemmatized word:  ’
# Synset not found
# Lemmatized word:  ll
# Synset not found
# Lemmatized word:  be
# be  |  Synset('be.v.01')  |  <be.v.01: PosScore=0.25 NegScore=0.125>  |  have the quality of being; (copula, used with an adjective or a predicate noun)
# Lemmatized word:  in
# in  |  Synset('inch.n.01')  |  <inch.n.01: PosScore=0.0 NegScore=0.0>  |  a unit of length equal to one twelfth of a foot
# Lemmatized word:  malaysia
# malaysia  |  Synset('malaysia.n.01')  |  <malaysia.n.01: PosScore=0.0 NegScore=0.0>  |  a constitutional monarchy in southeastern Asia on Borneo and the Malay Peninsula; achieved independence from the United Kingdom in 1957
# Lemmatized word:  🇲🇾
# Synset not found
# Lemmatized word:  in
# in  |  Synset('inch.n.01')  |  <inch.n.01: PosScore=0.0 NegScore=0.0>  |  a unit of length equal to one twelfth of a foot
# Lemmatized word:  a
# a  |  Synset('angstrom.n.01')  |  <angstrom.n.01: PosScore=0.0 NegScore=0.0>  |  a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# Lemmatized word:  few
# few  |  Synset('few.a.01')  |  <few.a.01: PosScore=0.0 NegScore=0.0>  |  a quantifier that can be used with count nouns and is often preceded by `a'; a small but indefinite number
# Lemmatized word:  week
# week  |  Synset('week.n.01')  |  <week.n.01: PosScore=0.0 NegScore=0.0>  |  any period of seven consecutive days
# This sentence has a positive sentiment: 0.125
#
# New comment
# ---------------------------------------
# Sentence:  😍 promo whatshap quick ready body height for the first 10 people.
# [('😍', 'JJ'), ('promo', 'NN'), ('whatshap', 'NN'), ('quick', 'JJ'), ('ready', 'JJ'), ('body', 'NN'), ('height', 'NN'), ('for', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('10', 'CD'), ('people', 'NNS'), ('.', '.')]
# Lemmatized word:  😍
# Synset not found
# Lemmatized word:  promo
# Synset not found
# Lemmatized word:  whatshap
# Synset not found
# Lemmatized word:  quick
# quick  |  Synset('quick.s.01')  |  <quick.s.01: PosScore=0.0 NegScore=0.0>  |  accomplished rapidly and without delay
# Lemmatized word:  ready
# ready  |  Synset('ready.a.01')  |  <ready.a.01: PosScore=0.0 NegScore=0.0>  |  completely prepared or in condition for immediate action or use or progress
# Lemmatized word:  body
# body  |  Synset('body.n.01')  |  <body.n.01: PosScore=0.0 NegScore=0.0>  |  the entire structure of an organism (an animal, plant, or human being)
# Lemmatized word:  height
# height  |  Synset('height.n.01')  |  <height.n.01: PosScore=0.0 NegScore=0.0>  |  the vertical dimension of extension; distance from the base of something to the top
# Lemmatized word:  for
# Synset not found
# Lemmatized word:  the
# Synset not found
# Lemmatized word:  first
# first  |  Synset('first.a.01')  |  <first.a.01: PosScore=0.0 NegScore=0.0>  |  preceding all others in time or space or degree
# Lemmatized word:  10
# 10  |  Synset('ten.n.01')  |  <ten.n.01: PosScore=0.0 NegScore=0.0>  |  the cardinal number that is the sum of nine and one; the base of the decimal system
# Lemmatized word:  people
# people  |  Synset('people.n.01')  |  <people.n.01: PosScore=0.0 NegScore=0.0>  |  (plural) any group of human beings (men or women or children) collectively
# Lemmatized word:  .
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  💊💊
# [('💊💊', 'NN')]
# Lemmatized word:  💊💊
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  tshirt never ada jual ke?
# [('tshirt', 'NN'), ('never', 'RB'), ('ada', 'VBP'), ('jual', 'JJ'), ('ke', 'NN'), ('?', '.')]
# Lemmatized word:  tshirt
# Synset not found
# Lemmatized word:  never
# never  |  Synset('never.r.01')  |  <never.r.01: PosScore=0.0 NegScore=0.625>  |  not ever; at no time in the past or future
# Lemmatized word:  ada
# Synset not found
# Lemmatized word:  jual
# Synset not found
# Lemmatized word:  ke
# Synset not found
# Lemmatized word:  ?
# Synset not found
# This sentence has a negative sentiment: -0.625
#
# New comment
# ---------------------------------------
# Sentence:  hi key !
# [('hi', 'NN'), ('key', 'NN'), ('!', '.')]
# Lemmatized word:  hi
# hi  |  Synset('hello.n.01')  |  <hello.n.01: PosScore=0.0 NegScore=0.0>  |  an expression of greeting
# Lemmatized word:  key
# key  |  Synset('key.n.01')  |  <key.n.01: PosScore=0.0 NegScore=0.0>  |  metal device shaped in such a way that when it is inserted into the appropriate lock the lock's mechanism can be rotated
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  we are so proud of you 💜
# [('we', 'PRP'), ('are', 'VBP'), ('so', 'RB'), ('proud', 'JJ'), ('of', 'IN'), ('you', 'PRP'), ('💜', 'VBP')]
# Lemmatized word:  we
# Synset not found
# Lemmatized word:  be
# be  |  Synset('be.v.01')  |  <be.v.01: PosScore=0.25 NegScore=0.125>  |  have the quality of being; (copula, used with an adjective or a predicate noun)
# Lemmatized word:  so
# so  |  Synset('so.r.01')  |  <so.r.01: PosScore=0.0 NegScore=0.0>  |  to a very great extent or degree
# Lemmatized word:  proud
# proud  |  Synset('proud.a.01')  |  <proud.a.01: PosScore=0.375 NegScore=0.25>  |  feeling self-respect or pleasure in something by which you measure your self-worth; or being a reason for pride
# Lemmatized word:  of
# Synset not found
# Lemmatized word:  you
# Synset not found
# Lemmatized word:  💜
# Synset not found
# This sentence has a positive sentiment: 0.25
#
# New comment
# ---------------------------------------
# Sentence:  @jaden_ee
# [('@', 'NN'), ('jaden_ee', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  jaden_ee
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  hi cutiepie, jaden!
# [('hi', 'NN'), ('cutiepie', 'NN'), (',', ','), ('jaden', 'NN'), ('!', '.')]
# Lemmatized word:  hi
# hi  |  Synset('hello.n.01')  |  <hello.n.01: PosScore=0.0 NegScore=0.0>  |  an expression of greeting
# Lemmatized word:  cutiepie
# Synset not found
# Lemmatized word:  ,
# Synset not found
# Lemmatized word:  jaden
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @ysteoh
# [('@', 'NN'), ('ysteoh', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  ysteoh
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  yasss 😍👍
# [('yasss', 'NN'), ('😍👍', 'NN')]
# Lemmatized word:  yasss
# Synset not found
# Lemmatized word:  😍👍
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  wooww!!
# [('wooww', 'NN'), ('!', '.'), ('!', '.')]
# Lemmatized word:  wooww
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  it's like skin care advertising @kenmuns 😁
# [('it', 'PRP'), ("'s", 'VBZ'), ('like', 'IN'), ('skin', 'FW'), ('care', 'NN'), ('advertising', 'VBG'), ('@', 'NNP'), ('kenmuns', 'NNS'), ('😁', 'VBP')]
# Lemmatized word:  it
# it  |  Synset('information_technology.n.01')  |  <information_technology.n.01: PosScore=0.0 NegScore=0.0>  |  the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# Lemmatized word:  's
# Synset not found
# Lemmatized word:  like
# like  |  Synset('like.n.01')  |  <like.n.01: PosScore=0.125 NegScore=0.0>  |  a similar kind
# Lemmatized word:  skin
# skin  |  Synset('skin.n.01')  |  <skin.n.01: PosScore=0.0 NegScore=0.0>  |  a natural protective body covering and site of the sense of touch
# Lemmatized word:  care
# care  |  Synset('care.n.01')  |  <care.n.01: PosScore=0.0 NegScore=0.0>  |  the work of providing treatment for or attending to someone or something
# Lemmatized word:  advertise
# advertise  |  Synset('advertise.v.01')  |  <advertise.v.01: PosScore=0.0 NegScore=0.0>  |  call attention to
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  kenmuns
# Synset not found
# Lemmatized word:  😁
# Synset not found
# This sentence has a positive sentiment: 0.125
#
# New comment
# ---------------------------------------
# Sentence:  @fettyzurando haha not sk ii, it’s skm!
# [('@', 'JJ'), ('fettyzurando', 'NN'), ('haha', 'NN'), ('not', 'RB'), ('sk', 'JJ'), ('ii', 'NN'), (',', ','), ('it', 'PRP'), ('’', 'VBZ'), ('s', 'JJ'), ('skm', 'NN'), ('!', '.')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  fettyzurando
# Synset not found
# Lemmatized word:  haha
# Synset not found
# Lemmatized word:  not
# not  |  Synset('not.r.01')  |  <not.r.01: PosScore=0.0 NegScore=0.625>  |  negation of a word or group of words
# Lemmatized word:  sk
# Synset not found
# Lemmatized word:  ii
# ii  |  Synset('two.n.01')  |  <two.n.01: PosScore=0.0 NegScore=0.0>  |  the cardinal number that is the sum of one and one or a numeral representing this number
# Lemmatized word:  ,
# Synset not found
# Lemmatized word:  it
# it  |  Synset('information_technology.n.01')  |  <information_technology.n.01: PosScore=0.0 NegScore=0.0>  |  the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# Lemmatized word:  ’
# Synset not found
# Lemmatized word:  s
# Synset not found
# Lemmatized word:  skm
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a negative sentiment: -0.625
#
# New comment
# ---------------------------------------
# Sentence:  @nalayee
# [('@', 'NNS'), ('nalayee', 'NNS')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  nalayee
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  hey @ng_jason
# [('hey', 'NN'), ('@', 'CD'), ('ng_jason', 'NN')]
# Lemmatized word:  hey
# Synset not found
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  ng_jason
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  👏
# [('👏', 'NN')]
# Lemmatized word:  👏
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  can't wait!
# [('ca', 'MD'), ("n't", 'RB'), ('wait', 'VB'), ('!', '.')]
# Lemmatized word:  ca
# ca  |  Synset('calcium.n.01')  |  <calcium.n.01: PosScore=0.0 NegScore=0.0>  |  a white metallic element that burns with a brilliant light; the fifth most abundant element in the earth's crust; an important component of most plants and animals
# Lemmatized word:  n't
# Synset not found
# Lemmatized word:  wait
# wait  |  Synset('wait.v.01')  |  <wait.v.01: PosScore=0.0 NegScore=0.0>  |  stay in one place and anticipate or expect something
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  hi hi @coach.liez
# [('hi', 'NN'), ('hi', 'NN'), ('@', 'NNP'), ('coach.liez', 'NN')]
# Lemmatized word:  hi
# hi  |  Synset('hello.n.01')  |  <hello.n.01: PosScore=0.0 NegScore=0.0>  |  an expression of greeting
# Lemmatized word:  hi
# hi  |  Synset('hello.n.01')  |  <hello.n.01: PosScore=0.0 NegScore=0.0>  |  an expression of greeting
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  coach.liez
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @missnudra bestnyer
# [('@', 'JJ'), ('missnudra', 'NN'), ('bestnyer', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  missnudra
# Synset not found
# Lemmatized word:  bestnyer
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  loving your insta gallery :) i like your profile.
# [('loving', 'VBG'), ('your', 'PRP$'), ('insta', 'JJ'), ('gallery', 'NN'), (':', ':'), (')', ')'), ('i', 'VBP'), ('like', 'IN'), ('your', 'PRP$'), ('profile', 'NN'), ('.', '.')]
# Lemmatized word:  love
# love  |  Synset('love.v.01')  |  <love.v.01: PosScore=0.5 NegScore=0.0>  |  have a great affection or liking for
# Lemmatized word:  your
# Synset not found
# Lemmatized word:  insta
# Synset not found
# Lemmatized word:  gallery
# gallery  |  Synset('gallery.n.01')  |  <gallery.n.01: PosScore=0.0 NegScore=0.0>  |  spectators at a golf or tennis match
# Lemmatized word:  :
# Synset not found
# Lemmatized word:  )
# Synset not found
# Lemmatized word:  i
# Synset not found
# Lemmatized word:  like
# like  |  Synset('like.n.01')  |  <like.n.01: PosScore=0.125 NegScore=0.0>  |  a similar kind
# Lemmatized word:  your
# Synset not found
# Lemmatized word:  profile
# profile  |  Synset('profile.n.01')  |  <profile.n.01: PosScore=0.0 NegScore=0.0>  |  an analysis (often in graphical form) representing the extent to which something exhibits various characteristics
# Lemmatized word:  .
# Synset not found
# This sentence has a positive sentiment: 0.625
# Sentence:  you're doing great job.
# ...
# Lemmatized word:  bag
# bag  |  Synset('bag.v.01')  |  <bag.v.01: PosScore=0.125 NegScore=0.0>  |  capture or kill, as in hunting
# Lemmatized word:  hahahahaha
# Synset not found
# This sentence has a positive sentiment: 0.25
#
# New comment
# ---------------------------------------
# Sentence:  👍👋
# [('👍👋', 'NN')]
# Lemmatized word:  👍👋
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  👍👋
# [('👍👋', 'NN')]
# Lemmatized word:  👍👋
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  hiii you 💥 you could’ve certainly manager our line :) msg knowledge on this prime ig!!
# [('hiii', 'NN'), ('you', 'PRP'), ('💥', 'VBP'), ('you', 'PRP'), ('could', 'MD'), ('’', 'VB'), ('ve', 'FW'), ('certainly', 'RB'), ('manager', 'NN'), ('our', 'PRP$'), ('line', 'NN'), (':', ':'), (')', ')'), ('msg', 'VBP'), ('knowledge', 'NN'), ('on', 'IN'), ('this', 'DT'), ('prime', 'JJ'), ('ig', 'NN'), ('!', '.'), ('!', '.')]
# Lemmatized word:  hiii
# Synset not found
# Lemmatized word:  you
# Synset not found
# Lemmatized word:  💥
# Synset not found
# Lemmatized word:  you
# Synset not found
# Lemmatized word:  could
# Synset not found
# Lemmatized word:  ’
# Synset not found
# Lemmatized word:  ve
# Synset not found
# Lemmatized word:  certainly
# certainly  |  Synset('surely.r.01')  |  <surely.r.01: PosScore=0.25 NegScore=0.0>  |  definitely or positively (`sure' is sometimes used informally for `surely')
# Lemmatized word:  manager
# manager  |  Synset('director.n.01')  |  <director.n.01: PosScore=0.0 NegScore=0.0>  |  someone who controls resources and expenditures
# Lemmatized word:  our
# Synset not found
# Lemmatized word:  line
# line  |  Synset('line.n.01')  |  <line.n.01: PosScore=0.0 NegScore=0.0>  |  a formation of people or things one beside another
# Lemmatized word:  :
# Synset not found
# Lemmatized word:  )
# Synset not found
# Lemmatized word:  msg
# Synset not found
# Lemmatized word:  knowledge
# knowledge  |  Synset('cognition.n.01')  |  <cognition.n.01: PosScore=0.0 NegScore=0.0>  |  the psychological result of perception and learning and reasoning
# Lemmatized word:  on
# on  |  Synset('on.a.01')  |  <on.a.01: PosScore=0.0 NegScore=0.0>  |  in operation or operational
# Lemmatized word:  this
# Synset not found
# Lemmatized word:  prime
# prime  |  Synset('premier.s.01')  |  <premier.s.01: PosScore=0.25 NegScore=0.25>  |  first in rank or degree
# Lemmatized word:  ig
# ig  |  Synset('immunoglobulin.n.01')  |  <immunoglobulin.n.01: PosScore=0.0 NegScore=0.0>  |  a class of proteins produced in lymph tissue in vertebrates and that function as antibodies in the immune response
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.25
# Sentence:  act those instantly
# [('act', 'NN'), ('those', 'DT'), ('instantly', 'RB')]
# Lemmatized word:  act
# act  |  Synset('act.n.01')  |  <act.n.01: PosScore=0.0 NegScore=0.0>  |  a legal document codifying the result of deliberations of a committee or society or legislative body
# Lemmatized word:  those
# Synset not found
# Lemmatized word:  instantly
# instantly  |  Synset('immediately.r.01')  |  <immediately.r.01: PosScore=0.0 NegScore=0.375>  |  without delay or hesitation; with no time intervening
# This sentence has a negative sentiment: -0.375
#
# New comment
# ---------------------------------------
# Sentence:  @nczeerick16 & @ddianahttira lets join together as a teammate
# [('@', 'NNP'), ('nczeerick16', 'NN'), ('&', 'CC'), ('@', 'NNP'), ('ddianahttira', 'VBZ'), ('lets', 'NNS'), ('join', 'VB'), ('together', 'RB'), ('as', 'IN'), ('a', 'DT'), ('teammate', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  nczeerick16
# Synset not found
# Lemmatized word:  &
# Synset not found
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  ddianahttira
# Synset not found
# Lemmatized word:  let
# let  |  Synset('lashkar-e-taiba.n.01')  |  <lashkar-e-taiba.n.01: PosScore=0.0 NegScore=0.0>  |  a brutal terrorist group active in Kashmir; fights against India with the goal of restoring Islamic rule of India
# Lemmatized word:  join
# join  |  Synset('join.v.01')  |  <join.v.01: PosScore=0.0 NegScore=0.0>  |  become part of; become a member of a group or organization
# Lemmatized word:  together
# together  |  Synset('together.r.01')  |  <together.r.01: PosScore=0.0 NegScore=0.0>  |  in contact with each other or in proximity
# Lemmatized word:  a
# a  |  Synset('angstrom.n.01')  |  <angstrom.n.01: PosScore=0.0 NegScore=0.0>  |  a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# Lemmatized word:  a
# a  |  Synset('angstrom.n.01')  |  <angstrom.n.01: PosScore=0.0 NegScore=0.0>  |  a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# Lemmatized word:  teammate
# teammate  |  Synset('teammate.n.01')  |  <teammate.n.01: PosScore=0.0 NegScore=0.0>  |  a fellow member of a team
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @zue2020 ok sure why not.. when this zue
# [('@', 'JJ'), ('zue2020', 'NN'), ('ok', 'JJ'), ('sure', 'JJ'), ('why', 'WRB'), ('not..', 'RB'), ('when', 'WRB'), ('this', 'DT'), ('zue', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  zue2020
# Synset not found
# Lemmatized word:  ok
# ok  |  Synset('all_right.s.01')  |  <all_right.s.01: PosScore=0.375 NegScore=0.0>  |  being satisfactory or in satisfactory condition
# Lemmatized word:  sure
# sure  |  Synset('certain.a.02')  |  <certain.a.02: PosScore=0.25 NegScore=0.5>  |  having or feeling no doubt or uncertainty; confident and assured
# Lemmatized word:  why
# why  |  Synset('why.n.01')  |  <why.n.01: PosScore=0.0 NegScore=0.0>  |  the cause or intention underlying an action or situation, especially in the phrase `the whys and wherefores'
# Lemmatized word:  not..
# Synset not found
# Lemmatized word:  when
# Synset not found
# Lemmatized word:  this
# Synset not found
# Lemmatized word:  zue
# Synset not found
# This sentence has a positive sentiment: 0.125
#
# New comment
# ---------------------------------------
# Sentence:  @ p3i__p3i
# [('@', 'NN'), ('p3i__p3i', 'NN')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  p3i__p3i
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  great pic!!
# [('great', 'JJ'), ('pic', 'NN'), ('!', '.'), ('!', '.')]
# Lemmatized word:  great
# great  |  Synset('great.s.01')  |  <great.s.01: PosScore=0.0 NegScore=0.0>  |  relatively large in size or number or extent; larger than others of its kind
# Lemmatized word:  pic
# pic  |  Synset('movie.n.01')  |  <movie.n.01: PosScore=0.0 NegScore=0.0>  |  a form of entertainment that enacts a story by sound and a sequence of images giving the illusion of continuous movement
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  🙌 😄
# [('🙌', 'NN'), ('😄', 'NN')]
# Lemmatized word:  🙌
# Synset not found
# Lemmatized word:  😄
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  great content!
# [('great', 'JJ'), ('content', 'NN'), ('!', '.')]
# Lemmatized word:  great
# great  |  Synset('great.s.01')  |  <great.s.01: PosScore=0.0 NegScore=0.0>  |  relatively large in size or number or extent; larger than others of its kind
# Lemmatized word:  content
# content  |  Synset('content.n.01')  |  <content.n.01: PosScore=0.0 NegScore=0.0>  |  everything that is included in a collection and that is held or included in something
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  thank you for the great workout and thank you for the great shutout on my birthday in the pool.
# [('thank', 'NN'), ('you', 'PRP'), ('for', 'IN'), ('the', 'DT'), ('great', 'JJ'), ('workout', 'NN'), ('and', 'CC'), ('thank', 'NN'), ('you', 'PRP'), ('for', 'IN'), ('the', 'DT'), ('great', 'JJ'), ('shutout', 'NN'), ('on', 'IN'), ('my', 'PRP$'), ('birthday', 'NN'), ('in', 'IN'), ('the', 'DT'), ('pool', 'NN'), ('.', '.')]
# Lemmatized word:  thank
# Synset not found
# Lemmatized word:  you
# Synset not found
# Lemmatized word:  for
# Synset not found
# Lemmatized word:  the
# Synset not found
# Lemmatized word:  great
# great  |  Synset('great.s.01')  |  <great.s.01: PosScore=0.0 NegScore=0.0>  |  relatively large in size or number or extent; larger than others of its kind
# Lemmatized word:  workout
# workout  |  Synset('exercise.n.01')  |  <exercise.n.01: PosScore=0.0 NegScore=0.0>  |  the activity of exerting your muscles in various ways to keep fit
# Lemmatized word:  and
# Synset not found
# Lemmatized word:  thank
# Synset not found
# Lemmatized word:  you
# Synset not found
# Lemmatized word:  for
# Synset not found
# Lemmatized word:  the
# Synset not found
# Lemmatized word:  great
# great  |  Synset('great.s.01')  |  <great.s.01: PosScore=0.0 NegScore=0.0>  |  relatively large in size or number or extent; larger than others of its kind
# Lemmatized word:  shutout
# shutout  |  Synset('shutout.n.01')  |  <shutout.n.01: PosScore=0.0 NegScore=0.0>  |  a defeat in a game where one side fails to score
# Lemmatized word:  on
# on  |  Synset('on.a.01')  |  <on.a.01: PosScore=0.0 NegScore=0.0>  |  in operation or operational
# Lemmatized word:  my
# Synset not found
# Lemmatized word:  birthday
# birthday  |  Synset('birthday.n.01')  |  <birthday.n.01: PosScore=0.0 NegScore=0.0>  |  an anniversary of the day on which a person was born (or the celebration of it)
# Lemmatized word:  in
# in  |  Synset('inch.n.01')  |  <inch.n.01: PosScore=0.0 NegScore=0.0>  |  a unit of length equal to one twelfth of a foot
# Lemmatized word:  the
# Synset not found
# Lemmatized word:  pool
# pool  |  Synset('pool.n.01')  |  <pool.n.01: PosScore=0.0 NegScore=0.0>  |  an excavation that is (usually) filled with water
# Lemmatized word:  .
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  having the best day for me!!
# [('having', 'VBG'), ('the', 'DT'), ('best', 'JJS'), ('day', 'NN'), ('for', 'IN'), ('me', 'PRP'), ('!', '.'), ('!', '.')]
# Lemmatized word:  have
# have  |  Synset('have.v.01')  |  <have.v.01: PosScore=0.25 NegScore=0.0>  |  have or possess, either in a concrete or an abstract sense
# Lemmatized word:  the
# Synset not found
# Lemmatized word:  best
# best  |  Synset('best.a.01')  |  <best.a.01: PosScore=0.75 NegScore=0.0>  |  (superlative of `good') having the most positive qualities
# Lemmatized word:  day
# day  |  Synset('day.n.01')  |  <day.n.01: PosScore=0.0 NegScore=0.0>  |  time for Earth to make a complete rotation on its axis
# Lemmatized word:  for
# Synset not found
# Lemmatized word:  me
# me  |  Synset('maine.n.01')  |  <maine.n.01: PosScore=0.0 NegScore=0.0>  |  a state in New England
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 1.0
# Sentence:  !
# [('!', '.')]
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  😊
# [('😊', 'NN')]
# Lemmatized word:  😊
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  👍🏻👍🏻
# [('👍🏻👍🏻', 'NN')]
# Lemmatized word:  👍🏻👍🏻
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  best
# [('best', 'JJS')]
# Lemmatized word:  best
# best  |  Synset('best.a.01')  |  <best.a.01: PosScore=0.75 NegScore=0.0>  |  (superlative of `good') having the most positive qualities
# This sentence has a positive sentiment: 0.75
#
# New comment
# ---------------------------------------
# Sentence:  looks like ff platinum tower 535 hong kong
# [('looks', 'NNS'), ('like', 'IN'), ('ff', 'JJ'), ('platinum', 'NN'), ('tower', 'NN'), ('535', 'CD'), ('hong', 'NN'), ('kong', 'NN')]
# Lemmatized word:  look
# look  |  Synset('expression.n.01')  |  <expression.n.01: PosScore=0.0 NegScore=0.0>  |  the feelings expressed on a person's face
# Lemmatized word:  like
# like  |  Synset('like.n.01')  |  <like.n.01: PosScore=0.125 NegScore=0.0>  |  a similar kind
# Lemmatized word:  ff
# Synset not found
# Lemmatized word:  platinum
# platinum  |  Synset('platinum.n.01')  |  <platinum.n.01: PosScore=0.0 NegScore=0.0>  |  a heavy precious metallic element; grey-white and resistant to corroding; occurs in some nickel and copper ores and is also found native in some deposits
# Lemmatized word:  tower
# tower  |  Synset('tower.n.01')  |  <tower.n.01: PosScore=0.0 NegScore=0.0>  |  a structure taller than its diameter; can stand alone or be attached to a larger building
# Lemmatized word:  535
# Synset not found
# Lemmatized word:  hong
# Synset not found
# Lemmatized word:  kong
# Synset not found
# This sentence has a positive sentiment: 0.125
#
# New comment
# ---------------------------------------
# Sentence:  nice lounge !
# [('nice', 'JJ'), ('lounge', 'NN'), ('!', '.')]
# Lemmatized word:  nice
# nice  has a score of 0.875
# Lemmatized word:  lounge
# lounge  |  Synset('sofa.n.01')  |  <sofa.n.01: PosScore=0.0 NegScore=0.0>  |  an upholstered seat for more than one person
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.875
#
# New comment
# ---------------------------------------
# Sentence:  fairtex punching bag??!
# [('fairtex', 'NN'), ('punching', 'VBG'), ('bag', 'NN'), ('?', '.'), ('?', '.'), ('!', '.')]
# Lemmatized word:  fairtex
# Synset not found
# Lemmatized word:  punch
# punch  |  Synset('punch.v.01')  |  <punch.v.01: PosScore=0.0 NegScore=0.0>  |  deliver a quick blow to
# Lemmatized word:  bag
# bag  |  Synset('bag.n.01')  |  <bag.n.01: PosScore=0.0 NegScore=0.0>  |  a flexible container with a single opening
# Lemmatized word:  ?
# Synset not found
# Lemmatized word:  ?
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  ohmaigadddd!!!!
# [('ohmaigadddd', 'NN'), ('!', '.'), ('!', '.'), ('!', '.'), ('!', '.')]
# Lemmatized word:  ohmaigadddd
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
# Sentence:  !
# [('!', '.')]
# Lemmatized word:  !
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  when cf member can join ff?
# [('when', 'WRB'), ('cf', 'JJ'), ('member', 'NN'), ('can', 'MD'), ('join', 'VB'), ('ff', 'VB'), ('?', '.')]
# Lemmatized word:  when
# Synset not found
# Lemmatized word:  cf
# Synset not found
# Lemmatized word:  member
# member  |  Synset('member.n.01')  |  <member.n.01: PosScore=0.0 NegScore=0.0>  |  one of the persons who compose a social group (especially individuals who have joined and participate in a group organization)
# Lemmatized word:  can
# can  |  Synset('can.n.01')  |  <can.n.01: PosScore=0.0 NegScore=0.0>  |  airtight sealed metal container for food or drink or paint etc.
# Lemmatized word:  join
# join  |  Synset('join.v.01')  |  <join.v.01: PosScore=0.0 NegScore=0.0>  |  become part of; become a member of a group or organization
# Lemmatized word:  ff
# Synset not found
# Lemmatized word:  ?
# Synset not found
# This sentence has a positive sentiment: 0.0
#
# New comment
# ---------------------------------------
# Sentence:  @masriana_darmawi gi exersize cmni k
# [('@', 'JJ'), ('masriana_darmawi', 'NN'), ('gi', 'NN'), ('exersize', 'VB'), ('cmni', 'NNS'), ('k', 'VB')]
# Lemmatized word:  @
# Synset not found
# Lemmatized word:  masriana_darmawi
# Synset not found
# Lemmatized word:  gi
# gi  |  Synset('gilbert.n.01')  |  <gilbert.n.01: PosScore=0.0 NegScore=0.0>  |  a unit of magnetomotive force equal to 0.7958 ampere-turns
# Lemmatized word:  exersize
# Synset not found
# Lemmatized word:  cmni
# Synset not found
# Lemmatized word:  k
# Synset not found
# This sentence has a positive sentiment: 0.0

# %%
df_filtered = df[df['Sentiment'] != 0]
print(len(df_filtered[df_filtered['Sentiment'] < 0]))
print(len(df_filtered[df_filtered['Sentiment'] > 0]))
# Out:
# 14
# 40

# %%
df_filtered[df_filtered['Sentiment'] > 0]
# Out:
#                                                   Post  \
# 5    Reward yourself with a refreshing drink and re...
# 6    Reward yourself with a refreshing drink and re...
# 7    Looking for a more challenging workout? Try th...
# 11   Get your workout on with Aqua Combat!\n\n#fitn...
# 17   Early Bird Tickets for Fit in The City are now...
# 20   Early Bird Tickets for Fit in The City are now...
# 23   Here's a sneak peek of what's coming your way ...
# 25   Here's a sneak peek of what's coming your way ...
# 30   Breathing in relaxation. Breathing out tension...
# 32   Spartan Beast 2017 is approaching soon and it’...
# 35   Ross, Fitness First & Celebrity Fitness Malays...
# 39   There will be obstacles, there will be doubter...
# 40   There will be obstacles, there will be doubter...
# 41   There will be obstacles, there will be doubter...
# 43   Our Fitness First team - Ahmad, Mukhriz, Faiz ...
# 45   We fight to beat the odds - new programme only...
# 47   We fight to beat the odds - new programme only...
# 50   3 days to go to opening of #FitnessFirstPlatin...
# 56   Adding one more club to our list! Meet our ama...
# 61   Work up a sweat with Renee and Queen, Fitness ...
# 65   Strengthen your core muscles - for overall bal...
# 66   Dance is the mission, #Zumba is the passion!\n...
# 68   Let the energy fuel you through an 8 hour back...
# 69   Let the energy fuel you through an 8 hour back...
# 77   Get your groove on with House, Hip Hop and Con...
# 83   Go all in, go all out with the NEW RELEASE of ...
# 88   @henrycedeno turning up the heat up at Fitness...
# 91   @henrycedeno turning up the heat up at Fitness...
# 96   Still don't have your Entry Pack for Fit in Th...
# 107  Push yourself because no one else is going to ...
# 108  Push yourself because no one else is going to ...
# 109  Push yourself because no one else is going to ...
# 114  Extended space for a more intense workout. New...
# 117  12 years and going strong. All thanks to your ...
# 118  Experience a sweet flow with fresh air on the ...
# 119  May the season bring you and your loved ones l...
# 121  It will have you grooving from the get go. Exp...
# 123  It will have you grooving from the get go. Exp...
# 130  The most precious gift you can give your loved...
# 133  Introducing BOOM, the latest programme at your...
#
#                                                Comment  \
# 5                                        nice lounge !
# 6           looks like ff platinum tower 535 hong kong
# 7                                                 best
# 11                        having the best day for me!!
# 17            @zue2020 ok sure why not.. when this zue
# 20   hiii you 💥 you could’ve certainly manager our ...
# 23       cant wait to get my toiletries bag hahahahaha
# 25        btw it's good to serve members around there.
# 30             what’s this beautiful place called 💫🦋💕🌸
# 32   we manufacture custom ocr and outdoor race app...
# 35             wow...ross looks like @casssmartin 😩lol
# 39                                        we had fun 😎
# 40                             thanks for the workout!
# 41                             thanks for the pics :))
# 43                                  you are hardcore !
# 45                                           hero 🥊🥊💥💥
# 47                                 looking good mikey!
# 50                            is there any free trial?
# 56   hello eriq, anne and all mm team..u guys are g...
# 61              the world will still be your miracle 😄
# 65                                                wow!
# 66                                     wow @joelle_teh
# 68                             you're doing great job.
# 69   loving your insta gallery :) i like your profile.
# 77          it's like skin care advertising @kenmuns 😁
# 83                            we are so proud of you 💜
# 88               i’ll be in malaysia 🇲🇾 in a few weeks
# 91                                 wow very awesome😍😍😍
# 96                     sounds like fun - free for all?
# 107  the instructors were very helpful demonstratin...
# 108                        the event was smooth going.
# 109  a big shoutout to everyone at @  and @celebrit...
# 114                                               nice
# 117                                               nice
# 118                                           love it!
# 119                               today close or open?
# 121  @damnputracy i introduce to u my favorite danc...
# 123                            this is sh’bam😂lol.....
# 130  very cool stuff :) continue with interesting c...
# 133                                              nice!
#
#                          Topic  Sentiment                           Source
# 5                       lounge      0.875  Instagram Comment Fitness First
# 6         looks,platinum,tower      0.125  Instagram Comment Fitness First
# 7                                   0.750  Instagram Comment Fitness First
# 11                         day      1.000  Instagram Comment Fitness First
# 17                                  0.125  Instagram Comment Fitness First
# 20   manager,line,knowledge,ig      0.250  Instagram Comment Fitness First
# 23             wait,toiletries      0.250  Instagram Comment Fitness First
# 25                     members      0.750  Instagram Comment Fitness First
# 30                     s,place      1.000  Instagram Comment Fitness First
# 32         race,apparel,chance      1.375  Instagram Comment Fitness First
# 35                         wow      0.625  Instagram Comment Fitness First
# 39                                  0.250  Instagram Comment Fitness First
# 40              thanks,workout      0.125  Instagram Comment Fitness First
# 41                 thanks,pics      0.125  Instagram Comment Fitness First
# 43                                  0.125  Instagram Comment Fitness First
# 45                        hero      0.375  Instagram Comment Fitness First
# 47                                  0.750  Instagram Comment Fitness First
# 50                       trial      0.500  Instagram Comment Fitness First
# 56             hello,anne,guys      0.125  Instagram Comment Fitness First
# 61               world,miracle      0.500  Instagram Comment Fitness First
# 65                         wow      0.500  Instagram Comment Fitness First
# 66                         wow      0.500  Instagram Comment Fitness First
# 68                         job      0.875  Instagram Comment Fitness First
# 69             gallery,profile      0.625  Instagram Comment Fitness First
# 77                        care      0.125  Instagram Comment Fitness First
# 83                                  0.250  Instagram Comment Fitness First
# 88              malaysia,weeks      0.125  Instagram Comment Fitness First
# 91                                  0.500  Instagram Comment Fitness First
# 96                  sounds,fun      0.875  Instagram Comment Fitness First
# 107                instructors      0.375  Instagram Comment Fitness First
# 108                      event      0.375  Instagram Comment Fitness First
# 109                                 0.125  Instagram Comment Fitness First
# 114                                 0.875  Instagram Comment Fitness First
# 117                                 0.875  Instagram Comment Fitness First
# 118                                 0.500  Instagram Comment Fitness First
# 119                      today      0.125  Instagram Comment Fitness First
# 121           dance,instructor      0.125  Instagram Comment Fitness First
# 123                                 0.125  Instagram Comment Fitness First
# 130              stuff,content      0.875  Instagram Comment Fitness First
# 133                                 0.875  Instagram Comment Fitness First

# %%
df_filtered[df_filtered['Sentiment'] < 0]
# Out:
#                                                   Post  \
# 19   Early Bird Tickets for Fit in The City are now...
# 26   Here's a sneak peek of what's coming your way ...
# 31   Early morning awakenings.\n\nEnergising Mornin...
# 42   Our Fitness First team - Ahmad, Mukhriz, Faiz ...
# 51   Tomorrow is the day! Just one day left to take...
# 53   We are about to unleash fresh moves and hot ne...
# 58   A desire, a passion, a champion. Stay tuned fo...
# 76   Get your groove on with House, Hip Hop and Con...
# 85   Be sure to collect your Entry Pack for Fit in ...
# 90   @henrycedeno turning up the heat up at Fitness...
# 99   A little sneak peek to Fit in The City. Happen...
# 100  A little sneak peek to Fit in The City. Happen...
# 105  Push yourself because no one else is going to ...
# 113  Extended space for a more intense workout. New...
#
#                                                Comment  \
# 19                                 act those instantly
# 26                      very bad traffic around there.
# 31   send us a direct message if you are looking fo...
# 42   missed this great session with the national at...
# 51   can somebody explain why other clubs patinum m...
# 53                     @hatayap hahaha ... not going 😁
# 58                                      pick up stop;)
# 76             @fettyzurando haha not sk ii, it’s skm!
# 85                           tshirt never ada jual ke?
# 90                                    omg i miss this!
# 99   moreover not matter is i also recognize people...
# 100  thank provide professional service to me, at t...
# 105    it's my first obstacle course and it's a blast!
# 113  hi  , are you iphone user?ada problem contact ...
#
#                                            Topic  Sentiment  \
# 19                                           act     -0.375
# 26                                       traffic     -0.625
# 31                                       message     -0.125
# 42                session,athletes,class,leisure     -0.250
# 51   somebody,clubs,members,access,club,november     -0.375
# 53                                                   -0.625
# 58                                          stop     -0.750
# 76                                            ii     -0.625
# 85                                                   -0.625
# 90                                                   -0.250
# 99                                 matter,people     -0.875
# 100                          service,people,case     -0.750
# 105                        obstacle,course,blast     -0.125
# 113                          ada,problem,contact     -0.125
#
#                               Source
# 19   Instagram Comment Fitness First
# 26   Instagram Comment Fitness First
# 31   Instagram Comment Fitness First
# 42   Instagram Comment Fitness First
# 51   Instagram Comment Fitness First
# 53   Instagram Comment Fitness First
# 58   Instagram Comment Fitness First
# 76   Instagram Comment Fitness First
# 85   Instagram Comment Fitness First
# 90   Instagram Comment Fitness First
# 99   Instagram Comment Fitness First
# 100  Instagram Comment Fitness First
# 105  Instagram Comment Fitness First
# 113  Instagram Comment Fitness First

# %%
df_filtered.to_json('instagram_fitnessfirstsentiment.json', orient='records')

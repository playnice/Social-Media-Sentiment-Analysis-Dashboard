# %%
#convert the csv to txt
import csv
import pandas as pd
f=pd.read_csv("uniqlo.my_facebook_comments.csv")
keep_col = ['comment_message']
new_f = f[keep_col]
new_f.to_csv("uniqlo.my_facebook_comments.csv", index=False)
with open('UniqloComment.txt', "w",encoding = "UTF-8") as my_output_file:
    with open('uniqlo.my_facebook_comments.csv', "r",encoding = "UTF-8") as my_input_file:
        [ my_output_file.write(" ".join(row)+'\n') for row in csv.reader(my_input_file)]
    my_output_file.close()

# %%
# Sentiment Analysis For Uniqlo Comment
import matplotlib.pyplot as plt
from textblob import TextBlob
if __name__ == "__main__":
    
    Sentence_polarity_pos =0
    Sentence_polarity_neutral = 0
    Sentence_polarity_neg = 0
    

    inputfile = open("UniqloComment.txt", "r",encoding = "UTF-8")
    outputfile = open("UMFBTEXTSentimentBySentence.txt", "w",encoding = "UTF-8")


    for line in inputfile:
        try:
            
            Count_neg=0
            Count_neutral=0
            Count_pos=0
            
            #print(line)
            line = TextBlob(line)
           
            print ("Input sentence = ", line.strip() + "\n")
            outputfile.write("Input sentence = " + str(line).strip() +"\n")
            
            for each_line in line.sentences:
                print("Line: " + str(each_line))
                print(each_line.sentiment)
                outputfile.write(str(each_line.sentiment)+"\n")

                if each_line.sentiment.polarity < 0.0:
                    print(each_line.sentiment)
                    print ("negative" + "\n")
                    outputfile.write (str(each_line)+"\n")
                    outputfile.write ("negative\n\n")
                    Count_neg +=1
                elif each_line.sentiment.polarity == 0:
                    print ("neutral" + "\n")
                    outputfile.write (str(each_line)+"\n")
                    outputfile.write ("neutral\n\n")
                    Count_neutral +=1
                else:
                    print ("positive" + "\n")
                    outputfile.write (str(each_line)+"\n")
                    outputfile.write ("positive\n\n")
                    Count_pos +=1

                    
            if Count_pos > Count_neg: 
                print ("THE SENTENCE IS +ve")
                outputfile.write ("The sentence has Positive sentiment\n\n")
                Sentence_polarity_pos += 1
                print (Sentence_polarity_pos)

            elif (Count_pos == Count_neg):  
                print ("THE SENTENCE IS NEUTRAL")
                outputfile.write ("The sentence is Neutral\n\n")
                print (Sentence_polarity_neutral)
                Sentence_polarity_neutral += 1

            else:
                print ("THE SENTENCE IS -ve") 
                outputfile.write ("The sentence has Negative sentiment\n\n")
                Sentence_polarity_neg += 1
                print (Sentence_polarity_neg)
           
            outputfile.write("=============================================================\n")
            print("========================================================================")
        except:
            continue

    print ("Sentence Polarity Negative = ",Sentence_polarity_neg )
    print ("Sentence Polarity Neutral = ",Sentence_polarity_neutral )
    print ("Sentence Polarity Positive = ",Sentence_polarity_pos )
    outputfile.write ("Sentence Polarity Negative = %s \n"%Sentence_polarity_neg )
    outputfile.write ("Sentence Polarity Neutral = %s \n"%Sentence_polarity_neutral )
    outputfile.write ("Sentence Polarity Positive = %s \n"%Sentence_polarity_pos )

    Polarity = [1,3]
    LABELS = ["Positive", "Negative"]
    Count_polarity = [Sentence_polarity_pos, Sentence_polarity_neg]

    plt.xlabel('Polarity')
    plt.ylabel('Count')
    plt.title('Uniqlo Sentiment Analysis')

    plt.grid(True)
    plt.bar(Polarity, Count_polarity, align='center')
    plt.xticks(Polarity, LABELS)
    plt.savefig('UniqloSentiment.png', dpi=1000)
    plt.show()
    
outputfile.close()
# Out:
# Input sentence =  comment_message
#
# Line: comment_message
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 0
# ========================================================================
# Input sentence =  Let's go together n buy. I'm a fan of uniqlo hahaha....every entry will grab one
#
# Line: Let's go together n buy.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I'm a fan of uniqlo hahaha....every entry will grab one
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 1
# ========================================================================
# Input sentence =  Atiqah Ismail
#
# Line: Atiqah Ismail
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 2
# ========================================================================
# Input sentence =  I open my purse i cry
#
# Line: I open my purse i cry
# Sentiment(polarity=0.0, subjectivity=0.5)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3
# ========================================================================
# Input sentence =  Do you have any white shirts that wont show my nipple :O
#
# Line: Do you have any white shirts that wont show my nipple :O
# Sentiment(polarity=0.025, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 1
# ========================================================================
# Input sentence =  Try turning off the aircond
#
# Line: Try turning off the aircond
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 4
# ========================================================================
# Input sentence =  Radzli Rahman u mean turning on ? hahaha
#
# Line: Radzli Rahman u mean turning on ?
# Sentiment(polarity=-0.3125, subjectivity=0.6875)
# Sentiment(polarity=-0.3125, subjectivity=0.6875)
# negative
#
# Line: hahaha
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS NEUTRAL
# 5
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 6
# ========================================================================
# Input sentence =  alot white shirts i have no idea why it look so thin that will show nipples. like opacity 70% thou
#
# Line: alot white shirts i have no idea why it look so thin that will show nipples.
# Sentiment(polarity=-0.2, subjectivity=0.42500000000000004)
# Sentiment(polarity=-0.2, subjectivity=0.42500000000000004)
# negative
#
# Line: like opacity 70% thou
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS -ve
# 1
# ========================================================================
# Input sentence =  No choice ah bro, wear inner
#
# Line: No choice ah bro, wear inner
# Sentiment(polarity=0.0, subjectivity=0.16666666666666666)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 7
# ========================================================================
# Input sentence =  Ryan E Liang wear inner gonna be too hot + extra detergent leh haha just saying.
#
# Line: Ryan E Liang wear inner gonna be too hot + extra detergent leh haha just saying.
# Sentiment(polarity=0.1125, subjectivity=0.35416666666666674)
# positive
#
# THE SENTENCE IS +ve
# 2
# ========================================================================
# Input sentence =  Azra Izzatie
#
# Line: Azra Izzatie
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 8
# ========================================================================
# Input sentence =  Eugene Tan
#
# Line: Eugene Tan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 9
# ========================================================================
# Input sentence =  If you turn on aircond (cold), your nipple will become erect/firm. It will highlight your nips even more 😂
#
# Line: If you turn on aircond (cold), your nipple will become erect/firm.
# Sentiment(polarity=-0.6, subjectivity=1.0)
# Sentiment(polarity=-0.6, subjectivity=1.0)
# negative
#
# Line: It will highlight your nips even more 😂
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS NEUTRAL
# 10
# ========================================================================
# Input sentence =  Radzli Rahman hahaha i tot its because of the weather in Malaysia that makes me sweat which causes my shirt to turn visible. hahahaha
#
# Line: Radzli Rahman hahaha i tot its because of the weather in Malaysia that makes me sweat which causes my shirt to turn visible.
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# Line: hahahaha
# Sentiment(polarity=0.2, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 3
# ========================================================================
# Input sentence =  Chen Yong Bryan Jian Feng Albert Liow Chien Her
#
# Line: Chen Yong Bryan Jian Feng Albert Liow Chien Her
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 11
# ========================================================================
# Input sentence =  U should wear bra...its proven.. by women
#
# Line: U should wear bra...its proven.. by women
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 12
# ========================================================================
# Input sentence =  Azrul Best yea. and the shape of the bra can be seen.
#
# Line: Azrul Best yea.
# Sentiment(polarity=1.0, subjectivity=0.3)
# positive
#
# Line: and the shape of the bra can be seen.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 4
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 13
# ========================================================================
# Input sentence =  #eyecandy
#
# Line: #eyecandy
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 14
# ========================================================================
# Input sentence =  Use nipple tape
#
# Line: Use nipple tape
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 15
# ========================================================================
# Input sentence =  Shawn Yong  wear white airism.
#
# Line: Shawn Yong  wear white airism.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 16
# ========================================================================
# Input sentence =  Maybe the ladies / guys in ur office turn you on?
#
# Line: Maybe the ladies / guys in ur office turn you on?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 17
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 18
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 19
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 20
# ========================================================================
# Input sentence =  I'm not judging
#
# Line: I'm not judging
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 21
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 22
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 23
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 24
# ========================================================================
# Input sentence =  😂😂🤣🤣
#
# Line: 😂😂🤣🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 25
# ========================================================================
# Input sentence =  Jimmg Chng nope. I turned myself on.
#
# Line: Jimmg Chng nope.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I turned myself on.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 26
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 27
# ========================================================================
# Input sentence =  Im too HAWT! dayum hahaha
#
# Line: Im too HAWT!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: dayum hahaha
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 5
# ========================================================================
# Input sentence =  workout bro
#
# Line: workout bro
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 28
# ========================================================================
# Input sentence =  Darren Ong i'm gonna get loads of these for you. hmmmm....when are they doing this for school uniforms? 😂
#
# Line: Darren Ong i'm gonna get loads of these for you.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: hmmmm....when are they doing this for school uniforms?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 29
# ========================================================================
# Input sentence =  Do you have super non-iron shirt for lady?
#
# Line: Do you have super non-iron shirt for lady?
# Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# positive
#
# THE SENTENCE IS +ve
# 6
# ========================================================================
# Input sentence =  Do you make non-iron women’s shirts?
#
# Line: Do you make non-iron women’s shirts?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 30
# ========================================================================
# Input sentence =  I air dried it but still have to iron
#
# Line: I air dried it but still have to iron
# Sentiment(polarity=-0.2, subjectivity=0.6)
# Sentiment(polarity=-0.2, subjectivity=0.6)
# negative
#
# THE SENTENCE IS -ve
# 2
# ========================================================================
# Input sentence =  Hi, u meant this Uniqlo one?  I'm skeptical
#
# Line: Hi, u meant this Uniqlo one?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I'm skeptical
# Sentiment(polarity=-0.5, subjectivity=0.5)
# Sentiment(polarity=-0.5, subjectivity=0.5)
# negative
#
# THE SENTENCE IS -ve
# 3
# ========================================================================
# Input sentence =  Chris Lim Leong Fah yes. My husband has but still need to iron
#
# Line: Chris Lim Leong Fah yes.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: My husband has but still need to iron
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 31
# ========================================================================
# Input sentence =  Same. Still need to iron. No different from other brand work shirt.
#
# Line: Same.
# Sentiment(polarity=0.0, subjectivity=0.125)
# neutral
#
# Line: Still need to iron.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: No different from other brand work shirt.
# Sentiment(polarity=-0.0625, subjectivity=0.4875)
# Sentiment(polarity=-0.0625, subjectivity=0.4875)
# negative
#
# THE SENTENCE IS -ve
# 4
# ========================================================================
# Input sentence =  If you guys see in the first ads the shirt still wrinkle when he wear from the washing machine 😂
#
# Line: If you guys see in the first ads the shirt still wrinkle when he wear from the washing machine 😂
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# positive
#
# THE SENTENCE IS +ve
# 7
# ========================================================================
# Input sentence =  Iman Nadieya Hassan org ni ckp still kene iron. Dahh, review dah confirmkn jgn nk mengada bazir duit pi beli..
#
# Line: Iman Nadieya Hassan org ni ckp still kene iron.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Dahh, review dah confirmkn jgn nk mengada bazir duit pi beli..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 32
# ========================================================================
# Input sentence =  Jessie Lim gonna get one and try xD I’ll crumple and see 😂
#
# Line: Jessie Lim gonna get one and try xD I’ll crumple and see 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 33
# ========================================================================
# Input sentence =  wah o.o so cool de the advertisement
#
# Line: wah o.o so cool de the advertisement
# Sentiment(polarity=0.19999999999999998, subjectivity=0.825)
# positive
#
# THE SENTENCE IS +ve
# 8
# ========================================================================
# Input sentence =  I bought this non iron shirt but still have to iron. Nonsense
#
# Line: I bought this non iron shirt but still have to iron.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Nonsense
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 34
# ========================================================================
# Input sentence =  This is what I always wanted. Hehehe. Sure will visit uniqlo soon.
#
# Line: This is what I always wanted.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Hehehe.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Sure will visit uniqlo soon.
# Sentiment(polarity=0.5, subjectivity=0.8888888888888888)
# positive
#
# THE SENTENCE IS +ve
# 9
# ========================================================================
# Input sentence =  Kenny Li can you like go back to melbs and get me 5 of these kthxbye
#
# Line: Kenny Li can you like go back to melbs and get me 5 of these kthxbye
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 35
# ========================================================================
# Input sentence =  HAHAHA
#
# Line: HAHAHA
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 10
# ========================================================================
# Input sentence =  Maybe :)
#
# Line: Maybe :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 11
# ========================================================================
# Input sentence =  Joel  I think we need to change your whole wardrobe to this! 😂
#
# Line: Joel  I think we need to change your whole wardrobe to this!
# Sentiment(polarity=0.25, subjectivity=0.4)
# positive
#
# Line: 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 12
# ========================================================================
# Input sentence =  When will have bigger size for man? Wish to buy for my husband.
#
# Line: When will have bigger size for man?
# Sentiment(polarity=0.0, subjectivity=0.5)
# neutral
#
# Line: Wish to buy for my husband.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 36
# ========================================================================
# Input sentence =  Joyce Kan you can buy for me if you don't want to ironing anymore.
#
# Line: Joyce Kan you can buy for me if you don't want to ironing anymore.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 37
# ========================================================================
# Input sentence =  You should think of sayang your wife, change all to this by yourself!
#
# Line: You should think of sayang your wife, change all to this by yourself!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 38
# ========================================================================
# Input sentence =  tagging all husband Yong David
#
# Line: tagging all husband Yong David
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 39
# ========================================================================
# Input sentence =  Evangeline Lau i think this is so for me who lazy to iron hahahhahhahahaha
#
# Line: Evangeline Lau i think this is so for me who lazy to iron hahahhahhahahaha
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 5
# ========================================================================
# Input sentence =  Nobody likes iron baju la😂
#
# Line: Nobody likes iron baju la😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 40
# ========================================================================
# Input sentence =  But i hv to wear compny uniform..ermm
#
# Line: But i hv to wear compny uniform..ermm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 41
# ========================================================================
# Input sentence =  Jien Wai Lim can buy this one Liao!
#
# Line: Jien Wai Lim can buy this one Liao!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 42
# ========================================================================
# Input sentence =  I had non iron cloth from other brand. It is soft type or
#
# Line: I had non iron cloth from other brand.
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Sentiment(polarity=-0.125, subjectivity=0.375)
# negative
#
# Line: It is soft type or
# Sentiment(polarity=0.1, subjectivity=0.35)
# positive
#
# THE SENTENCE IS NEUTRAL
# 43
# ========================================================================
# Input sentence =  Marius no antimicrobes tho
#
# Line: Marius no antimicrobes tho
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 44
# ========================================================================
# Input sentence =  It's just not good enough then😂
#
# Line: It's just not good enough then😂
# Sentiment(polarity=-0.175, subjectivity=0.55)
# Sentiment(polarity=-0.175, subjectivity=0.55)
# negative
#
# THE SENTENCE IS -ve
# 6
# ========================================================================
# Input sentence =  Uniqlo Malaysia depending on what washing conditions? Can explain in detail?
#
# Line: Uniqlo Malaysia depending on what washing conditions?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Can explain in detail?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 45
# ========================================================================
# Input sentence =  Kelvin Tayu need this lazy nong hahaha
#
# Line: Kelvin Tayu need this lazy nong hahaha
# Sentiment(polarity=-0.024999999999999994, subjectivity=0.7)
# Sentiment(polarity=-0.024999999999999994, subjectivity=0.7)
# negative
#
# THE SENTENCE IS -ve
# 7
# ========================================================================
# Input sentence =  Buy pls
#
# Line: Buy pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 46
# ========================================================================
# Input sentence =  Yi Lin Ong, in future, throw away your iron.
#
# Line: Yi Lin Ong, in future, throw away your iron.
# Sentiment(polarity=0.0, subjectivity=0.125)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 47
# ========================================================================
# Input sentence =  Lo Chang Yong your fav brand but it's preventing from doing your fav thing. 😂
#
# Line: Lo Chang Yong your fav brand but it's preventing from doing your fav thing.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 48
# ========================================================================
# Input sentence =  yeah . so sad :(
#
# Line: yeah .
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: so sad :(
# Sentiment(polarity=-0.625, subjectivity=1.0)
# Sentiment(polarity=-0.625, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 8
# ========================================================================
# Input sentence =  Farah Aisyah my dream clothes. How about scarfs?? Take my money!! Tapi harga duck! Tapi no need to iron!!!!!!! 😭
#
# Line: Farah Aisyah my dream clothes.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: How about scarfs??
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Take my money!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Tapi harga duck!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Tapi no need to iron!!!!!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😭
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 49
# ========================================================================
# Input sentence =  Beli sehelai utk pki waktu terdesak lmbt gi kerja hahah
#
# Line: Beli sehelai utk pki waktu terdesak lmbt gi kerja hahah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 50
# ========================================================================
# Input sentence =  Mine Ascmmy kalau sy beli yang ni, rugi pula tak pakai iron baru awak tuuu haha😂🤣
#
# Line: Mine Ascmmy kalau sy beli yang ni, rugi pula tak pakai iron baru awak tuuu haha😂🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 51
# ========================================================================
# Input sentence =  alaaaa ye dok uniqlo ni hahahahh
#
# Line: alaaaa ye dok uniqlo ni hahahahh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 52
# ========================================================================
# Input sentence =  Tan Ching Pei no need iron shirt Liao yes
#
# Line: Tan Ching Pei no need iron shirt Liao yes
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 53
# ========================================================================
# Input sentence =  Can you produce more Regular fit office shirts? Too many Slim fits available...
#
# Line: Can you produce more Regular fit office shirts?
# Sentiment(polarity=0.3, subjectivity=0.32564102564102565)
# positive
#
# Line: Too many Slim fits available...
# Sentiment(polarity=0.45, subjectivity=0.45)
# positive
#
# THE SENTENCE IS +ve
# 13
# ========================================================================
# Input sentence =  Chong Hr your dream come true 😂
#
# Line: Chong Hr your dream come true 😂
# Sentiment(polarity=0.35, subjectivity=0.65)
# positive
#
# THE SENTENCE IS +ve
# 14
# ========================================================================
# Input sentence =  Wong C. Kok u shd invest into this!
#
# Line: Wong C. Kok u shd invest into this!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 54
# ========================================================================
# Input sentence =  Choong Koi Ling u can ask ur husband invest liao
#
# Line: Choong Koi Ling u can ask ur husband invest liao
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 55
# ========================================================================
# Input sentence =  Yaya... I saw this too... checked the price liao
#
# Line: Yaya...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I saw this too... checked the price liao
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 56
# ========================================================================
# Input sentence =  But still ask him to iron himself 😬😬
#
# Line: But still ask him to iron himself 😬😬
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 57
# ========================================================================
# Input sentence =  Jireh Ho Jia Jun this is customized for u!
#
# Line: Jireh Ho Jia Jun this is customized for u!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 58
# ========================================================================
# Input sentence =  Hazman Hasim get this more baby!
#
# Line: Hazman Hasim get this more baby!
# Sentiment(polarity=0.625, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 15
# ========================================================================
# Input sentence =  Diana Dee wonder if they have my size!
#
# Line: Diana Dee wonder if they have my size!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 59
# ========================================================================
# Input sentence =  Rodrigo Arturo You need to buy this 😊
#
# Line: Rodrigo Arturo You need to buy this 😊
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 60
# ========================================================================
# Input sentence =  I definitely do :(
#
# Line: I definitely do :(
# Sentiment(polarity=-0.375, subjectivity=0.75)
# Sentiment(polarity=-0.375, subjectivity=0.75)
# negative
#
# THE SENTENCE IS -ve
# 9
# ========================================================================
# Input sentence =  Alicia Lok can help me buy all available colours?
#
# Line: Alicia Lok can help me buy all available colours?
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 16
# ========================================================================
# Input sentence =  Han Neo you need this so badly.
#
# Line: Han Neo you need this so badly.
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)
# negative
#
# THE SENTENCE IS -ve
# 10
# ========================================================================
# Input sentence =  Zhang Phong Ooi Eugene Tan don’t need to spend 500 years ironing your shirt before clubbing anymore
#
# Line: Zhang Phong Ooi Eugene Tan don’t need to spend 500 years ironing your shirt before clubbing anymore
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 61
# ========================================================================
# Input sentence =  Ryan Chan you forgot about him
#
# Line: Ryan Chan you forgot about him
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 62
# ========================================================================
# Input sentence =  Wen Kaii Lim the video concept i was talking about
#
# Line: Wen Kaii Lim the video concept i was talking about
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 63
# ========================================================================
# Input sentence =  Muhammad Azreeq g beli kat uniqlo..sesuai utk kau..hahah
#
# Line: Muhammad Azreeq g beli kat uniqlo..sesuai utk kau..hahah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 64
# ========================================================================
# Input sentence =  Esther How time to get these instead of g2000
#
# Line: Esther How time to get these instead of g2000
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 65
# ========================================================================
# Input sentence =  Omg specially made for you !!! Sarah Chang
#
# Line: Omg specially made for you !!!
# Sentiment(polarity=0.6975446428571429, subjectivity=0.5714285714285714)
# positive
#
# Line: Sarah Chang
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 17
# ========================================================================
# Input sentence =  But they only have men’s shirt!!! So unfair
#
# Line: But they only have men’s shirt!!!
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: So unfair
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 11
# ========================================================================
# Input sentence =  Sarah Chang sure got ladies must go see
#
# Line: Sarah Chang sure got ladies must go see
# Sentiment(polarity=0.5, subjectivity=0.8888888888888888)
# positive
#
# THE SENTENCE IS +ve
# 18
# ========================================================================
# Input sentence =  Anna Liang Christopher Lee- no need to drive to the dry cleaners lol
#
# Line: Anna Liang Christopher Lee- no need to drive to the dry cleaners lol
# Sentiment(polarity=0.3666666666666667, subjectivity=0.6499999999999999)
# positive
#
# THE SENTENCE IS +ve
# 19
# ========================================================================
# Input sentence =  Prema Ra can buy for Paul
#
# Line: Prema Ra can buy for Paul
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 66
# ========================================================================
# Input sentence =  Ameenur Rashid Selamat wujud lah kemeja xyah iron.. kau bleh beli..
#
# Line: Ameenur Rashid Selamat wujud lah kemeja xyah iron.. kau bleh beli..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 67
# ========================================================================
# Input sentence =  Mell Ejah 😍😍 no need to iron.
#
# Line: Mell Ejah 😍😍 no need to iron.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 68
# ========================================================================
# Input sentence =  pmpuan punya tda ka?😄😄
#
# Line: pmpuan punya tda ka?😄😄
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 69
# ========================================================================
# Input sentence =  Coming soon 🙊
#
# Line: Coming soon 🙊
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 70
# ========================================================================
# Input sentence =  Terrance Tan pls buy shirt from uniqlo
#
# Line: Terrance Tan pls buy shirt from uniqlo
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 71
# ========================================================================
# Input sentence =  Pls buy for me 😘
#
# Line: Pls buy for me 😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 72
# ========================================================================
# Input sentence =  Wai Fung Tsui have you bought this that day 😂
#
# Line: Wai Fung Tsui have you bought this that day 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 73
# ========================================================================
# Input sentence =  why he acting bust on the right hand side?🤔
#
# Line: why he acting bust on the right hand side?🤔
# Sentiment(polarity=0.14285714285714285, subjectivity=0.26785714285714285)
# positive
#
# THE SENTENCE IS +ve
# 20
# ========================================================================
# Input sentence =  busy*
#
# Line: busy*
# Sentiment(polarity=0.1, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 21
# ========================================================================
# Input sentence =  TungLiang Tan suitable for u. Go buy go buy
#
# Line: TungLiang Tan suitable for u.
# Sentiment(polarity=0.55, subjectivity=0.75)
# positive
#
# Line: Go buy go buy
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 22
# ========================================================================
# Input sentence =  Faliq Murad you need this in all colors.
#
# Line: Faliq Murad you need this in all colors.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 74
# ========================================================================
# Input sentence =  Ruby Lee something for me lol
#
# Line: Ruby Lee something for me lol
# Sentiment(polarity=0.8, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 23
# ========================================================================
# Input sentence =  Meant for lazy people. Lol
#
# Line: Meant for lazy people.
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# negative
#
# Line: Lol
# Sentiment(polarity=0.8, subjectivity=0.7)
# positive
#
# THE SENTENCE IS NEUTRAL
# 75
# ========================================================================
# Input sentence =  Ruby Lee innovation ok
#
# Line: Ruby Lee innovation ok
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 24
# ========================================================================
# Input sentence =  Cheah Qian Yi maybe he bought this kind of shirts that's why his shirt looks neat all the time hahha
#
# Line: Cheah Qian Yi maybe he bought this kind of shirts that's why his shirt looks neat all the time hahha
# Sentiment(polarity=0.6, subjectivity=0.9)
# positive
#
# THE SENTENCE IS +ve
# 25
# ========================================================================
# Input sentence =  Hahahahahaha omg sohai 😂😂 you should too 😏😏
#
# Line: Hahahahahaha omg sohai 😂😂 you should too 😏😏
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 76
# ========================================================================
# Input sentence =  Anna Radzihan..buy this for my brother..😀😀😀
#
# Line: Anna Radzihan..buy this for my brother..😀😀😀
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 77
# ========================================================================
# Input sentence =  Dinie Mohamed non iron shirt.. weehooo..
#
# Line: Dinie Mohamed non iron shirt.. weehooo..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 78
# ========================================================================
# Input sentence =  Melvin Chong please buy more of this
#
# Line: Melvin Chong please buy more of this
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 26
# ========================================================================
# Input sentence =  Have to be comfortable also
#
# Line: Have to be comfortable also
# Sentiment(polarity=0.4, subjectivity=0.8)
# positive
#
# THE SENTENCE IS +ve
# 27
# ========================================================================
# Input sentence =  Keyth Ng u should buy 😏
#
# Line: Keyth Ng u should buy 😏
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 79
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 80
# ========================================================================
# Input sentence =  Sarrah Yusof Adilah Wafaa nah hampa xrajin nak iron baju kan😌😌😌
#
# Line: Sarrah Yusof Adilah Wafaa nah hampa xrajin nak iron baju kan😌😌😌
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 81
# ========================================================================
# Input sentence =  Melissa Ong I’m gonna buy 10 of this shirt
#
# Line: Melissa Ong I’m gonna buy 10 of this shirt
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 82
# ========================================================================
# Input sentence =  I just bought one actually 😂😂 the old one la rayon shirt
#
# Line: I just bought one actually 😂😂 the old one la rayon shirt
# Sentiment(polarity=0.05, subjectivity=0.15000000000000002)
# positive
#
# THE SENTENCE IS +ve
# 28
# ========================================================================
# Input sentence =  Melissa Ong is it as good as they say?
#
# Line: Melissa Ong is it as good as they say?
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
#
# THE SENTENCE IS +ve
# 29
# ========================================================================
# Input sentence =  Yes! It’s super comfy I slept in it on the plane
#
# Line: Yes!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: It’s super comfy I slept in it on the plane
# Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# positive
#
# THE SENTENCE IS +ve
# 30
# ========================================================================
# Input sentence =  Please, let’s buy this 😁 Aidi Affendi
#
# Line: Please, let’s buy this 😁 Aidi Affendi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 83
# ========================================================================
# Input sentence =  Lawrence Leong You need to get this ;)
#
# Line: Lawrence Leong You need to get this ;)
# Sentiment(polarity=0.25, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 31
# ========================================================================
# Input sentence =  Yasmin Jamian Syahida Amo kasi beli sy satu. Nda payah iron punya
#
# Line: Yasmin Jamian Syahida Amo kasi beli sy satu.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Nda payah iron punya
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 84
# ========================================================================
# Input sentence =  X payah jess. kta iron syiak bju hari2 k
#
# Line: X payah jess.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: kta iron syiak bju hari2 k
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 85
# ========================================================================
# Input sentence =  Berapa latus la niii
#
# Line: Berapa latus la niii
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 86
# ========================================================================
# Input sentence =  Murah ja tu 😂😂
#
# Line: Murah ja tu 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 87
# ========================================================================
# Input sentence =  Li Ping Ooi they heard me!!!
#
# Line: Li Ping Ooi they heard me!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 88
# ========================================================================
# Input sentence =  Can buy 7 pieces. Forever wear them hahaha
#
# Line: Can buy 7 pieces.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Forever wear them hahaha
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 32
# ========================================================================
# Input sentence =  😩the price
#
# Line: 😩the price
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 89
# ========================================================================
# Input sentence =  Anything for the ladies? Non iron? Hihi
#
# Line: Anything for the ladies?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Non iron?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Hihi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 90
# ========================================================================
# Input sentence =  Joey Khong you will be kedut no longer!
#
# Line: Joey Khong you will be kedut no longer!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 91
# ========================================================================
# Input sentence =  Noiceeee! 😁
#
# Line: Noiceeee!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😁
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 92
# ========================================================================
# Input sentence =  Uniqlo; how to buy online
#
# Line: Uniqlo; how to buy online
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 93
# ========================================================================
# Input sentence =  None for the ladies?
#
# Line: None for the ladies?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 94
# ========================================================================
# Input sentence =  Siti sarah Aida Suhaimi kalo ada women's shirt bleh beli ni
#
# Line: Siti sarah Aida Suhaimi kalo ada women's shirt bleh beli ni
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 95
# ========================================================================
# Input sentence =  Senang kannn
#
# Line: Senang kannn
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 96
# ========================================================================
# Input sentence =  Klaus Cheok this very good leh
#
# Line: Klaus Cheok this very good leh
# Sentiment(polarity=0.9099999999999999, subjectivity=0.7800000000000001)
# positive
#
# THE SENTENCE IS +ve
# 33
# ========================================================================
# Input sentence =  Really? Later go have a look
#
# Line: Really?
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# Line: Later go have a look
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 34
# ========================================================================
# Input sentence =  No need iron leh..somemore not really expensive pun
#
# Line: No need iron leh..somemore not really expensive pun
# Sentiment(polarity=0.25, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 35
# ========================================================================
# Input sentence =  Haha, very nice 👍🏻
#
# Line: Haha, very nice 👍🏻
# Sentiment(polarity=0.49, subjectivity=0.65)
# positive
#
# THE SENTENCE IS +ve
# 36
# ========================================================================
# Input sentence =  Izzat Syahmi Yusni beli hop ni la pg2 x yoh gosok baju dh
#
# Line: Izzat Syahmi Yusni beli hop ni la pg2 x yoh gosok baju dh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 97
# ========================================================================
# Input sentence =  Second intake
#
# Line: Second intake
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 98
# ========================================================================
# Input sentence =  威翰, good
#
# Line: 威翰, good
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
#
# THE SENTENCE IS +ve
# 37
# ========================================================================
# Input sentence =  Fuyooooooo ni best ni 🤣 Fh Mohammad Faiz
#
# Line: Fuyooooooo ni best ni 🤣 Fh Mohammad Faiz
# Sentiment(polarity=1.0, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 38
# ========================================================================
# Input sentence =  ta best tade side
#
# Line: ta best tade side
# Sentiment(polarity=1.0, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 39
# ========================================================================
# Input sentence =  K 😑
#
# Line: K 😑
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 99
# ========================================================================
# Input sentence =  Chris Rjn check it out ok
#
# Line: Chris Rjn check it out ok
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 40
# ========================================================================
# Input sentence =  Ryan Eng Kah Jie im gonna get this for u
#
# Line: Ryan Eng Kah Jie im gonna get this for u
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 100
# ========================================================================
# Input sentence =  Roziah Abu tgk ni...macam boleh beli ni...
#
# Line: Roziah Abu tgk ni...macam boleh beli ni...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 101
# ========================================================================
# Input sentence =  Sy sokong kenyataan di atas...
#
# Line: Sy sokong kenyataan di atas...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 102
# ========================================================================
# Input sentence =  Jom kamal...hahaha
#
# Line: Jom kamal...hahaha
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 103
# ========================================================================
# Input sentence =  Aha jommm
#
# Line: Aha jommm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 104
# ========================================================================
# Input sentence =  Angeline Lai mom gonna love these shirts.
#
# Line: Angeline Lai mom gonna love these shirts.
# Sentiment(polarity=0.5, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 41
# ========================================================================
# Input sentence =  Izzul Haziq you should try this
#
# Line: Izzul Haziq you should try this
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 105
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 106
# ========================================================================
# Input sentence =  One dozen please ...
#
# Line: One dozen please ...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 107
# ========================================================================
# Input sentence =  Pui-Ching Yong saves you from ironing
#
# Line: Pui-Ching Yong saves you from ironing
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 108
# ========================================================================
# Input sentence =  Unikuro
#
# Line: Unikuro
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 109
# ========================================================================
# Input sentence =  应该做校裙的😂😂😂 钟宛妤 then no need to iron it haizzz
#
# Line: 应该做校裙的😂😂😂 钟宛妤 then no need to iron it haizzz
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 110
# ========================================================================
# Input sentence =  真好😂😂😂
#
# Line: 真好😂😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 111
# ========================================================================
# Input sentence =  如果我们住一起就买一个😂😂😂😂
#
# Line: 如果我们住一起就买一个😂😂😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 112
# ========================================================================
# Input sentence =  钟宛妤 ok hahahhaha😂😂😂😂😂
#
# Line: 钟宛妤 ok hahahhaha😂😂😂😂😂
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 42
# ========================================================================
# Input sentence =  Nice..cma hrga je..
#
# Line: Nice..cma hrga je..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 113
# ========================================================================
# Input sentence =  Abg Amir Syafiq lps nie beli baju kije nie byk2...syg xyh gsok dh... 😂😂😂
#
# Line: Abg Amir Syafiq lps nie beli baju kije nie byk2...syg xyh gsok dh... 😂😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 114
# ========================================================================
# Input sentence =  Uniqlo always make a good product ! :D
#
# Line: Uniqlo always make a good product !
# Sentiment(polarity=0.875, subjectivity=0.6000000000000001)
# positive
#
# Line: :D
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 43
# ========================================================================
# Input sentence =  Aku suka dengan baju Uniqlo setiap baju dia bila pakai selesa
#
# Line: Aku suka dengan baju Uniqlo setiap baju dia bila pakai selesa
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 115
# ========================================================================
# Input sentence =  Wahhhh😍
#
# Line: Wahhhh😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 116
# ========================================================================
# Input sentence =  Baju tu takde unsur iron betul la tu
#
# Line: Baju tu takde unsur iron betul la tu
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 117
# ========================================================================
# Input sentence =  Jun Chew
#
# Line: Jun Chew
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 118
# ========================================================================
# Input sentence =  Jom
#
# Line: Jom
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 119
# ========================================================================
# Input sentence =  Mau takmau qatuih jgk nii
#
# Line: Mau takmau qatuih jgk nii
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 120
# ========================================================================
# Input sentence =  Settle masalah
#
# Line: Settle masalah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 121
# ========================================================================
# Input sentence =  Seriously ?!
#
# Line: Seriously ?
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.6666666666666666)
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.6666666666666666)
# negative
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS -ve
# 12
# ========================================================================
# Input sentence =  I needed this!
#
# ...
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3080
# ========================================================================
# Input sentence =  Akmal Azman kepala bapak harga cm tu eh 😂
#
# Line: Akmal Azman kepala bapak harga cm tu eh 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3081
# ========================================================================
# Input sentence =  John Louis Monteza Fernandez
#
# Line: John Louis Monteza Fernandez
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3082
# ========================================================================
# Input sentence =  John Louis Monteza Fernandez
#
# Line: John Louis Monteza Fernandez
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3083
# ========================================================================
# Input sentence =  Nabila Arijja
#
# Line: Nabila Arijja
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3084
# ========================================================================
# Input sentence =  Abby Teoh
#
# Line: Abby Teoh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3085
# ========================================================================
# Input sentence =  Hafizul Azren
#
# Line: Hafizul Azren
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3086
# ========================================================================
# Input sentence =  Zunaiddie Didi
#
# Line: Zunaiddie Didi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3087
# ========================================================================
# Input sentence =  吴玉萍
#
# Line: 吴玉萍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3088
# ========================================================================
# Input sentence =  I m from sg. Can i order online and collect at JB outlet?
#
# Line: I m from sg.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Can i order online and collect at JB outlet?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3089
# ========================================================================
# Input sentence =  Hi Christy Tay, yes you can. Check out our Click and Collect option here: http://www.uniqlo.com/my/clickandcollect/
#
# Line: Hi Christy Tay, yes you can.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Check out our Click and Collect option here: http://www.uniqlo.com/my/clickandcollect/
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3090
# ========================================================================
# Input sentence =  the outlet is all in KL? how to select the one in JB
#
# Line: the outlet is all in KL?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: how to select the one in JB
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3091
# ========================================================================
# Input sentence =  the click and collect is it available at johor? can't find any selection
#
# Line: the click and collect is it available at johor?
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# Line: can't find any selection
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 573
# ========================================================================
# Input sentence =  Hi Christy Tay, the click and collect stores are only in the selection given. :/
#
# Line: Hi Christy Tay, the click and collect stores are only in the selection given.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: :/
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 138
# ========================================================================
# Input sentence =  Legging can tahan under - 10°c?
#
# Line: Legging can tahan under - 10°c?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3092
# ========================================================================
# Input sentence =  Hey Chan Ev, yes they are suitable for winter. You may want to wear layers to keep the cold and wind out. We also recommend our Blocktech warm lined pants which has a fleece lining inside. Do note that these also depend on individual tolerance to cold and wind speeds.
#
# Line: Hey Chan Ev, yes they are suitable for winter.
# Sentiment(polarity=0.55, subjectivity=0.75)
# positive
#
# Line: You may want to wear layers to keep the cold and wind out.
# Sentiment(polarity=-0.6, subjectivity=1.0)
# Sentiment(polarity=-0.6, subjectivity=1.0)
# negative
#
# Line: We also recommend our Blocktech warm lined pants which has a fleece lining inside.
# Sentiment(polarity=0.6, subjectivity=0.6)
# positive
#
# Line: Do note that these also depend on individual tolerance to cold and wind speeds.
# Sentiment(polarity=-0.3, subjectivity=0.7)
# Sentiment(polarity=-0.3, subjectivity=0.7)
# negative
#
# THE SENTENCE IS NEUTRAL
# 3093
# ========================================================================
# Input sentence =  Wah ! Now still have ultra warm . Any different leh ! Haha , mean the last version not enough warm
#
# Line: Wah !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Now still have ultra warm .
# Sentiment(polarity=0.6, subjectivity=0.6)
# positive
#
# Line: Any different leh !
# Sentiment(polarity=0.0, subjectivity=0.6)
# neutral
#
# Line: Haha , mean the last version not enough warm
# Sentiment(polarity=0.0975, subjectivity=0.43083333333333335)
# positive
#
# THE SENTENCE IS +ve
# 574
# ========================================================================
# Input sentence =  Which suitable travelling Hokkaido in March?
#
# Line: Which suitable travelling Hokkaido in March?
# Sentiment(polarity=0.55, subjectivity=0.75)
# positive
#
# THE SENTENCE IS +ve
# 575
# ========================================================================
# Input sentence =  Kenzo Nightwalker Tracy Chang Weng Hwa Ang can I buy this for rinjani?
#
# Line: Kenzo Nightwalker Tracy Chang Weng Hwa Ang can I buy this for rinjani?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3094
# ========================================================================
# Input sentence =  Next time heattech new product call "extreme ultra warm" 🤣
#
# Line: Next time heattech new product call "extreme ultra warm" 🤣
# Sentiment(polarity=0.15284090909090908, subjectivity=0.5136363636363637)
# positive
#
# THE SENTENCE IS +ve
# 576
# ========================================================================
# Input sentence =  Sulastri Yahya; heat tech by uniqlo
#
# Line: Sulastri Yahya; heat tech by uniqlo
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3095
# ========================================================================
# Input sentence =  Eifa Masdari long John.
#
# Line: Eifa Masdari long John.
# Sentiment(polarity=-0.05, subjectivity=0.4)
# Sentiment(polarity=-0.05, subjectivity=0.4)
# negative
#
# THE SENTENCE IS -ve
# 139
# ========================================================================
# Input sentence =  Nasrullah Zulkipli
#
# Line: Nasrullah Zulkipli
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3096
# ========================================================================
# Input sentence =  Christine Chann
#
# Line: Christine Chann
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3097
# ========================================================================
# Input sentence =  Ramizan Rusly Ayin Yahaya
#
# Line: Ramizan Rusly Ayin Yahaya
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3098
# ========================================================================
# Input sentence =  Sudah adaa
#
# Line: Sudah adaa
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3099
# ========================================================================
# Input sentence =  Beli untuk syg la sebab saya tadak lagi. 🙄
#
# Line: Beli untuk syg la sebab saya tadak lagi.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 🙄
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3100
# ========================================================================
# Input sentence =  jomm
#
# Line: jomm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3101
# ========================================================================
# Input sentence =  Eh Affan skali hehe
#
# Line: Eh Affan skali hehe
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3102
# ========================================================================
# Input sentence =  Jeremy Teh
#
# Line: Jeremy Teh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3103
# ========================================================================
# Input sentence =  Muhammad Sahrilsal 😂😂
#
# Line: Muhammad Sahrilsal 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3104
# ========================================================================
# Input sentence =  Beza rm3 je dgn jepon punya.. cannot tahan 😂😂
#
# Line: Beza rm3 je dgn jepon punya.. cannot tahan 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3105
# ========================================================================
# Input sentence =  Mata wang malaysia rendah..nk buat mcm mn..😂😂
#
# Line: Mata wang malaysia rendah..nk buat mcm mn..😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3106
# ========================================================================
# Input sentence =  Rozaidi Rodi
#
# Line: Rozaidi Rodi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3107
# ========================================================================
# Input sentence =  Jun Weng
#
# Line: Jun Weng
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3108
# ========================================================================
# Input sentence =  赵天
#
# Line: 赵天
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3109
# ========================================================================
# Input sentence =  Online shop and earn more!
#
# Line: Online shop and earn more!
# Sentiment(polarity=0.625, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 577
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3110
# ========================================================================
# Input sentence =  Only at http://mys.shop.com/sml66
#
# Line: Only at http://mys.shop.com/sml66
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3111
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3112
# ========================================================================
# Input sentence =  Partner Store - UNIQLO [[SHARE]]
#
# Line: Partner Store - UNIQLO [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3113
# ========================================================================
# Input sentence =  do e-special offer for supima cotton pls...hehehe
#
# Line: do e-special offer for supima cotton pls...hehehe
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3114
# ========================================================================
# Input sentence =  Winnie Teoh Tiang Suan Tioh 这里应该有颜色和size
#
# Line: Winnie Teoh Tiang Suan Tioh 这里应该有颜色和size
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3115
# ========================================================================
# Input sentence =  你是说冬衣吗
#
# Line: 你是说冬衣吗
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3116
# ========================================================================
# Input sentence =  对 ultra light
#
# Line: 对 ultra light
# Sentiment(polarity=0.4, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 578
# ========================================================================
# Input sentence =  Ooi Chai Hoon, Jia Ni, Jia Jie Cheah
#
# Line: Ooi Chai Hoon, Jia Ni, Jia Jie Cheah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3117
# ========================================================================
# Input sentence =  Chunkiat New Walter Lim Ming Wei
#
# Line: Chunkiat New Walter Lim Ming Wei
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# positive
#
# THE SENTENCE IS +ve
# 579
# ========================================================================
# Input sentence =  Tai Jia Yi
#
# Line: Tai Jia Yi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3118
# ========================================================================
# Input sentence =  Mancy Loo
#
# Line: Mancy Loo
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3119
# ========================================================================
# Input sentence =  Hui Sin
#
# Line: Hui Sin
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3120
# ========================================================================
# Input sentence =  The pink colour nice
#
# Line: The pink colour nice
# Sentiment(polarity=0.25, subjectivity=0.65)
# positive
#
# THE SENTENCE IS +ve
# 580
# ========================================================================
# Input sentence =  Can buy online want ma?
#
# Line: Can buy online want ma?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3121
# ========================================================================
# Input sentence =  Li Tzer
#
# Line: Li Tzer
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3122
# ========================================================================
# Input sentence =  Joey Cheong 好像很好穿
#
# Line: Joey Cheong 好像很好穿
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3123
# ========================================================================
# Input sentence =  Tony Lim
#
# Line: Tony Lim
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3124
# ========================================================================
# Input sentence =  Asrul Bolt
#
# Line: Asrul Bolt
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3125
# ========================================================================
# Input sentence =  ba weekend?
#
# Line: ba weekend?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3126
# ========================================================================
# Input sentence =  Asrul Bolt nnt atur
#
# Line: Asrul Bolt nnt atur
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3127
# ========================================================================
# Input sentence =  Nurul Syahiena
#
# Line: Nurul Syahiena
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3128
# ========================================================================
# Input sentence =  Adeline Hah
#
# Line: Adeline Hah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3129
# ========================================================================
# Input sentence =  CiKk FiNn
#
# Line: CiKk FiNn
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3130
# ========================================================================
# Input sentence =  LoveCat Connie
#
# Line: LoveCat Connie
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3131
# ========================================================================
# Input sentence =  Momo Summer
#
# Line: Momo Summer
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3132
# ========================================================================
# Sentence Polarity Negative =  139
# Sentence Polarity Neutral =  3133
# Sentence Polarity Positive =  580

# %%
# WordCloud for Uniqlo Comment
from os import path
from wordcloud import WordCloud
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
convert_wordcloud = 'UniqloComment.txt'

# Read the whole text.
text = open(convert_wordcloud,encoding ="UTF-8").read()

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:

stop_Words = stopwords.words('english') + ['please','ni','la','tu','uniqlo','lee','lim','ahmad','wong','tan','hahaha','haha','amir','go','beli']
wordcloud = WordCloud(stopwords=stop_Words,
                      background_color='black',
                      width=1800,
                      height=1400).generate(text.lower())
plt.title("Uniqlo Comment WordCloud")
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig('UniqloCommentWordCloud.png', dpi=1000)
plt.show()

# %%
# Sentiment Analysis For WordCloud (Uniqlo)
import matplotlib.pyplot as plt
from textblob import TextBlob
if __name__ == "__main__":
    
    Sentence_polarity_pos =0
    Sentence_polarity_neutral = 0
    Sentence_polarity_neg = 0
    

    inputfile = open("UniqloComment.txt", "r",encoding = "UTF-8")
    outputfile = open("SentimentUniqlo.txt", "w",encoding = "UTF-8")


    for line in inputfile:
        try:
            
            Count_neg=0
            Count_neutral=0
            Count_pos=0
            
            #print(line)
            line = TextBlob(line)
           
            print ("Input sentence = ", line.strip() + "\n")
            
            for each_line in line.sentences:
                print("Line: " + str(each_line))
                print(each_line.sentiment)
                outputfile.write(str(each_line)+"+"+";")

                if each_line.sentiment.polarity < 0.0:
                    print(each_line.sentiment)
                    print ("negative" + "\n")
                    outputfile.write ("negative\n")
                    Count_neg +=1
                elif each_line.sentiment.polarity == 0:
                    print ("neutral" + "\n")
                    outputfile.write ("neutral\n")
                    Count_neutral +=1
                else:
                    print ("positive" + "\n")
                    outputfile.write ("positive\n")
                    Count_pos +=1

                    
            if Count_pos > Count_neg: 
                print ("THE SENTENCE IS +ve")
                Sentence_polarity_pos += 1
                print (Sentence_polarity_pos)

            elif (Count_pos == Count_neg):  
                print ("THE SENTENCE IS NEUTRAL")
                print (Sentence_polarity_neutral)
                Sentence_polarity_neutral += 1

            else:
                print ("THE SENTENCE IS -ve") 
                Sentence_polarity_neg += 1
                print (Sentence_polarity_neg)
           
            print("========================================================================")
        except:
            continue

    print ("Sentence Polarity Negative = ",Sentence_polarity_neg )
    print ("Sentence Polarity Neutral = ",Sentence_polarity_neutral )
    print ("Sentence Polarity Positive = ",Sentence_polarity_pos )
    Polarity = [1,3]
    LABELS = ["Positive", "Negative"]
    Count_polarity = [Sentence_polarity_pos, Sentence_polarity_neg]

    plt.xlabel('Polarity')
    plt.ylabel('Count')
    plt.title('Uniqlo Sentiment Analysis')

    plt.grid(True)
    plt.bar(Polarity, Count_polarity, align='center')
    plt.xticks(Polarity, LABELS)
    plt.savefig('UniqloSentiment.png', dpi=1000)
    plt.show()
    
outputfile.close()
# Out:
# Input sentence =  comment_message
#
# Line: comment_message
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 0
# ========================================================================
# Input sentence =  Let's go together n buy. I'm a fan of uniqlo hahaha....every entry will grab one
#
# Line: Let's go together n buy.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I'm a fan of uniqlo hahaha....every entry will grab one
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 1
# ========================================================================
# Input sentence =  Atiqah Ismail
#
# Line: Atiqah Ismail
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 2
# ========================================================================
# Input sentence =  I open my purse i cry
#
# Line: I open my purse i cry
# Sentiment(polarity=0.0, subjectivity=0.5)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3
# ========================================================================
# Input sentence =  Do you have any white shirts that wont show my nipple :O
#
# Line: Do you have any white shirts that wont show my nipple :O
# Sentiment(polarity=0.025, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 1
# ========================================================================
# Input sentence =  Try turning off the aircond
#
# Line: Try turning off the aircond
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 4
# ========================================================================
# Input sentence =  Radzli Rahman u mean turning on ? hahaha
#
# Line: Radzli Rahman u mean turning on ?
# Sentiment(polarity=-0.3125, subjectivity=0.6875)
# Sentiment(polarity=-0.3125, subjectivity=0.6875)
# negative
#
# Line: hahaha
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS NEUTRAL
# 5
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 6
# ========================================================================
# Input sentence =  alot white shirts i have no idea why it look so thin that will show nipples. like opacity 70% thou
#
# Line: alot white shirts i have no idea why it look so thin that will show nipples.
# Sentiment(polarity=-0.2, subjectivity=0.42500000000000004)
# Sentiment(polarity=-0.2, subjectivity=0.42500000000000004)
# negative
#
# Line: like opacity 70% thou
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS -ve
# 1
# ========================================================================
# Input sentence =  No choice ah bro, wear inner
#
# Line: No choice ah bro, wear inner
# Sentiment(polarity=0.0, subjectivity=0.16666666666666666)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 7
# ========================================================================
# Input sentence =  Ryan E Liang wear inner gonna be too hot + extra detergent leh haha just saying.
#
# Line: Ryan E Liang wear inner gonna be too hot + extra detergent leh haha just saying.
# Sentiment(polarity=0.1125, subjectivity=0.35416666666666674)
# positive
#
# THE SENTENCE IS +ve
# 2
# ========================================================================
# Input sentence =  Azra Izzatie
#
# Line: Azra Izzatie
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 8
# ========================================================================
# Input sentence =  Eugene Tan
#
# Line: Eugene Tan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 9
# ========================================================================
# Input sentence =  If you turn on aircond (cold), your nipple will become erect/firm. It will highlight your nips even more 😂
#
# Line: If you turn on aircond (cold), your nipple will become erect/firm.
# Sentiment(polarity=-0.6, subjectivity=1.0)
# Sentiment(polarity=-0.6, subjectivity=1.0)
# negative
#
# Line: It will highlight your nips even more 😂
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS NEUTRAL
# 10
# ========================================================================
# Input sentence =  Radzli Rahman hahaha i tot its because of the weather in Malaysia that makes me sweat which causes my shirt to turn visible. hahahaha
#
# Line: Radzli Rahman hahaha i tot its because of the weather in Malaysia that makes me sweat which causes my shirt to turn visible.
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# Line: hahahaha
# Sentiment(polarity=0.2, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 3
# ========================================================================
# Input sentence =  Chen Yong Bryan Jian Feng Albert Liow Chien Her
#
# Line: Chen Yong Bryan Jian Feng Albert Liow Chien Her
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 11
# ========================================================================
# Input sentence =  U should wear bra...its proven.. by women
#
# Line: U should wear bra...its proven.. by women
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 12
# ========================================================================
# Input sentence =  Azrul Best yea. and the shape of the bra can be seen.
#
# Line: Azrul Best yea.
# Sentiment(polarity=1.0, subjectivity=0.3)
# positive
#
# Line: and the shape of the bra can be seen.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 4
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 13
# ========================================================================
# Input sentence =  #eyecandy
#
# Line: #eyecandy
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 14
# ========================================================================
# Input sentence =  Use nipple tape
#
# Line: Use nipple tape
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 15
# ========================================================================
# Input sentence =  Shawn Yong  wear white airism.
#
# Line: Shawn Yong  wear white airism.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 16
# ========================================================================
# Input sentence =  Maybe the ladies / guys in ur office turn you on?
#
# Line: Maybe the ladies / guys in ur office turn you on?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 17
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 18
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 19
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 20
# ========================================================================
# Input sentence =  I'm not judging
#
# Line: I'm not judging
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 21
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 22
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 23
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 24
# ========================================================================
# Input sentence =  😂😂🤣🤣
#
# Line: 😂😂🤣🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 25
# ========================================================================
# Input sentence =  Jimmg Chng nope. I turned myself on.
#
# Line: Jimmg Chng nope.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I turned myself on.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 26
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 27
# ========================================================================
# Input sentence =  Im too HAWT! dayum hahaha
#
# Line: Im too HAWT!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: dayum hahaha
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 5
# ========================================================================
# Input sentence =  workout bro
#
# Line: workout bro
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 28
# ========================================================================
# Input sentence =  Darren Ong i'm gonna get loads of these for you. hmmmm....when are they doing this for school uniforms? 😂
#
# Line: Darren Ong i'm gonna get loads of these for you.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: hmmmm....when are they doing this for school uniforms?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 29
# ========================================================================
# Input sentence =  Do you have super non-iron shirt for lady?
#
# Line: Do you have super non-iron shirt for lady?
# Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# positive
#
# THE SENTENCE IS +ve
# 6
# ========================================================================
# Input sentence =  Do you make non-iron women’s shirts?
#
# Line: Do you make non-iron women’s shirts?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 30
# ========================================================================
# Input sentence =  I air dried it but still have to iron
#
# Line: I air dried it but still have to iron
# Sentiment(polarity=-0.2, subjectivity=0.6)
# Sentiment(polarity=-0.2, subjectivity=0.6)
# negative
#
# THE SENTENCE IS -ve
# 2
# ========================================================================
# Input sentence =  Hi, u meant this Uniqlo one?  I'm skeptical
#
# Line: Hi, u meant this Uniqlo one?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I'm skeptical
# Sentiment(polarity=-0.5, subjectivity=0.5)
# Sentiment(polarity=-0.5, subjectivity=0.5)
# negative
#
# THE SENTENCE IS -ve
# 3
# ========================================================================
# Input sentence =  Chris Lim Leong Fah yes. My husband has but still need to iron
#
# Line: Chris Lim Leong Fah yes.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: My husband has but still need to iron
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 31
# ========================================================================
# Input sentence =  Same. Still need to iron. No different from other brand work shirt.
#
# Line: Same.
# Sentiment(polarity=0.0, subjectivity=0.125)
# neutral
#
# Line: Still need to iron.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: No different from other brand work shirt.
# Sentiment(polarity=-0.0625, subjectivity=0.4875)
# Sentiment(polarity=-0.0625, subjectivity=0.4875)
# negative
#
# THE SENTENCE IS -ve
# 4
# ========================================================================
# Input sentence =  If you guys see in the first ads the shirt still wrinkle when he wear from the washing machine 😂
#
# Line: If you guys see in the first ads the shirt still wrinkle when he wear from the washing machine 😂
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# positive
#
# THE SENTENCE IS +ve
# 7
# ========================================================================
# Input sentence =  Iman Nadieya Hassan org ni ckp still kene iron. Dahh, review dah confirmkn jgn nk mengada bazir duit pi beli..
#
# Line: Iman Nadieya Hassan org ni ckp still kene iron.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Dahh, review dah confirmkn jgn nk mengada bazir duit pi beli..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 32
# ========================================================================
# Input sentence =  Jessie Lim gonna get one and try xD I’ll crumple and see 😂
#
# Line: Jessie Lim gonna get one and try xD I’ll crumple and see 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 33
# ========================================================================
# Input sentence =  wah o.o so cool de the advertisement
#
# Line: wah o.o so cool de the advertisement
# Sentiment(polarity=0.19999999999999998, subjectivity=0.825)
# positive
#
# THE SENTENCE IS +ve
# 8
# ========================================================================
# Input sentence =  I bought this non iron shirt but still have to iron. Nonsense
#
# Line: I bought this non iron shirt but still have to iron.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Nonsense
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 34
# ========================================================================
# Input sentence =  This is what I always wanted. Hehehe. Sure will visit uniqlo soon.
#
# Line: This is what I always wanted.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Hehehe.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Sure will visit uniqlo soon.
# Sentiment(polarity=0.5, subjectivity=0.8888888888888888)
# positive
#
# THE SENTENCE IS +ve
# 9
# ========================================================================
# Input sentence =  Kenny Li can you like go back to melbs and get me 5 of these kthxbye
#
# Line: Kenny Li can you like go back to melbs and get me 5 of these kthxbye
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 35
# ========================================================================
# Input sentence =  HAHAHA
#
# Line: HAHAHA
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 10
# ========================================================================
# Input sentence =  Maybe :)
#
# Line: Maybe :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 11
# ========================================================================
# Input sentence =  Joel  I think we need to change your whole wardrobe to this! 😂
#
# Line: Joel  I think we need to change your whole wardrobe to this!
# Sentiment(polarity=0.25, subjectivity=0.4)
# positive
#
# Line: 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 12
# ========================================================================
# Input sentence =  When will have bigger size for man? Wish to buy for my husband.
#
# Line: When will have bigger size for man?
# Sentiment(polarity=0.0, subjectivity=0.5)
# neutral
#
# Line: Wish to buy for my husband.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 36
# ========================================================================
# Input sentence =  Joyce Kan you can buy for me if you don't want to ironing anymore.
#
# Line: Joyce Kan you can buy for me if you don't want to ironing anymore.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 37
# ========================================================================
# Input sentence =  You should think of sayang your wife, change all to this by yourself!
#
# Line: You should think of sayang your wife, change all to this by yourself!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 38
# ========================================================================
# Input sentence =  tagging all husband Yong David
#
# Line: tagging all husband Yong David
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 39
# ========================================================================
# Input sentence =  Evangeline Lau i think this is so for me who lazy to iron hahahhahhahahaha
#
# Line: Evangeline Lau i think this is so for me who lazy to iron hahahhahhahahaha
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 5
# ========================================================================
# Input sentence =  Nobody likes iron baju la😂
#
# Line: Nobody likes iron baju la😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 40
# ========================================================================
# Input sentence =  But i hv to wear compny uniform..ermm
#
# Line: But i hv to wear compny uniform..ermm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 41
# ========================================================================
# Input sentence =  Jien Wai Lim can buy this one Liao!
#
# Line: Jien Wai Lim can buy this one Liao!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 42
# ========================================================================
# Input sentence =  I had non iron cloth from other brand. It is soft type or
#
# Line: I had non iron cloth from other brand.
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Sentiment(polarity=-0.125, subjectivity=0.375)
# negative
#
# Line: It is soft type or
# Sentiment(polarity=0.1, subjectivity=0.35)
# positive
#
# THE SENTENCE IS NEUTRAL
# 43
# ========================================================================
# Input sentence =  Marius no antimicrobes tho
#
# Line: Marius no antimicrobes tho
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 44
# ========================================================================
# Input sentence =  It's just not good enough then😂
#
# Line: It's just not good enough then😂
# Sentiment(polarity=-0.175, subjectivity=0.55)
# Sentiment(polarity=-0.175, subjectivity=0.55)
# negative
#
# THE SENTENCE IS -ve
# 6
# ========================================================================
# Input sentence =  Uniqlo Malaysia depending on what washing conditions? Can explain in detail?
#
# Line: Uniqlo Malaysia depending on what washing conditions?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Can explain in detail?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 45
# ========================================================================
# Input sentence =  Kelvin Tayu need this lazy nong hahaha
#
# Line: Kelvin Tayu need this lazy nong hahaha
# Sentiment(polarity=-0.024999999999999994, subjectivity=0.7)
# Sentiment(polarity=-0.024999999999999994, subjectivity=0.7)
# negative
#
# THE SENTENCE IS -ve
# 7
# ========================================================================
# Input sentence =  Buy pls
#
# Line: Buy pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 46
# ========================================================================
# Input sentence =  Yi Lin Ong, in future, throw away your iron.
#
# Line: Yi Lin Ong, in future, throw away your iron.
# Sentiment(polarity=0.0, subjectivity=0.125)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 47
# ========================================================================
# Input sentence =  Lo Chang Yong your fav brand but it's preventing from doing your fav thing. 😂
#
# Line: Lo Chang Yong your fav brand but it's preventing from doing your fav thing.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 48
# ========================================================================
# Input sentence =  yeah . so sad :(
#
# Line: yeah .
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: so sad :(
# Sentiment(polarity=-0.625, subjectivity=1.0)
# Sentiment(polarity=-0.625, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 8
# ========================================================================
# Input sentence =  Farah Aisyah my dream clothes. How about scarfs?? Take my money!! Tapi harga duck! Tapi no need to iron!!!!!!! 😭
#
# Line: Farah Aisyah my dream clothes.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: How about scarfs??
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Take my money!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Tapi harga duck!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Tapi no need to iron!!!!!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😭
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 49
# ========================================================================
# Input sentence =  Beli sehelai utk pki waktu terdesak lmbt gi kerja hahah
#
# Line: Beli sehelai utk pki waktu terdesak lmbt gi kerja hahah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 50
# ========================================================================
# Input sentence =  Mine Ascmmy kalau sy beli yang ni, rugi pula tak pakai iron baru awak tuuu haha😂🤣
#
# Line: Mine Ascmmy kalau sy beli yang ni, rugi pula tak pakai iron baru awak tuuu haha😂🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 51
# ========================================================================
# Input sentence =  alaaaa ye dok uniqlo ni hahahahh
#
# Line: alaaaa ye dok uniqlo ni hahahahh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 52
# ========================================================================
# Input sentence =  Tan Ching Pei no need iron shirt Liao yes
#
# Line: Tan Ching Pei no need iron shirt Liao yes
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 53
# ========================================================================
# Input sentence =  Can you produce more Regular fit office shirts? Too many Slim fits available...
#
# Line: Can you produce more Regular fit office shirts?
# Sentiment(polarity=0.3, subjectivity=0.32564102564102565)
# positive
#
# Line: Too many Slim fits available...
# Sentiment(polarity=0.45, subjectivity=0.45)
# positive
#
# THE SENTENCE IS +ve
# 13
# ========================================================================
# Input sentence =  Chong Hr your dream come true 😂
#
# Line: Chong Hr your dream come true 😂
# Sentiment(polarity=0.35, subjectivity=0.65)
# positive
#
# THE SENTENCE IS +ve
# 14
# ========================================================================
# Input sentence =  Wong C. Kok u shd invest into this!
#
# Line: Wong C. Kok u shd invest into this!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 54
# ========================================================================
# Input sentence =  Choong Koi Ling u can ask ur husband invest liao
#
# Line: Choong Koi Ling u can ask ur husband invest liao
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 55
# ========================================================================
# Input sentence =  Yaya... I saw this too... checked the price liao
#
# Line: Yaya...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I saw this too... checked the price liao
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 56
# ========================================================================
# Input sentence =  But still ask him to iron himself 😬😬
#
# Line: But still ask him to iron himself 😬😬
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 57
# ========================================================================
# Input sentence =  Jireh Ho Jia Jun this is customized for u!
#
# Line: Jireh Ho Jia Jun this is customized for u!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 58
# ========================================================================
# Input sentence =  Hazman Hasim get this more baby!
#
# Line: Hazman Hasim get this more baby!
# Sentiment(polarity=0.625, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 15
# ========================================================================
# Input sentence =  Diana Dee wonder if they have my size!
#
# Line: Diana Dee wonder if they have my size!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 59
# ========================================================================
# Input sentence =  Rodrigo Arturo You need to buy this 😊
#
# Line: Rodrigo Arturo You need to buy this 😊
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 60
# ========================================================================
# Input sentence =  I definitely do :(
#
# Line: I definitely do :(
# Sentiment(polarity=-0.375, subjectivity=0.75)
# Sentiment(polarity=-0.375, subjectivity=0.75)
# negative
#
# THE SENTENCE IS -ve
# 9
# ========================================================================
# Input sentence =  Alicia Lok can help me buy all available colours?
#
# Line: Alicia Lok can help me buy all available colours?
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 16
# ========================================================================
# Input sentence =  Han Neo you need this so badly.
#
# Line: Han Neo you need this so badly.
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)
# negative
#
# THE SENTENCE IS -ve
# 10
# ========================================================================
# Input sentence =  Zhang Phong Ooi Eugene Tan don’t need to spend 500 years ironing your shirt before clubbing anymore
#
# Line: Zhang Phong Ooi Eugene Tan don’t need to spend 500 years ironing your shirt before clubbing anymore
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 61
# ========================================================================
# Input sentence =  Ryan Chan you forgot about him
#
# Line: Ryan Chan you forgot about him
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 62
# ========================================================================
# Input sentence =  Wen Kaii Lim the video concept i was talking about
#
# Line: Wen Kaii Lim the video concept i was talking about
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 63
# ========================================================================
# Input sentence =  Muhammad Azreeq g beli kat uniqlo..sesuai utk kau..hahah
#
# Line: Muhammad Azreeq g beli kat uniqlo..sesuai utk kau..hahah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 64
# ========================================================================
# Input sentence =  Esther How time to get these instead of g2000
#
# Line: Esther How time to get these instead of g2000
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 65
# ========================================================================
# Input sentence =  Omg specially made for you !!! Sarah Chang
#
# Line: Omg specially made for you !!!
# Sentiment(polarity=0.6975446428571429, subjectivity=0.5714285714285714)
# positive
#
# Line: Sarah Chang
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 17
# ========================================================================
# Input sentence =  But they only have men’s shirt!!! So unfair
#
# Line: But they only have men’s shirt!!!
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: So unfair
# Sentiment(polarity=-0.5, subjectivity=1.0)
# Sentiment(polarity=-0.5, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 11
# ========================================================================
# Input sentence =  Sarah Chang sure got ladies must go see
#
# Line: Sarah Chang sure got ladies must go see
# Sentiment(polarity=0.5, subjectivity=0.8888888888888888)
# positive
#
# THE SENTENCE IS +ve
# 18
# ========================================================================
# Input sentence =  Anna Liang Christopher Lee- no need to drive to the dry cleaners lol
#
# Line: Anna Liang Christopher Lee- no need to drive to the dry cleaners lol
# Sentiment(polarity=0.3666666666666667, subjectivity=0.6499999999999999)
# positive
#
# THE SENTENCE IS +ve
# 19
# ========================================================================
# Input sentence =  Prema Ra can buy for Paul
#
# Line: Prema Ra can buy for Paul
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 66
# ========================================================================
# Input sentence =  Ameenur Rashid Selamat wujud lah kemeja xyah iron.. kau bleh beli..
#
# Line: Ameenur Rashid Selamat wujud lah kemeja xyah iron.. kau bleh beli..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 67
# ========================================================================
# Input sentence =  Mell Ejah 😍😍 no need to iron.
#
# Line: Mell Ejah 😍😍 no need to iron.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 68
# ========================================================================
# Input sentence =  pmpuan punya tda ka?😄😄
#
# Line: pmpuan punya tda ka?😄😄
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 69
# ========================================================================
# Input sentence =  Coming soon 🙊
#
# Line: Coming soon 🙊
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 70
# ========================================================================
# Input sentence =  Terrance Tan pls buy shirt from uniqlo
#
# Line: Terrance Tan pls buy shirt from uniqlo
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 71
# ========================================================================
# Input sentence =  Pls buy for me 😘
#
# Line: Pls buy for me 😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 72
# ========================================================================
# Input sentence =  Wai Fung Tsui have you bought this that day 😂
#
# Line: Wai Fung Tsui have you bought this that day 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 73
# ========================================================================
# Input sentence =  why he acting bust on the right hand side?🤔
#
# Line: why he acting bust on the right hand side?🤔
# Sentiment(polarity=0.14285714285714285, subjectivity=0.26785714285714285)
# positive
#
# THE SENTENCE IS +ve
# 20
# ========================================================================
# Input sentence =  busy*
#
# Line: busy*
# Sentiment(polarity=0.1, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 21
# ========================================================================
# Input sentence =  TungLiang Tan suitable for u. Go buy go buy
#
# Line: TungLiang Tan suitable for u.
# Sentiment(polarity=0.55, subjectivity=0.75)
# positive
#
# Line: Go buy go buy
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 22
# ========================================================================
# Input sentence =  Faliq Murad you need this in all colors.
#
# Line: Faliq Murad you need this in all colors.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 74
# ========================================================================
# Input sentence =  Ruby Lee something for me lol
#
# Line: Ruby Lee something for me lol
# Sentiment(polarity=0.8, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 23
# ========================================================================
# Input sentence =  Meant for lazy people. Lol
#
# Line: Meant for lazy people.
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# negative
#
# Line: Lol
# Sentiment(polarity=0.8, subjectivity=0.7)
# positive
#
# THE SENTENCE IS NEUTRAL
# 75
# ========================================================================
# Input sentence =  Ruby Lee innovation ok
#
# Line: Ruby Lee innovation ok
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 24
# ========================================================================
# Input sentence =  Cheah Qian Yi maybe he bought this kind of shirts that's why his shirt looks neat all the time hahha
#
# Line: Cheah Qian Yi maybe he bought this kind of shirts that's why his shirt looks neat all the time hahha
# Sentiment(polarity=0.6, subjectivity=0.9)
# positive
#
# THE SENTENCE IS +ve
# 25
# ========================================================================
# Input sentence =  Hahahahahaha omg sohai 😂😂 you should too 😏😏
#
# Line: Hahahahahaha omg sohai 😂😂 you should too 😏😏
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 76
# ========================================================================
# Input sentence =  Anna Radzihan..buy this for my brother..😀😀😀
#
# Line: Anna Radzihan..buy this for my brother..😀😀😀
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 77
# ========================================================================
# Input sentence =  Dinie Mohamed non iron shirt.. weehooo..
#
# Line: Dinie Mohamed non iron shirt.. weehooo..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 78
# ========================================================================
# Input sentence =  Melvin Chong please buy more of this
#
# Line: Melvin Chong please buy more of this
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 26
# ========================================================================
# Input sentence =  Have to be comfortable also
#
# Line: Have to be comfortable also
# Sentiment(polarity=0.4, subjectivity=0.8)
# positive
#
# THE SENTENCE IS +ve
# 27
# ========================================================================
# Input sentence =  Keyth Ng u should buy 😏
#
# Line: Keyth Ng u should buy 😏
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 79
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 80
# ========================================================================
# Input sentence =  Sarrah Yusof Adilah Wafaa nah hampa xrajin nak iron baju kan😌😌😌
#
# Line: Sarrah Yusof Adilah Wafaa nah hampa xrajin nak iron baju kan😌😌😌
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 81
# ========================================================================
# Input sentence =  Melissa Ong I’m gonna buy 10 of this shirt
#
# Line: Melissa Ong I’m gonna buy 10 of this shirt
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 82
# ========================================================================
# Input sentence =  I just bought one actually 😂😂 the old one la rayon shirt
#
# Line: I just bought one actually 😂😂 the old one la rayon shirt
# Sentiment(polarity=0.05, subjectivity=0.15000000000000002)
# positive
#
# THE SENTENCE IS +ve
# 28
# ========================================================================
# Input sentence =  Melissa Ong is it as good as they say?
#
# Line: Melissa Ong is it as good as they say?
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
#
# THE SENTENCE IS +ve
# 29
# ========================================================================
# Input sentence =  Yes! It’s super comfy I slept in it on the plane
#
# Line: Yes!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: It’s super comfy I slept in it on the plane
# Sentiment(polarity=0.3333333333333333, subjectivity=0.6666666666666666)
# positive
#
# THE SENTENCE IS +ve
# 30
# ========================================================================
# Input sentence =  Please, let’s buy this 😁 Aidi Affendi
#
# Line: Please, let’s buy this 😁 Aidi Affendi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 83
# ========================================================================
# Input sentence =  Lawrence Leong You need to get this ;)
#
# Line: Lawrence Leong You need to get this ;)
# Sentiment(polarity=0.25, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 31
# ========================================================================
# Input sentence =  Yasmin Jamian Syahida Amo kasi beli sy satu. Nda payah iron punya
#
# Line: Yasmin Jamian Syahida Amo kasi beli sy satu.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Nda payah iron punya
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 84
# ========================================================================
# Input sentence =  X payah jess. kta iron syiak bju hari2 k
#
# Line: X payah jess.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: kta iron syiak bju hari2 k
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 85
# ========================================================================
# Input sentence =  Berapa latus la niii
#
# Line: Berapa latus la niii
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 86
# ========================================================================
# Input sentence =  Murah ja tu 😂😂
#
# Line: Murah ja tu 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 87
# ========================================================================
# Input sentence =  Li Ping Ooi they heard me!!!
#
# Line: Li Ping Ooi they heard me!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 88
# ========================================================================
# Input sentence =  Can buy 7 pieces. Forever wear them hahaha
#
# Line: Can buy 7 pieces.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Forever wear them hahaha
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 32
# ========================================================================
# Input sentence =  😩the price
#
# Line: 😩the price
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 89
# ========================================================================
# Input sentence =  Anything for the ladies? Non iron? Hihi
#
# Line: Anything for the ladies?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Non iron?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Hihi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 90
# ========================================================================
# Input sentence =  Joey Khong you will be kedut no longer!
#
# Line: Joey Khong you will be kedut no longer!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 91
# ========================================================================
# Input sentence =  Noiceeee! 😁
#
# Line: Noiceeee!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😁
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 92
# ========================================================================
# Input sentence =  Uniqlo; how to buy online
#
# Line: Uniqlo; how to buy online
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 93
# ========================================================================
# Input sentence =  None for the ladies?
#
# Line: None for the ladies?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 94
# ========================================================================
# Input sentence =  Siti sarah Aida Suhaimi kalo ada women's shirt bleh beli ni
#
# Line: Siti sarah Aida Suhaimi kalo ada women's shirt bleh beli ni
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 95
# ========================================================================
# Input sentence =  Senang kannn
#
# Line: Senang kannn
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 96
# ========================================================================
# Input sentence =  Klaus Cheok this very good leh
#
# Line: Klaus Cheok this very good leh
# Sentiment(polarity=0.9099999999999999, subjectivity=0.7800000000000001)
# positive
#
# THE SENTENCE IS +ve
# 33
# ========================================================================
# Input sentence =  Really? Later go have a look
#
# Line: Really?
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# Line: Later go have a look
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 34
# ========================================================================
# Input sentence =  No need iron leh..somemore not really expensive pun
#
# Line: No need iron leh..somemore not really expensive pun
# Sentiment(polarity=0.25, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 35
# ========================================================================
# Input sentence =  Haha, very nice 👍🏻
#
# Line: Haha, very nice 👍🏻
# Sentiment(polarity=0.49, subjectivity=0.65)
# positive
#
# THE SENTENCE IS +ve
# 36
# ========================================================================
# Input sentence =  Izzat Syahmi Yusni beli hop ni la pg2 x yoh gosok baju dh
#
# Line: Izzat Syahmi Yusni beli hop ni la pg2 x yoh gosok baju dh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 97
# ========================================================================
# Input sentence =  Second intake
#
# Line: Second intake
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 98
# ========================================================================
# Input sentence =  威翰, good
#
# Line: 威翰, good
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
#
# THE SENTENCE IS +ve
# 37
# ========================================================================
# Input sentence =  Fuyooooooo ni best ni 🤣 Fh Mohammad Faiz
#
# Line: Fuyooooooo ni best ni 🤣 Fh Mohammad Faiz
# Sentiment(polarity=1.0, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 38
# ========================================================================
# Input sentence =  ta best tade side
#
# Line: ta best tade side
# Sentiment(polarity=1.0, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 39
# ========================================================================
# Input sentence =  K 😑
#
# Line: K 😑
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 99
# ========================================================================
# Input sentence =  Chris Rjn check it out ok
#
# Line: Chris Rjn check it out ok
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 40
# ========================================================================
# Input sentence =  Ryan Eng Kah Jie im gonna get this for u
#
# Line: Ryan Eng Kah Jie im gonna get this for u
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 100
# ========================================================================
# Input sentence =  Roziah Abu tgk ni...macam boleh beli ni...
#
# Line: Roziah Abu tgk ni...macam boleh beli ni...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 101
# ========================================================================
# Input sentence =  Sy sokong kenyataan di atas...
#
# Line: Sy sokong kenyataan di atas...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 102
# ========================================================================
# Input sentence =  Jom kamal...hahaha
#
# Line: Jom kamal...hahaha
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 103
# ========================================================================
# Input sentence =  Aha jommm
#
# Line: Aha jommm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 104
# ========================================================================
# Input sentence =  Angeline Lai mom gonna love these shirts.
#
# Line: Angeline Lai mom gonna love these shirts.
# Sentiment(polarity=0.5, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 41
# ========================================================================
# Input sentence =  Izzul Haziq you should try this
#
# Line: Izzul Haziq you should try this
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 105
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 106
# ========================================================================
# Input sentence =  One dozen please ...
#
# Line: One dozen please ...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 107
# ========================================================================
# Input sentence =  Pui-Ching Yong saves you from ironing
#
# Line: Pui-Ching Yong saves you from ironing
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 108
# ========================================================================
# Input sentence =  Unikuro
#
# Line: Unikuro
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 109
# ========================================================================
# Input sentence =  应该做校裙的😂😂😂 钟宛妤 then no need to iron it haizzz
#
# Line: 应该做校裙的😂😂😂 钟宛妤 then no need to iron it haizzz
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 110
# ========================================================================
# Input sentence =  真好😂😂😂
#
# Line: 真好😂😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 111
# ========================================================================
# Input sentence =  如果我们住一起就买一个😂😂😂😂
#
# Line: 如果我们住一起就买一个😂😂😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 112
# ========================================================================
# Input sentence =  钟宛妤 ok hahahhaha😂😂😂😂😂
#
# Line: 钟宛妤 ok hahahhaha😂😂😂😂😂
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 42
# ========================================================================
# Input sentence =  Nice..cma hrga je..
#
# Line: Nice..cma hrga je..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 113
# ========================================================================
# Input sentence =  Abg Amir Syafiq lps nie beli baju kije nie byk2...syg xyh gsok dh... 😂😂😂
#
# Line: Abg Amir Syafiq lps nie beli baju kije nie byk2...syg xyh gsok dh... 😂😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 114
# ========================================================================
# Input sentence =  Uniqlo always make a good product ! :D
#
# Line: Uniqlo always make a good product !
# Sentiment(polarity=0.875, subjectivity=0.6000000000000001)
# positive
#
# Line: :D
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 43
# ========================================================================
# Input sentence =  Aku suka dengan baju Uniqlo setiap baju dia bila pakai selesa
#
# Line: Aku suka dengan baju Uniqlo setiap baju dia bila pakai selesa
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 115
# ========================================================================
# Input sentence =  Wahhhh😍
#
# Line: Wahhhh😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 116
# ========================================================================
# Input sentence =  Baju tu takde unsur iron betul la tu
#
# Line: Baju tu takde unsur iron betul la tu
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 117
# ========================================================================
# Input sentence =  Jun Chew
#
# Line: Jun Chew
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 118
# ========================================================================
# Input sentence =  Jom
#
# Line: Jom
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 119
# ========================================================================
# Input sentence =  Mau takmau qatuih jgk nii
#
# Line: Mau takmau qatuih jgk nii
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 120
# ========================================================================
# Input sentence =  Settle masalah
#
# Line: Settle masalah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 121
# ========================================================================
# Input sentence =  Seriously ?!
#
# Line: Seriously ?
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.6666666666666666)
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.6666666666666666)
# negative
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS -ve
# 12
# ========================================================================
# Input sentence =  I needed this!
#
# ...
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3080
# ========================================================================
# Input sentence =  Akmal Azman kepala bapak harga cm tu eh 😂
#
# Line: Akmal Azman kepala bapak harga cm tu eh 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3081
# ========================================================================
# Input sentence =  John Louis Monteza Fernandez
#
# Line: John Louis Monteza Fernandez
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3082
# ========================================================================
# Input sentence =  John Louis Monteza Fernandez
#
# Line: John Louis Monteza Fernandez
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3083
# ========================================================================
# Input sentence =  Nabila Arijja
#
# Line: Nabila Arijja
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3084
# ========================================================================
# Input sentence =  Abby Teoh
#
# Line: Abby Teoh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3085
# ========================================================================
# Input sentence =  Hafizul Azren
#
# Line: Hafizul Azren
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3086
# ========================================================================
# Input sentence =  Zunaiddie Didi
#
# Line: Zunaiddie Didi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3087
# ========================================================================
# Input sentence =  吴玉萍
#
# Line: 吴玉萍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3088
# ========================================================================
# Input sentence =  I m from sg. Can i order online and collect at JB outlet?
#
# Line: I m from sg.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Can i order online and collect at JB outlet?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3089
# ========================================================================
# Input sentence =  Hi Christy Tay, yes you can. Check out our Click and Collect option here: http://www.uniqlo.com/my/clickandcollect/
#
# Line: Hi Christy Tay, yes you can.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Check out our Click and Collect option here: http://www.uniqlo.com/my/clickandcollect/
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3090
# ========================================================================
# Input sentence =  the outlet is all in KL? how to select the one in JB
#
# Line: the outlet is all in KL?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: how to select the one in JB
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3091
# ========================================================================
# Input sentence =  the click and collect is it available at johor? can't find any selection
#
# Line: the click and collect is it available at johor?
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# Line: can't find any selection
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 573
# ========================================================================
# Input sentence =  Hi Christy Tay, the click and collect stores are only in the selection given. :/
#
# Line: Hi Christy Tay, the click and collect stores are only in the selection given.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: :/
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 138
# ========================================================================
# Input sentence =  Legging can tahan under - 10°c?
#
# Line: Legging can tahan under - 10°c?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3092
# ========================================================================
# Input sentence =  Hey Chan Ev, yes they are suitable for winter. You may want to wear layers to keep the cold and wind out. We also recommend our Blocktech warm lined pants which has a fleece lining inside. Do note that these also depend on individual tolerance to cold and wind speeds.
#
# Line: Hey Chan Ev, yes they are suitable for winter.
# Sentiment(polarity=0.55, subjectivity=0.75)
# positive
#
# Line: You may want to wear layers to keep the cold and wind out.
# Sentiment(polarity=-0.6, subjectivity=1.0)
# Sentiment(polarity=-0.6, subjectivity=1.0)
# negative
#
# Line: We also recommend our Blocktech warm lined pants which has a fleece lining inside.
# Sentiment(polarity=0.6, subjectivity=0.6)
# positive
#
# Line: Do note that these also depend on individual tolerance to cold and wind speeds.
# Sentiment(polarity=-0.3, subjectivity=0.7)
# Sentiment(polarity=-0.3, subjectivity=0.7)
# negative
#
# THE SENTENCE IS NEUTRAL
# 3093
# ========================================================================
# Input sentence =  Wah ! Now still have ultra warm . Any different leh ! Haha , mean the last version not enough warm
#
# Line: Wah !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Now still have ultra warm .
# Sentiment(polarity=0.6, subjectivity=0.6)
# positive
#
# Line: Any different leh !
# Sentiment(polarity=0.0, subjectivity=0.6)
# neutral
#
# Line: Haha , mean the last version not enough warm
# Sentiment(polarity=0.0975, subjectivity=0.43083333333333335)
# positive
#
# THE SENTENCE IS +ve
# 574
# ========================================================================
# Input sentence =  Which suitable travelling Hokkaido in March?
#
# Line: Which suitable travelling Hokkaido in March?
# Sentiment(polarity=0.55, subjectivity=0.75)
# positive
#
# THE SENTENCE IS +ve
# 575
# ========================================================================
# Input sentence =  Kenzo Nightwalker Tracy Chang Weng Hwa Ang can I buy this for rinjani?
#
# Line: Kenzo Nightwalker Tracy Chang Weng Hwa Ang can I buy this for rinjani?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3094
# ========================================================================
# Input sentence =  Next time heattech new product call "extreme ultra warm" 🤣
#
# Line: Next time heattech new product call "extreme ultra warm" 🤣
# Sentiment(polarity=0.15284090909090908, subjectivity=0.5136363636363637)
# positive
#
# THE SENTENCE IS +ve
# 576
# ========================================================================
# Input sentence =  Sulastri Yahya; heat tech by uniqlo
#
# Line: Sulastri Yahya; heat tech by uniqlo
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3095
# ========================================================================
# Input sentence =  Eifa Masdari long John.
#
# Line: Eifa Masdari long John.
# Sentiment(polarity=-0.05, subjectivity=0.4)
# Sentiment(polarity=-0.05, subjectivity=0.4)
# negative
#
# THE SENTENCE IS -ve
# 139
# ========================================================================
# Input sentence =  Nasrullah Zulkipli
#
# Line: Nasrullah Zulkipli
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3096
# ========================================================================
# Input sentence =  Christine Chann
#
# Line: Christine Chann
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3097
# ========================================================================
# Input sentence =  Ramizan Rusly Ayin Yahaya
#
# Line: Ramizan Rusly Ayin Yahaya
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3098
# ========================================================================
# Input sentence =  Sudah adaa
#
# Line: Sudah adaa
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3099
# ========================================================================
# Input sentence =  Beli untuk syg la sebab saya tadak lagi. 🙄
#
# Line: Beli untuk syg la sebab saya tadak lagi.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 🙄
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3100
# ========================================================================
# Input sentence =  jomm
#
# Line: jomm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3101
# ========================================================================
# Input sentence =  Eh Affan skali hehe
#
# Line: Eh Affan skali hehe
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3102
# ========================================================================
# Input sentence =  Jeremy Teh
#
# Line: Jeremy Teh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3103
# ========================================================================
# Input sentence =  Muhammad Sahrilsal 😂😂
#
# Line: Muhammad Sahrilsal 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3104
# ========================================================================
# Input sentence =  Beza rm3 je dgn jepon punya.. cannot tahan 😂😂
#
# Line: Beza rm3 je dgn jepon punya.. cannot tahan 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3105
# ========================================================================
# Input sentence =  Mata wang malaysia rendah..nk buat mcm mn..😂😂
#
# Line: Mata wang malaysia rendah..nk buat mcm mn..😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3106
# ========================================================================
# Input sentence =  Rozaidi Rodi
#
# Line: Rozaidi Rodi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3107
# ========================================================================
# Input sentence =  Jun Weng
#
# Line: Jun Weng
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3108
# ========================================================================
# Input sentence =  赵天
#
# Line: 赵天
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3109
# ========================================================================
# Input sentence =  Online shop and earn more!
#
# Line: Online shop and earn more!
# Sentiment(polarity=0.625, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 577
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3110
# ========================================================================
# Input sentence =  Only at http://mys.shop.com/sml66
#
# Line: Only at http://mys.shop.com/sml66
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3111
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3112
# ========================================================================
# Input sentence =  Partner Store - UNIQLO [[SHARE]]
#
# Line: Partner Store - UNIQLO [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3113
# ========================================================================
# Input sentence =  do e-special offer for supima cotton pls...hehehe
#
# Line: do e-special offer for supima cotton pls...hehehe
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3114
# ========================================================================
# Input sentence =  Winnie Teoh Tiang Suan Tioh 这里应该有颜色和size
#
# Line: Winnie Teoh Tiang Suan Tioh 这里应该有颜色和size
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3115
# ========================================================================
# Input sentence =  你是说冬衣吗
#
# Line: 你是说冬衣吗
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3116
# ========================================================================
# Input sentence =  对 ultra light
#
# Line: 对 ultra light
# Sentiment(polarity=0.4, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 578
# ========================================================================
# Input sentence =  Ooi Chai Hoon, Jia Ni, Jia Jie Cheah
#
# Line: Ooi Chai Hoon, Jia Ni, Jia Jie Cheah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3117
# ========================================================================
# Input sentence =  Chunkiat New Walter Lim Ming Wei
#
# Line: Chunkiat New Walter Lim Ming Wei
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# positive
#
# THE SENTENCE IS +ve
# 579
# ========================================================================
# Input sentence =  Tai Jia Yi
#
# Line: Tai Jia Yi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3118
# ========================================================================
# Input sentence =  Mancy Loo
#
# Line: Mancy Loo
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3119
# ========================================================================
# Input sentence =  Hui Sin
#
# Line: Hui Sin
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3120
# ========================================================================
# Input sentence =  The pink colour nice
#
# Line: The pink colour nice
# Sentiment(polarity=0.25, subjectivity=0.65)
# positive
#
# THE SENTENCE IS +ve
# 580
# ========================================================================
# Input sentence =  Can buy online want ma?
#
# Line: Can buy online want ma?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3121
# ========================================================================
# Input sentence =  Li Tzer
#
# Line: Li Tzer
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3122
# ========================================================================
# Input sentence =  Joey Cheong 好像很好穿
#
# Line: Joey Cheong 好像很好穿
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3123
# ========================================================================
# Input sentence =  Tony Lim
#
# Line: Tony Lim
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3124
# ========================================================================
# Input sentence =  Asrul Bolt
#
# Line: Asrul Bolt
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3125
# ========================================================================
# Input sentence =  ba weekend?
#
# Line: ba weekend?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3126
# ========================================================================
# Input sentence =  Asrul Bolt nnt atur
#
# Line: Asrul Bolt nnt atur
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3127
# ========================================================================
# Input sentence =  Nurul Syahiena
#
# Line: Nurul Syahiena
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3128
# ========================================================================
# Input sentence =  Adeline Hah
#
# Line: Adeline Hah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3129
# ========================================================================
# Input sentence =  CiKk FiNn
#
# Line: CiKk FiNn
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3130
# ========================================================================
# Input sentence =  LoveCat Connie
#
# Line: LoveCat Connie
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3131
# ========================================================================
# Input sentence =  Momo Summer
#
# Line: Momo Summer
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3132
# ========================================================================
# Sentence Polarity Negative =  139
# Sentence Polarity Neutral =  3133
# Sentence Polarity Positive =  580

# %%
# txt to csv 
with open('SentimentUniqlo.txt', 'r',encoding ='UTF-8') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split("+;") for line in stripped if line)
    with open('sentiment(Uniqlo).csv', 'w',encoding ='UTF-8') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('text', 'sentiment'))
        writer.writerows(lines)

# %% [markdown]
# ### WordCloud Sentiment Analysis (Uniqlo)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split # function for splitting data to train and test sets

import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output

# %%
data = pd.read_csv('sentiment(Uniqlo).csv')
# Keeping only the neccessary columns
data = data[['text','sentiment']]

# %%
# Splitting the dataset into train and test set
train, test = train_test_split(data,test_size = 0.1)
# Removing neutral sentiments
train = train[train.sentiment != "neutral"]

# %%
train_pos = train[ train['sentiment'] == 'positive']
train_pos = train_pos['text']
train_neg = train[ train['sentiment'] == 'negative']
train_neg = train_neg['text']

def wordcloud_draw(data, color = 'black',name = 'Unknown', titl = 'Netural'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT' 
                            ])
    STOPWORDS = stopwords.words('english') + ['uniqlo','wan','hahaha','much','haha','.lol','hahahaha','.nipple']
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=1800,
                      height=1400
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.title('Uniqlo'+titl+'Sentiment Analysis')
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.savefig(name, dpi=1000)
    plt.show()
    
print("Positive words")
wordcloud_draw(train_pos,'white','PositiveUniqlo.png','Positive')
print("Negative words")
wordcloud_draw(train_neg,'black','NegativeUniqlo.png','Negative')
# Out:
# Positive words
# Negative words

# %% [markdown]
# # Zalora

# %%
# !pip install textblob
#For Sentiment Analysis
# Out:
# Collecting textblob
#   Using cached textblob-0.15.1-py2.py3-none-any.whl
# Requirement already satisfied: nltk>=3.1 in c:\users\andy\anaconda3\lib\site-packages (from textblob)
# Requirement already satisfied: six in c:\users\andy\anaconda3\lib\site-packages (from nltk>=3.1->textblob)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.1

# %%
#convert the csv to txt
import csv
import pandas as pd
f=pd.read_csv("ZaloraMalaysia_facebook_comments5.csv")
keep_col = ['comment_message']
new_f = f[keep_col]
new_f.to_csv("ZaloraMalaysia_facebook_comments5.csv", index=False)
with open('ZaloraComment.txt', "w",encoding = "UTF-8") as my_output_file:
    with open('ZaloraMalaysia_facebook_comments5.csv', "r",encoding = "UTF-8") as my_input_file:
        [ my_output_file.write(" ".join(row)+'\n') for row in csv.reader(my_input_file)]
    my_output_file.close()

# %%
# Sentiment Analysis For Zalora Comment
import matplotlib.pyplot as plt
from textblob import TextBlob
if __name__ == "__main__":
    
    Sentence_polarity_pos =0
    Sentence_polarity_neutral = 0
    Sentence_polarity_neg = 0
    

    inputfile = open("ZaloraComment.txt", "r",encoding = "UTF-8")
    outputfile = open("ZMFBTEXTSentimentBySentence.txt", "w",encoding = "UTF-8")


    for line in inputfile:
        try:
            
            Count_neg=0
            Count_neutral=0
            Count_pos=0
            
            #print(line)
            line = TextBlob(line)
           
            print ("Input sentence = ", line.strip() + "\n")
            outputfile.write("Input sentence = " + str(line).strip() +"\n")
            
            for each_line in line.sentences:
                print("Line: " + str(each_line))
                print(each_line.sentiment)
                outputfile.write(str(each_line.sentiment)+"\n")

                if each_line.sentiment.polarity < 0.0:
                    print(each_line.sentiment)
                    print ("negative" + "\n")
                    outputfile.write (str(each_line)+"\n")
                    outputfile.write ("negative\n\n")
                    Count_neg +=1
                elif each_line.sentiment.polarity == 0:
                    print ("neutral" + "\n")
                    outputfile.write (str(each_line)+"\n")
                    outputfile.write ("neutral\n\n")
                    Count_neutral +=1
                else:
                    print ("positive" + "\n")
                    outputfile.write (str(each_line)+"\n")
                    outputfile.write ("positive\n\n")
                    Count_pos +=1

                    
            if Count_pos > Count_neg: 
                print ("THE SENTENCE IS +ve")
                outputfile.write ("The sentence has Positive sentiment\n\n")
                Sentence_polarity_pos += 1
                print (Sentence_polarity_pos)

            elif (Count_pos == Count_neg):  
                print ("THE SENTENCE IS NEUTRAL")
                outputfile.write ("The sentence is Neutral\n\n")
                print (Sentence_polarity_neutral)
                Sentence_polarity_neutral += 1

            else:
                print ("THE SENTENCE IS -ve") 
                outputfile.write ("The sentence has Negative sentiment\n\n")
                Sentence_polarity_neg += 1
                print (Sentence_polarity_neg)
           
            outputfile.write("=============================================================\n")
            print("========================================================================")
        except:
            continue

    print ("Sentence Polarity Negative = ",Sentence_polarity_neg )
    print ("Sentence Polarity Neutral = ",Sentence_polarity_neutral )
    print ("Sentence Polarity Positive = ",Sentence_polarity_pos )
    outputfile.write ("Sentence Polarity Negative = %s \n"%Sentence_polarity_neg )
    outputfile.write ("Sentence Polarity Neutral = %s \n"%Sentence_polarity_neutral )
    outputfile.write ("Sentence Polarity Positive = %s \n"%Sentence_polarity_pos )

    Polarity = [1,3]
    LABELS = ["Positive", "Negative"]
    Count_polarity = [Sentence_polarity_pos, Sentence_polarity_neg]

    plt.xlabel('Polarity')
    plt.ylabel('Count')
    plt.title('Zalora Sentiment Analysis')

    plt.grid(True)
    plt.bar(Polarity, Count_polarity, align='center')
    plt.xticks(Polarity, LABELS)
    plt.savefig('ZaloraSentiment.png', dpi=1000)
    plt.show()
    
outputfile.close()
# Out:
# Input sentence =  comment_message
#
# Line: comment_message
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 0
# ========================================================================
# Input sentence =  Ain Syada
#
# Line: Ain Syada
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 1
# ========================================================================
# Input sentence =  AH Man:bie nak kasut ni☺️
#
# Line: AH Man:bie nak kasut ni☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 2
# ========================================================================
# Input sentence =  Wan Muhammad Ariff nah ganti kasut bb yg takde size tu. 😍
#
# Line: Wan Muhammad Ariff nah ganti kasut bb yg takde size tu.
# Sentiment(polarity=-0.2, subjectivity=0.15000000000000002)
# Sentiment(polarity=-0.2, subjectivity=0.15000000000000002)
# negative
#
# Line: 😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS -ve
# 1
# ========================================================================
# Input sentence =  Rey Hash..nak yg ni...😘😘😘😘😘
#
# Line: Rey Hash..nak yg ni...😘😘😘😘😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3
# ========================================================================
# Input sentence =  Amir Cacipo tlg survey hihi
#
# Line: Amir Cacipo tlg survey hihi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 4
# ========================================================================
# Input sentence =  Haha ok,
#
# Line: Haha ok,
# Sentiment(polarity=0.35, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 1
# ========================================================================
# Input sentence =  Tp tali die xcantik pulak
#
# Line: Tp tali die xcantik pulak
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 5
# ========================================================================
# Input sentence =  Mmg lah tali dia mcm rayband
#
# Line: Mmg lah tali dia mcm rayband
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 6
# ========================================================================
# Input sentence =  Itu je xcantik
#
# Line: Itu je xcantik
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 7
# ========================================================================
# Input sentence =  Jiasiang Tey Nice ?
#
# Line: Jiasiang Tey Nice ?
# Sentiment(polarity=0.6, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 2
# ========================================================================
# Input sentence =  Khairul Asraf syg nk ni...
#
# Line: Khairul Asraf syg nk ni...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 8
# ========================================================================
# Input sentence =  Ita Hj Othman
#
# Line: Ita Hj Othman
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 9
# ========================================================================
# Input sentence =  Lawa eh ada ni arh zalora 🤤
#
# Line: Lawa eh ada ni arh zalora 🤤
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 10
# ========================================================================
# Input sentence =  Yoh zalora sudah nii 🤣
#
# Line: Yoh zalora sudah nii 🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 11
# ========================================================================
# Input sentence =  Ain Hunny
#
# Line: Ain Hunny
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 12
# ========================================================================
# Input sentence =  Rosman Aizat
#
# Line: Rosman Aizat
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 13
# ========================================================================
# Input sentence =  Elene Lee Joanne Lim 微妮
#
# Line: Elene Lee Joanne Lim 微妮
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 14
# ========================================================================
# Input sentence =  高的美，不过我没得穿😭
#
# Line: 高的美，不过我没得穿😭
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 15
# ========================================================================
# Input sentence =  Khairul Asraf
#
# Line: Khairul Asraf
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 16
# ========================================================================
# Input sentence =  Imelda Goh
#
# Line: Imelda Goh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 17
# ========================================================================
# Input sentence =  This don’t know how to wear 🤣
#
# Line: This don’t know how to wear 🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 18
# ========================================================================
# Input sentence =  Jmy Ooi
#
# Line: Jmy Ooi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 19
# ========================================================================
# Input sentence =  Ekeen Adinanin
#
# Line: Ekeen Adinanin
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 20
# ========================================================================
# Input sentence =  Pm harga
#
# Line: Pm harga
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 21
# ========================================================================
# Input sentence =  Pm me
#
# Line: Pm me
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 22
# ========================================================================
# Input sentence =  Melissa Tan from AsNTM 3 & Shikin Gomez from AsNTM 5...
#
# Line: Melissa Tan from AsNTM 3 & Shikin Gomez from AsNTM 5...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 23
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 24
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 25
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 26
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 27
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 28
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 29
# ========================================================================
# Input sentence =  Greattt...
#
# Line: Greattt...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 30
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 31
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 32
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 33
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 34
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 35
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 36
# ========================================================================
# Input sentence =  😏😏😏
#
# Line: 😏😏😏
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 37
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 38
# ========================================================================
# Input sentence =  Sandra Valdemor
#
# Line: Sandra Valdemor
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 39
# ========================================================================
# Input sentence =  pm price
#
# Line: pm price
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 40
# ========================================================================
# Input sentence =  jam gshock
#
# Line: jam gshock
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 41
# ========================================================================
# Input sentence =  Pm jaket
#
# Line: Pm jaket
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 42
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 43
# ========================================================================
# Input sentence =  Hi, calling all shopaholics !
#
# Line: Hi, calling all shopaholics !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 44
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 45
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 46
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 47
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 48
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 49
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 50
# ========================================================================
# Input sentence =  .
#
# Line: .
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 51
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 52
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 53
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 54
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 55
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 56
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 57
# ========================================================================
# Input sentence =  Great news ! Now you can save while shopping at Zalora. How ? Quote this code ‘ ZBAPX81L ‘ during checkout to enjoy 15% off total bill. Valid for new & existing customers.
#
# Line: Great news !
# Sentiment(polarity=1.0, subjectivity=0.75)
# positive
#
# Line: Now you can save while shopping at Zalora.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: How ?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Quote this code ‘ ZBAPX81L ‘ during checkout to enjoy 15% off total bill.
# Sentiment(polarity=0.2, subjectivity=0.625)
# positive
#
# Line: Valid for new & existing customers.
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# positive
#
# THE SENTENCE IS +ve
# 3
# ========================================================================
# Input sentence =  How Much
#
# Line: How Much
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 4
# ========================================================================
# Input sentence =  Khairul Bahar... Omg
#
# Line: Khairul Bahar... Omg
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 58
# ========================================================================
# Input sentence =  Nana Yusof tlg tgkkn saiz
#
# Line: Nana Yusof tlg tgkkn saiz
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 59
# ========================================================================
# Input sentence =  [[PHOTO]]
#
# Line: [[PHOTO]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 60
# ========================================================================
# Input sentence =  Brand apa ni ye...
#
# Line: Brand apa ni ye...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 61
# ========================================================================
# Input sentence =  Jurie Yanie ni smart kn
#
# Line: Jurie Yanie ni smart kn
# Sentiment(polarity=0.21428571428571427, subjectivity=0.6428571428571429)
# positive
#
# THE SENTENCE IS +ve
# 5
# ========================================================================
# Input sentence =  NiCk Fahmiey comel
#
# Line: NiCk Fahmiey comel
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 62
# ========================================================================
# Input sentence =  Brapo ni , blue black comel
#
# Line: Brapo ni , blue black comel
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.26666666666666666)
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.26666666666666666)
# negative
#
# THE SENTENCE IS -ve
# 2
# ========================================================================
# Input sentence =  xtahu aku
#
# Line: xtahu aku
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 63
# ========================================================================
# Input sentence =  Nati nok siasat
#
# Line: Nati nok siasat
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 64
# ========================================================================
# Input sentence =  how
#
# Line: how
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 65
# ========================================================================
# Input sentence =  Nur Wahida tell me how to save now?? 😱😱😱
#
# Line: Nur Wahida tell me how to save now??
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😱😱😱
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 66
# ========================================================================
# Input sentence =  Fatihah Onlyme lawa nye.......
#
# Line: Fatihah Onlyme lawa nye.......
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 67
# ========================================================================
# Input sentence =  Lawaaaaaaaa😉😉😉😉..tp kaler nude xde meyh
#
# Line: Lawaaaaaaaa😉😉😉😉..tp kaler nude xde meyh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 68
# ========================================================================
# Input sentence =  Aris Mohamed 😱
#
# Line: Aris Mohamed 😱
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 69
# ========================================================================
# Input sentence =  Please blanje satu
#
# Line: Please blanje satu
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 70
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 71
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 72
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 73
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 74
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 75
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 76
# ========================================================================
# Input sentence =  😙😙😙
#
# Line: 😙😙😙
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 77
# ========================================================================
# Input sentence =  🤔
#
# Line: 🤔
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 78
# ========================================================================
# Input sentence =  Dhiviya Kunalan
#
# Line: Dhiviya Kunalan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 79
# ========================================================================
# Input sentence =  Hana Idris Nur Fathihah Nur Irsalina
#
# Line: Hana Idris Nur Fathihah Nur Irsalina
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 80
# ========================================================================
# Input sentence =  Cantik lar Mamak
#
# Line: Cantik lar Mamak
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 81
# ========================================================================
# Input sentence =  wow
#
# Line: wow
# Sentiment(polarity=0.1, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 6
# ========================================================================
# Input sentence =  How she adapted the theme of floral fauna to make their big day full of tremendous goals and be remembered as the glorious part in life.congratulations Yuna and Adam
#
# Line: How she adapted the theme of floral fauna to make their big day full of tremendous goals and be remembered as the glorious part in life.congratulations Yuna and Adam
# Sentiment(polarity=0.22777777777777777, subjectivity=0.5499999999999999)
# positive
#
# THE SENTENCE IS +ve
# 7
# ========================================================================
# Input sentence =  Absolutely stunning
#
# Line: Absolutely stunning
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 8
# ========================================================================
# Input sentence =  Highlight of our proposed trip hehehe
#
# Line: Highlight of our proposed trip hehehe
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 82
# ========================================================================
# Input sentence =  Im really Dissapointed with your service. I purchase an item 11 January and until now ive not received my item and yet you dont even reply my email!!!!!!
#
# Line: Im really Dissapointed with your service.
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# Line: I purchase an item 11 January and until now ive not received my item and yet you dont even reply my email!!!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 9
# ========================================================================
# Input sentence =  How much?
#
# Line: How much?
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 10
# ========================================================================
# Input sentence =  Hi Zalora. Is this post accurate? You do not seem to have the leather models pictured here available.
#
# Line: Hi Zalora.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Is this post accurate?
# Sentiment(polarity=0.4000000000000001, subjectivity=0.6333333333333334)
# positive
#
# Line: You do not seem to have the leather models pictured here available.
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 11
# ========================================================================
# Input sentence =  Pm me the price and size
#
# Line: Pm me the price and size
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 83
# ========================================================================
# Input sentence =  Woww crown the feet!!
#
# Line: Woww crown the feet!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 84
# ========================================================================
# Input sentence =  Wah cantik...:)
#
# Line: Wah cantik...:)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 12
# ========================================================================
# Input sentence =  cantik2... gaji kitaorang keje gudang zalora bilo nk bayo...
#
# Line: cantik2... gaji kitaorang keje gudang zalora bilo nk bayo...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 85
# ========================================================================
# Input sentence =  Zmr Mhmd belanja.. hehe
#
# Line: Zmr Mhmd belanja.. hehe
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 86
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 87
# ========================================================================
# Input sentence =  Pm price
#
# Line: Pm price
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 88
# ========================================================================
# Input sentence =  pm hrga
#
# Line: pm hrga
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 89
# ========================================================================
# Input sentence =  Sivanesan Govindasamy
#
# Line: Sivanesan Govindasamy
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 90
# ========================================================================
# Input sentence =  How did he get out from prison?
#
# Line: How did he get out from prison?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 91
# ========================================================================
# Input sentence =  ..LOL #theflash
#
# Line: ..LOL #theflash
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 92
# ========================================================================
# Input sentence =  Thanks
#
# Line: Thanks
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 13
# ========================================================================
# Input sentence =  Wowww 😱
#
# Line: Wowww 😱
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 93
# ========================================================================
# Input sentence =  Puteri Elida  urs? 😁
#
# Line: Puteri Elida  urs?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😁
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 94
# ========================================================================
# Input sentence =  kabayan Rowena Sofian uso na ulit  ,I like it 😍
#
# Line: kabayan Rowena Sofian uso na ulit  ,I like it 😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 95
# ========================================================================
# Input sentence =  Wey wey gusto ko din yan😉
#
# Line: Wey wey gusto ko din yan😉
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 96
# ========================================================================
# Input sentence =  Bjhvjbv
#
# Line: Bjhvjbv
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 97
# ========================================================================
# Input sentence =  Fiqa Jamingon
#
# Line: Fiqa Jamingon
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 98
# ========================================================================
# Input sentence =  Hi p
#
# Line: Hi p
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 99
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 100
# ========================================================================
# Input sentence =  Mr.zalora
#
# Line: Mr.zalora
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 101
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 102
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 103
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 104
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 105
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 106
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 107
# ========================================================================
# Input sentence =  White Sneakers zalora brand yang ada zip tepi tu nanti ada keluar lagi tak?
#
# Line: White Sneakers zalora brand yang ada zip tepi tu nanti ada keluar lagi tak?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 108
# ========================================================================
# Input sentence =  Letitia Chai
#
# Line: Letitia Chai
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 109
# ========================================================================
# Input sentence =  pm
#
# Line: pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 110
# ========================================================================
# Input sentence =  This Dean? Migo Hhy
#
# Line: This Dean?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Migo Hhy
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 111
# ========================================================================
# Input sentence =  yes my fav <3 but now doesn't  look like this hahaa.. major change of hairstyle!
#
# Line: yes my fav <3 but now doesn't  look like this hahaa.. major change of hairstyle!
# Sentiment(polarity=0.5390625, subjectivity=0.75)
# positive
#
# THE SENTENCE IS +ve
# 14
# ========================================================================
# Input sentence =  Oooooo..lol..ok
#
# Line: Oooooo..lol..ok
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 112
# ========================================================================
# Input sentence =  Pushing the heart to admire the design.
#
# Line: Pushing the heart to admire the design.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 113
# ========================================================================
# Input sentence =  Hazirah Hidayat working shoes?
#
# Line: Hazirah Hidayat working shoes?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 114
# ========================================================================
# Input sentence =  nice, how much?
#
# Line: nice, how much?
# Sentiment(polarity=0.4, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 15
# ========================================================================
# Input sentence =  Hm
#
# Line: Hm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 115
# ========================================================================
# Input sentence =  How much
#
# Line: How much
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 16
# ========================================================================
# Input sentence =  Budok Belalang Nurr Hazirah 🤤🤤
#
# Line: Budok Belalang Nurr Hazirah 🤤🤤
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 116
# ========================================================================
# Input sentence =  Hahahhaha
#
# Line: Hahahhaha
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 117
# ========================================================================
# Input sentence =  Nurul Najihah Ismail Fahmi Elmi Suaaidah
#
# Line: Nurul Najihah Ismail Fahmi Elmi Suaaidah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 118
# ========================================================================
# Input sentence =  Mimie Omey
#
# Line: Mimie Omey
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 119
# ========================================================================
# Input sentence =  Mahai ado hahaha
#
# Line: Mahai ado hahaha
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 17
# ========================================================================
# Input sentence =  bags
#
# Line: bags
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 120
# ========================================================================
# Input sentence =  USE Coupon COde ZBAP7FFJ for 15% OOF
#
# Line: USE Coupon COde ZBAP7FFJ for 15% OOF
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 121
# ========================================================================
# Input sentence =  boss boleh order jam
#
# Line: boss boleh order jam
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 122
# ========================================================================
# Input sentence =  Mirul Aizat
#
# Line: Mirul Aizat
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 123
# ========================================================================
# Input sentence =  [[PHOTO]]
#
# Line: [[PHOTO]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 124
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 125
# ========================================================================
# Input sentence =  Reza Zahid Amir.... ramlah Ram 🐑
#
# Line: Reza Zahid Amir.... ramlah Ram 🐑
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 126
# ========================================================================
# Input sentence =  Ora podo turupo sesuk golek upo dari sobatmu duda merana
#
# Line: Ora podo turupo sesuk golek upo dari sobatmu duda merana
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 127
# ========================================================================
# Input sentence =  Nk slim n fitt.. plzzz.. hu2
#
# Line: Nk slim n fitt.. plzzz.. hu2
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 128
# ========================================================================
# Input sentence =  Hasmuni Lina
#
# Line: Hasmuni Lina
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 129
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 130
# ========================================================================
# Input sentence =  Happy New year to all zalora
#
# Line: Happy New year to all zalora
# Sentiment(polarity=0.4681818181818182, subjectivity=0.7272727272727273)
# positive
#
# THE SENTENCE IS +ve
# 18
# ========================================================================
# Input sentence =  Hi get upto 20% dicount coupon code:ZBAP7FFJ
#
# Line: Hi get upto 20% dicount coupon code:ZBAP7FFJ
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 131
# ========================================================================
# Input sentence =  Faid Emad Altkrity
#
# Line: Faid Emad Altkrity
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 132
# ========================================================================
# Input sentence =  شنو حبي
#
# Line: شنو حبي
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 133
# ========================================================================
# Input sentence =  Hm
#
# Line: Hm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 134
# ========================================================================
# Input sentence =  black size 6, how much
#
# Line: black size 6, how much
# Sentiment(polarity=0.016666666666666677, subjectivity=0.31666666666666665)
# positive
#
# THE SENTENCE IS +ve
# 19
# ========================================================================
# Input sentence =  How much prize?
#
# Line: How much prize?
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 20
# ========================================================================
# Input sentence =  Prize plz..
#
# Line: Prize plz..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 135
# ========================================================================
# Input sentence =  How much
#
# Line: How much
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 21
# ========================================================================
# Input sentence =  How much?
#
# Line: How much?
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 22
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 136
# ========================================================================
# Input sentence =  Lanje cu. hahahaha Rozita Ibrahim
#
# Line: Lanje cu.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: hahahaha Rozita Ibrahim
# Sentiment(polarity=0.2, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 23
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 137
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 138
# ========================================================================
# Input sentence =  Kiven Kigen hadiah 1
#
# Line: Kiven Kigen hadiah 1
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 139
# ========================================================================
# Input sentence =  1
#
# Line: 1
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 140
# ========================================================================
# Input sentence =  Luqman Hadi nak
#
# Line: Luqman Hadi nak
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 141
# ========================================================================
# Input sentence =  Shila Natasha 😂
#
# Line: Shila Natasha 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 142
# ========================================================================
# Input sentence =  Halizah ZahariJuliessa Ell 😂😂
#
# Line: Halizah ZahariJuliessa Ell 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 143
# ========================================================================
# Input sentence =  Astagaaaa ko x keja ka ni?😂😂
#
# Line: Astagaaaa ko x keja ka ni?😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 144
# ========================================================================
# Input sentence =  Halizah Zahari keja ba
#
# Line: Halizah Zahari keja ba
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 145
# ========================================================================
# Input sentence =  Celine Hong
#
# Line: Celine Hong
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 146
# ========================================================================
# Input sentence =  What a horrible styling!
#
# Line: What a horrible styling!
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 3
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 147
# ========================================================================
# Input sentence =  Hi Zalora. Can u check ur inbox?
#
# Line: Hi Zalora.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Can u check ur inbox?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 148
# ========================================================================
# Input sentence =  Dear Zalora, please find this post a request to provide (not the best but at least) essential customer service. This is the first time my order had a snag and the experience had bene an unpleasant one. Not only was I let down for never being able to receive my goods, it became painful to attempt communication with you.
#
# Line: Dear Zalora, please find this post a request to provide (not the best but at least) essential customer service.
# Sentiment(polarity=0.2333333333333333, subjectivity=0.3333333333333333)
# positive
#
# Line: This is the first time my order had a snag and the experience had bene an unpleasant one.
# Sentiment(polarity=-0.19999999999999996, subjectivity=0.6416666666666666)
# Sentiment(polarity=-0.19999999999999996, subjectivity=0.6416666666666666)
# negative
#
# Line: Not only was I let down for never being able to receive my goods, it became painful to attempt communication with you.
# Sentiment(polarity=-0.08888888888888888, subjectivity=0.7034722222222223)
# Sentiment(polarity=-0.08888888888888888, subjectivity=0.7034722222222223)
# negative
#
# THE SENTENCE IS -ve
# 4
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 149
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 150
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 151
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 152
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 153
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 154
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 155
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 156
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 157
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 158
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 159
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 160
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 161
# ========================================================================
# Input sentence =  I have ordered on the 13th (216935972) and yesterday my order was "refunded" in store credits without notice/explanation.
#
# Line: I have ordered on the 13th (216935972) and yesterday my order was "refunded" in store credits without notice/explanation.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 162
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 163
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 164
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 165
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 166
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 167
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 168
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 169
# ========================================================================
# Input sentence =
# THE SENTENCE IS NEUTRAL
# 170
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 171
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 172
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 173
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 174
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 175
# ========================================================================
# Input sentence =  Customer service answered the phone, couldn't explain what happened and gave me only one option to provide my bank account details. He could not even understand that as a customer the thing I want most is simply my items. He said he will email me for account details immediately. He never sent the email. I wrote in an email to ask for an explanation. It's been a day ago and yet no answer.
#
# Line: Customer service answered the phone, couldn't explain what happened and gave me only one option to provide my bank account details.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: He could not even understand that as a customer the thing I want most is simply my items.
# Sentiment(polarity=0.25, subjectivity=0.4285714285714286)
# positive
#
# Line: He said he will email me for account details immediately.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: He never sent the email.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I wrote in an email to ask for an explanation.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: It's been a day ago and yet no answer.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 24
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 176
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 177
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 178
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 179
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 180
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 181
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 182
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 183
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 184
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 185
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 186
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 187
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 188
# ========================================================================
# Input sentence =  Now, after waiting for more than 24 hours since sending in the email, I am sufficiently disappointed by you. I really do not want anything to do with you anymore. Answer me and I just want my money back please.
#
# Line: Now, after waiting for more than 24 hours since sending in the email, I am sufficiently disappointed by you.
# Sentiment(polarity=-0.125, subjectivity=0.625)
# Sentiment(polarity=-0.125, subjectivity=0.625)
# negative
#
# Line: I really do not want anything to do with you anymore.
# Sentiment(polarity=-0.1, subjectivity=0.2)
# Sentiment(polarity=-0.1, subjectivity=0.2)
# negative
#
# Line: Answer me and I just want my money back please.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS -ve
# 5
# ========================================================================
# Input sentence =  always lying to consumer, the delivery process never happened but they put a lot stories ....... [[STICKER]]
#
# Line: always lying to consumer, the delivery process never happened but they put a lot stories ....... [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 189
# ========================================================================
# Input sentence =  Can’t believe this!   Come on #zalora !!!
#
# Line: Can’t believe this!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Come on #zalora !!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 190
# ========================================================================
# Input sentence =  Same happen to me order 3 item on the 12 of december in early morning
#
# Line: Same happen to me order 3 item on the 12 of december in early morning
# Sentiment(polarity=0.05, subjectivity=0.2125)
# positive
#
# THE SENTENCE IS +ve
# 25
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 191
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 192
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 193
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 194
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 195
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 196
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 197
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 198
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 199
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 200
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 201
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 202
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 203
# ========================================================================
# Input sentence =  Not even 1 item receive...
#
# Line: Not even 1 item receive...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 204
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 205
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 206
# ========================================================================
# ...
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3464
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3465
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3466
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3467
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3468
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3469
# ========================================================================
# Input sentence =  PROMO CODE: ZBAPQSZL
#
# Line: PROMO CODE: ZBAPQSZL
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3470
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3471
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3472
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3473
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3474
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3475
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3476
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3477
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3478
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3479
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3480
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3481
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3482
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3483
# ========================================================================
# Input sentence =  This promocode is valid ONLY FOR NEW CUSTOMER ON THEIR FIRST TIME ORDER at www.zalora.com.my
#
# Line: This promocode is valid ONLY FOR NEW CUSTOMER ON THEIR FIRST TIME ORDER at www.zalora.com.my
# Sentiment(polarity=0.12878787878787878, subjectivity=0.5959595959595959)
# positive
#
# THE SENTENCE IS +ve
# 467
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3484
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3485
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3486
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3487
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3488
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3489
# ========================================================================
# Input sentence =  (its an online store for both male and female)
#
# Line: (its an online store for both male and female)
# Sentiment(polarity=0.0, subjectivity=0.13333333333333333)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3490
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3491
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3492
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3493
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3494
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3495
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3496
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3497
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3498
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3499
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3500
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3501
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3502
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3503
# ========================================================================
# Input sentence =  This promocode can be use by different users who never order at zalora before.
#
# Line: This promocode can be use by different users who never order at zalora before.
# Sentiment(polarity=0.0, subjectivity=0.6)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3504
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3505
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3506
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3507
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3508
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3509
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3510
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3511
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3512
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3513
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3514
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3515
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3516
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3517
# ========================================================================
# Input sentence =  TIPS: make another account again to order if you want to use the promocode over and over again!
#
# Line: TIPS: make another account again to order if you want to use the promocode over and over again!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3518
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3519
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3520
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3521
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3522
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3523
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3524
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3525
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3526
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3527
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3528
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3529
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3530
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3531
# ========================================================================
# Input sentence =  This promocode can be use on anything, including item that's already has sale/discount! But of course, you can only use one promo code at once.
#
# Line: This promocode can be use on anything, including item that's already has sale/discount!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: But of course, you can only use one promo code at once.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3532
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3533
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3534
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3535
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3536
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3537
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3538
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3539
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3540
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3541
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3542
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3543
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3544
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3545
# ========================================================================
# Input sentence =  You can STILL USE this promocode even though its already been used by others.
#
# Line: You can STILL USE this promocode even though its already been used by others.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3546
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3547
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3548
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3549
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3550
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3551
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3552
# ========================================================================
# Input sentence =  So Don't forget to copy paste and share it with your everyone! #sharingiscaring [[SHARE]]
#
# Line: So Don't forget to copy paste and share it with your everyone!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: #sharingiscaring [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3553
# ========================================================================
# Input sentence =  Welcome to Malaysia's finest, reliable dating agency . We have a wonderful influential RICH SUGAR MUMMY/DADDY/ IN MALAYSIA, be among the people to get our exclusive connections. We are reliable and efficient in our job, get the opportunity to meet them. We have sugar mummies all over Malaysia who are willing to lavish money on you, with gifts, cars, house and even contracts connections, and even assist get a job, start calling now to get connected within 24 hours and make more money.Note:Applicant must be 18 years and above and must possesses a well notable personality.a night with your mom is RM4,000 when you are able to satisfy your mom emotionally.
#
# Line: Welcome to Malaysia's finest, reliable dating agency .
# Sentiment(polarity=0.8, subjectivity=0.9)
# positive
#
# Line: We have a wonderful influential RICH SUGAR MUMMY/DADDY/ IN MALAYSIA, be among the people to get our exclusive connections.
# Sentiment(polarity=0.6875, subjectivity=0.875)
# positive
#
# Line: We are reliable and efficient in our job, get the opportunity to meet them.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: We have sugar mummies all over Malaysia who are willing to lavish money on you, with gifts, cars, house and even contracts connections, and even assist get a job, start calling now to get connected within 24 hours and make more money.Note:Applicant must be 18 years and above and must possesses a well notable personality.a night with your mom is RM4,000 when you are able to satisfy your mom emotionally.
# Sentiment(polarity=0.2916666666666667, subjectivity=0.5208333333333334)
# positive
#
# THE SENTENCE IS +ve
# 468
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3554
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3555
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3556
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3557
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3558
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3559
# ========================================================================
# Input sentence =  (Whatsapp+60143777309) Notable on whatsapp, as your agent can attend to you shortly. contact agent Mrs  Yang.
#
# Line: (Whatsapp+60143777309) Notable on whatsapp, as your agent can attend to you shortly.
# Sentiment(polarity=0.25, subjectivity=0.4)
# positive
#
# Line: contact agent Mrs  Yang.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 469
# ========================================================================
# Sentence Polarity Negative =  66
# Sentence Polarity Neutral =  3560
# Sentence Polarity Positive =  469

# %%
# WordCloud for Zalora Comment
from os import path
from wordcloud import WordCloud
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
convert_wordcloud = 'ZaloraComment.txt'

# Read the whole text.
text = open(convert_wordcloud,encoding ="UTF-8").read()

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:

stop_Words = stopwords.words('english') + ['much','hahaha','zalora','please','pm','la','kami','yg','sy','di','rt', 'via', 'bit', 'ly', 'get','https', 'www', 'com','ni','tu','Hi','yang','anda']
wordcloud = WordCloud(stopwords=stop_Words,
                      background_color='black',
                      width=1800,
                      height=1400).generate(text.lower())
plt.title("Zalora Comment WordCloud")
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig('ZaloraCommentWordCloud.png', dpi=1000)
plt.show()

# %%
# Sentiment Analysis For WordCloud (Zalora)
import matplotlib.pyplot as plt
from textblob import TextBlob
if __name__ == "__main__":
    
    Sentence_polarity_pos =0
    Sentence_polarity_neutral = 0
    Sentence_polarity_neg = 0
    

    inputfile = open("ZaloraComment.txt", "r",encoding = "UTF-8")
    outputfile = open("SentimentZalora.txt", "w",encoding = "UTF-8")


    for line in inputfile:
        try:
            
            Count_neg=0
            Count_neutral=0
            Count_pos=0
            
            #print(line)
            line = TextBlob(line)
           
            print ("Input sentence = ", line.strip() + "\n")
            
            for each_line in line.sentences:
                print("Line: " + str(each_line))
                print(each_line.sentiment)
                outputfile.write(str(each_line)+"+"+";")

                if each_line.sentiment.polarity < 0.0:
                    print(each_line.sentiment)
                    print ("negative" + "\n")
                    outputfile.write ("negative\n")
                    Count_neg +=1
                elif each_line.sentiment.polarity == 0:
                    print ("neutral" + "\n")
                    outputfile.write ("neutral\n")
                    Count_neutral +=1
                else:
                    print ("positive" + "\n")
                    outputfile.write ("positive\n")
                    Count_pos +=1

                    
            if Count_pos > Count_neg: 
                print ("THE SENTENCE IS +ve")
                Sentence_polarity_pos += 1
                print (Sentence_polarity_pos)

            elif (Count_pos == Count_neg):  
                print ("THE SENTENCE IS NEUTRAL")
                print (Sentence_polarity_neutral)
                Sentence_polarity_neutral += 1

            else:
                print ("THE SENTENCE IS -ve") 
                Sentence_polarity_neg += 1
                print (Sentence_polarity_neg)
           
            print("========================================================================")
        except:
            continue

    print ("Sentence Polarity Negative = ",Sentence_polarity_neg )
    print ("Sentence Polarity Neutral = ",Sentence_polarity_neutral )
    print ("Sentence Polarity Positive = ",Sentence_polarity_pos )
    Polarity = [1,3]
    LABELS = ["Positive", "Negative"]
    Count_polarity = [Sentence_polarity_pos, Sentence_polarity_neg]

    plt.xlabel('Polarity')
    plt.ylabel('Count')
    plt.title('Zalora Sentiment Analysis')

    plt.grid(True)
    plt.bar(Polarity, Count_polarity, align='center')
    plt.xticks(Polarity, LABELS)
    plt.savefig('ZaloraSentiment.png', dpi=1000)
    plt.show()
    
outputfile.close()
# Out:
# Input sentence =  comment_message
#
# Line: comment_message
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 0
# ========================================================================
# Input sentence =  Ain Syada
#
# Line: Ain Syada
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 1
# ========================================================================
# Input sentence =  AH Man:bie nak kasut ni☺️
#
# Line: AH Man:bie nak kasut ni☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 2
# ========================================================================
# Input sentence =  Wan Muhammad Ariff nah ganti kasut bb yg takde size tu. 😍
#
# Line: Wan Muhammad Ariff nah ganti kasut bb yg takde size tu.
# Sentiment(polarity=-0.2, subjectivity=0.15000000000000002)
# Sentiment(polarity=-0.2, subjectivity=0.15000000000000002)
# negative
#
# Line: 😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS -ve
# 1
# ========================================================================
# Input sentence =  Rey Hash..nak yg ni...😘😘😘😘😘
#
# Line: Rey Hash..nak yg ni...😘😘😘😘😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3
# ========================================================================
# Input sentence =  Amir Cacipo tlg survey hihi
#
# Line: Amir Cacipo tlg survey hihi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 4
# ========================================================================
# Input sentence =  Haha ok,
#
# Line: Haha ok,
# Sentiment(polarity=0.35, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 1
# ========================================================================
# Input sentence =  Tp tali die xcantik pulak
#
# Line: Tp tali die xcantik pulak
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 5
# ========================================================================
# Input sentence =  Mmg lah tali dia mcm rayband
#
# Line: Mmg lah tali dia mcm rayband
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 6
# ========================================================================
# Input sentence =  Itu je xcantik
#
# Line: Itu je xcantik
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 7
# ========================================================================
# Input sentence =  Jiasiang Tey Nice ?
#
# Line: Jiasiang Tey Nice ?
# Sentiment(polarity=0.6, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 2
# ========================================================================
# Input sentence =  Khairul Asraf syg nk ni...
#
# Line: Khairul Asraf syg nk ni...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 8
# ========================================================================
# Input sentence =  Ita Hj Othman
#
# Line: Ita Hj Othman
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 9
# ========================================================================
# Input sentence =  Lawa eh ada ni arh zalora 🤤
#
# Line: Lawa eh ada ni arh zalora 🤤
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 10
# ========================================================================
# Input sentence =  Yoh zalora sudah nii 🤣
#
# Line: Yoh zalora sudah nii 🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 11
# ========================================================================
# Input sentence =  Ain Hunny
#
# Line: Ain Hunny
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 12
# ========================================================================
# Input sentence =  Rosman Aizat
#
# Line: Rosman Aizat
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 13
# ========================================================================
# Input sentence =  Elene Lee Joanne Lim 微妮
#
# Line: Elene Lee Joanne Lim 微妮
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 14
# ========================================================================
# Input sentence =  高的美，不过我没得穿😭
#
# Line: 高的美，不过我没得穿😭
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 15
# ========================================================================
# Input sentence =  Khairul Asraf
#
# Line: Khairul Asraf
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 16
# ========================================================================
# Input sentence =  Imelda Goh
#
# Line: Imelda Goh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 17
# ========================================================================
# Input sentence =  This don’t know how to wear 🤣
#
# Line: This don’t know how to wear 🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 18
# ========================================================================
# Input sentence =  Jmy Ooi
#
# Line: Jmy Ooi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 19
# ========================================================================
# Input sentence =  Ekeen Adinanin
#
# Line: Ekeen Adinanin
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 20
# ========================================================================
# Input sentence =  Pm harga
#
# Line: Pm harga
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 21
# ========================================================================
# Input sentence =  Pm me
#
# Line: Pm me
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 22
# ========================================================================
# Input sentence =  Melissa Tan from AsNTM 3 & Shikin Gomez from AsNTM 5...
#
# Line: Melissa Tan from AsNTM 3 & Shikin Gomez from AsNTM 5...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 23
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 24
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 25
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 26
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 27
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 28
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 29
# ========================================================================
# Input sentence =  Greattt...
#
# Line: Greattt...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 30
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 31
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 32
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 33
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 34
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 35
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 36
# ========================================================================
# Input sentence =  😏😏😏
#
# Line: 😏😏😏
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 37
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 38
# ========================================================================
# Input sentence =  Sandra Valdemor
#
# Line: Sandra Valdemor
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 39
# ========================================================================
# Input sentence =  pm price
#
# Line: pm price
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 40
# ========================================================================
# Input sentence =  jam gshock
#
# Line: jam gshock
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 41
# ========================================================================
# Input sentence =  Pm jaket
#
# Line: Pm jaket
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 42
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 43
# ========================================================================
# Input sentence =  Hi, calling all shopaholics !
#
# Line: Hi, calling all shopaholics !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 44
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 45
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 46
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 47
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 48
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 49
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 50
# ========================================================================
# Input sentence =  .
#
# Line: .
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 51
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 52
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 53
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 54
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 55
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 56
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 57
# ========================================================================
# Input sentence =  Great news ! Now you can save while shopping at Zalora. How ? Quote this code ‘ ZBAPX81L ‘ during checkout to enjoy 15% off total bill. Valid for new & existing customers.
#
# Line: Great news !
# Sentiment(polarity=1.0, subjectivity=0.75)
# positive
#
# Line: Now you can save while shopping at Zalora.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: How ?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Quote this code ‘ ZBAPX81L ‘ during checkout to enjoy 15% off total bill.
# Sentiment(polarity=0.2, subjectivity=0.625)
# positive
#
# Line: Valid for new & existing customers.
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# positive
#
# THE SENTENCE IS +ve
# 3
# ========================================================================
# Input sentence =  How Much
#
# Line: How Much
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 4
# ========================================================================
# Input sentence =  Khairul Bahar... Omg
#
# Line: Khairul Bahar... Omg
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 58
# ========================================================================
# Input sentence =  Nana Yusof tlg tgkkn saiz
#
# Line: Nana Yusof tlg tgkkn saiz
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 59
# ========================================================================
# Input sentence =  [[PHOTO]]
#
# Line: [[PHOTO]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 60
# ========================================================================
# Input sentence =  Brand apa ni ye...
#
# Line: Brand apa ni ye...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 61
# ========================================================================
# Input sentence =  Jurie Yanie ni smart kn
#
# Line: Jurie Yanie ni smart kn
# Sentiment(polarity=0.21428571428571427, subjectivity=0.6428571428571429)
# positive
#
# THE SENTENCE IS +ve
# 5
# ========================================================================
# Input sentence =  NiCk Fahmiey comel
#
# Line: NiCk Fahmiey comel
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 62
# ========================================================================
# Input sentence =  Brapo ni , blue black comel
#
# Line: Brapo ni , blue black comel
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.26666666666666666)
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.26666666666666666)
# negative
#
# THE SENTENCE IS -ve
# 2
# ========================================================================
# Input sentence =  xtahu aku
#
# Line: xtahu aku
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 63
# ========================================================================
# Input sentence =  Nati nok siasat
#
# Line: Nati nok siasat
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 64
# ========================================================================
# Input sentence =  how
#
# Line: how
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 65
# ========================================================================
# Input sentence =  Nur Wahida tell me how to save now?? 😱😱😱
#
# Line: Nur Wahida tell me how to save now??
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😱😱😱
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 66
# ========================================================================
# Input sentence =  Fatihah Onlyme lawa nye.......
#
# Line: Fatihah Onlyme lawa nye.......
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 67
# ========================================================================
# Input sentence =  Lawaaaaaaaa😉😉😉😉..tp kaler nude xde meyh
#
# Line: Lawaaaaaaaa😉😉😉😉..tp kaler nude xde meyh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 68
# ========================================================================
# Input sentence =  Aris Mohamed 😱
#
# Line: Aris Mohamed 😱
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 69
# ========================================================================
# Input sentence =  Please blanje satu
#
# Line: Please blanje satu
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 70
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 71
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 72
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 73
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 74
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 75
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 76
# ========================================================================
# Input sentence =  😙😙😙
#
# Line: 😙😙😙
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 77
# ========================================================================
# Input sentence =  🤔
#
# Line: 🤔
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 78
# ========================================================================
# Input sentence =  Dhiviya Kunalan
#
# Line: Dhiviya Kunalan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 79
# ========================================================================
# Input sentence =  Hana Idris Nur Fathihah Nur Irsalina
#
# Line: Hana Idris Nur Fathihah Nur Irsalina
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 80
# ========================================================================
# Input sentence =  Cantik lar Mamak
#
# Line: Cantik lar Mamak
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 81
# ========================================================================
# Input sentence =  wow
#
# Line: wow
# Sentiment(polarity=0.1, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 6
# ========================================================================
# Input sentence =  How she adapted the theme of floral fauna to make their big day full of tremendous goals and be remembered as the glorious part in life.congratulations Yuna and Adam
#
# Line: How she adapted the theme of floral fauna to make their big day full of tremendous goals and be remembered as the glorious part in life.congratulations Yuna and Adam
# Sentiment(polarity=0.22777777777777777, subjectivity=0.5499999999999999)
# positive
#
# THE SENTENCE IS +ve
# 7
# ========================================================================
# Input sentence =  Absolutely stunning
#
# Line: Absolutely stunning
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 8
# ========================================================================
# Input sentence =  Highlight of our proposed trip hehehe
#
# Line: Highlight of our proposed trip hehehe
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 82
# ========================================================================
# Input sentence =  Im really Dissapointed with your service. I purchase an item 11 January and until now ive not received my item and yet you dont even reply my email!!!!!!
#
# Line: Im really Dissapointed with your service.
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# Line: I purchase an item 11 January and until now ive not received my item and yet you dont even reply my email!!!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 9
# ========================================================================
# Input sentence =  How much?
#
# Line: How much?
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 10
# ========================================================================
# Input sentence =  Hi Zalora. Is this post accurate? You do not seem to have the leather models pictured here available.
#
# Line: Hi Zalora.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Is this post accurate?
# Sentiment(polarity=0.4000000000000001, subjectivity=0.6333333333333334)
# positive
#
# Line: You do not seem to have the leather models pictured here available.
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 11
# ========================================================================
# Input sentence =  Pm me the price and size
#
# Line: Pm me the price and size
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 83
# ========================================================================
# Input sentence =  Woww crown the feet!!
#
# Line: Woww crown the feet!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 84
# ========================================================================
# Input sentence =  Wah cantik...:)
#
# Line: Wah cantik...:)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 12
# ========================================================================
# Input sentence =  cantik2... gaji kitaorang keje gudang zalora bilo nk bayo...
#
# Line: cantik2... gaji kitaorang keje gudang zalora bilo nk bayo...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 85
# ========================================================================
# Input sentence =  Zmr Mhmd belanja.. hehe
#
# Line: Zmr Mhmd belanja.. hehe
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 86
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 87
# ========================================================================
# Input sentence =  Pm price
#
# Line: Pm price
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 88
# ========================================================================
# Input sentence =  pm hrga
#
# Line: pm hrga
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 89
# ========================================================================
# Input sentence =  Sivanesan Govindasamy
#
# Line: Sivanesan Govindasamy
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 90
# ========================================================================
# Input sentence =  How did he get out from prison?
#
# Line: How did he get out from prison?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 91
# ========================================================================
# Input sentence =  ..LOL #theflash
#
# Line: ..LOL #theflash
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 92
# ========================================================================
# Input sentence =  Thanks
#
# Line: Thanks
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 13
# ========================================================================
# Input sentence =  Wowww 😱
#
# Line: Wowww 😱
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 93
# ========================================================================
# Input sentence =  Puteri Elida  urs? 😁
#
# Line: Puteri Elida  urs?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😁
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 94
# ========================================================================
# Input sentence =  kabayan Rowena Sofian uso na ulit  ,I like it 😍
#
# Line: kabayan Rowena Sofian uso na ulit  ,I like it 😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 95
# ========================================================================
# Input sentence =  Wey wey gusto ko din yan😉
#
# Line: Wey wey gusto ko din yan😉
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 96
# ========================================================================
# Input sentence =  Bjhvjbv
#
# Line: Bjhvjbv
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 97
# ========================================================================
# Input sentence =  Fiqa Jamingon
#
# Line: Fiqa Jamingon
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 98
# ========================================================================
# Input sentence =  Hi p
#
# Line: Hi p
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 99
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 100
# ========================================================================
# Input sentence =  Mr.zalora
#
# Line: Mr.zalora
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 101
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 102
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 103
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 104
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 105
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 106
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 107
# ========================================================================
# Input sentence =  White Sneakers zalora brand yang ada zip tepi tu nanti ada keluar lagi tak?
#
# Line: White Sneakers zalora brand yang ada zip tepi tu nanti ada keluar lagi tak?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 108
# ========================================================================
# Input sentence =  Letitia Chai
#
# Line: Letitia Chai
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 109
# ========================================================================
# Input sentence =  pm
#
# Line: pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 110
# ========================================================================
# Input sentence =  This Dean? Migo Hhy
#
# Line: This Dean?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Migo Hhy
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 111
# ========================================================================
# Input sentence =  yes my fav <3 but now doesn't  look like this hahaa.. major change of hairstyle!
#
# Line: yes my fav <3 but now doesn't  look like this hahaa.. major change of hairstyle!
# Sentiment(polarity=0.5390625, subjectivity=0.75)
# positive
#
# THE SENTENCE IS +ve
# 14
# ========================================================================
# Input sentence =  Oooooo..lol..ok
#
# Line: Oooooo..lol..ok
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 112
# ========================================================================
# Input sentence =  Pushing the heart to admire the design.
#
# Line: Pushing the heart to admire the design.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 113
# ========================================================================
# Input sentence =  Hazirah Hidayat working shoes?
#
# Line: Hazirah Hidayat working shoes?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 114
# ========================================================================
# Input sentence =  nice, how much?
#
# Line: nice, how much?
# Sentiment(polarity=0.4, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 15
# ========================================================================
# Input sentence =  Hm
#
# Line: Hm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 115
# ========================================================================
# Input sentence =  How much
#
# Line: How much
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 16
# ========================================================================
# Input sentence =  Budok Belalang Nurr Hazirah 🤤🤤
#
# Line: Budok Belalang Nurr Hazirah 🤤🤤
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 116
# ========================================================================
# Input sentence =  Hahahhaha
#
# Line: Hahahhaha
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 117
# ========================================================================
# Input sentence =  Nurul Najihah Ismail Fahmi Elmi Suaaidah
#
# Line: Nurul Najihah Ismail Fahmi Elmi Suaaidah
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 118
# ========================================================================
# Input sentence =  Mimie Omey
#
# Line: Mimie Omey
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 119
# ========================================================================
# Input sentence =  Mahai ado hahaha
#
# Line: Mahai ado hahaha
# Sentiment(polarity=0.2, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 17
# ========================================================================
# Input sentence =  bags
#
# Line: bags
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 120
# ========================================================================
# Input sentence =  USE Coupon COde ZBAP7FFJ for 15% OOF
#
# Line: USE Coupon COde ZBAP7FFJ for 15% OOF
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 121
# ========================================================================
# Input sentence =  boss boleh order jam
#
# Line: boss boleh order jam
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 122
# ========================================================================
# Input sentence =  Mirul Aizat
#
# Line: Mirul Aizat
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 123
# ========================================================================
# Input sentence =  [[PHOTO]]
#
# Line: [[PHOTO]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 124
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 125
# ========================================================================
# Input sentence =  Reza Zahid Amir.... ramlah Ram 🐑
#
# Line: Reza Zahid Amir.... ramlah Ram 🐑
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 126
# ========================================================================
# Input sentence =  Ora podo turupo sesuk golek upo dari sobatmu duda merana
#
# Line: Ora podo turupo sesuk golek upo dari sobatmu duda merana
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 127
# ========================================================================
# Input sentence =  Nk slim n fitt.. plzzz.. hu2
#
# Line: Nk slim n fitt.. plzzz.. hu2
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 128
# ========================================================================
# Input sentence =  Hasmuni Lina
#
# Line: Hasmuni Lina
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 129
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 130
# ========================================================================
# Input sentence =  Happy New year to all zalora
#
# Line: Happy New year to all zalora
# Sentiment(polarity=0.4681818181818182, subjectivity=0.7272727272727273)
# positive
#
# THE SENTENCE IS +ve
# 18
# ========================================================================
# Input sentence =  Hi get upto 20% dicount coupon code:ZBAP7FFJ
#
# Line: Hi get upto 20% dicount coupon code:ZBAP7FFJ
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 131
# ========================================================================
# Input sentence =  Faid Emad Altkrity
#
# Line: Faid Emad Altkrity
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 132
# ========================================================================
# Input sentence =  شنو حبي
#
# Line: شنو حبي
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 133
# ========================================================================
# Input sentence =  Hm
#
# Line: Hm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 134
# ========================================================================
# Input sentence =  black size 6, how much
#
# Line: black size 6, how much
# Sentiment(polarity=0.016666666666666677, subjectivity=0.31666666666666665)
# positive
#
# THE SENTENCE IS +ve
# 19
# ========================================================================
# Input sentence =  How much prize?
#
# Line: How much prize?
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 20
# ========================================================================
# Input sentence =  Prize plz..
#
# Line: Prize plz..
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 135
# ========================================================================
# Input sentence =  How much
#
# Line: How much
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 21
# ========================================================================
# Input sentence =  How much?
#
# Line: How much?
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 22
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 136
# ========================================================================
# Input sentence =  Lanje cu. hahahaha Rozita Ibrahim
#
# Line: Lanje cu.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: hahahaha Rozita Ibrahim
# Sentiment(polarity=0.2, subjectivity=0.5)
# positive
#
# THE SENTENCE IS +ve
# 23
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 137
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 138
# ========================================================================
# Input sentence =  Kiven Kigen hadiah 1
#
# Line: Kiven Kigen hadiah 1
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 139
# ========================================================================
# Input sentence =  1
#
# Line: 1
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 140
# ========================================================================
# Input sentence =  Luqman Hadi nak
#
# Line: Luqman Hadi nak
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 141
# ========================================================================
# Input sentence =  Shila Natasha 😂
#
# Line: Shila Natasha 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 142
# ========================================================================
# Input sentence =  Halizah ZahariJuliessa Ell 😂😂
#
# Line: Halizah ZahariJuliessa Ell 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 143
# ========================================================================
# Input sentence =  Astagaaaa ko x keja ka ni?😂😂
#
# Line: Astagaaaa ko x keja ka ni?😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 144
# ========================================================================
# Input sentence =  Halizah Zahari keja ba
#
# Line: Halizah Zahari keja ba
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 145
# ========================================================================
# Input sentence =  Celine Hong
#
# Line: Celine Hong
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 146
# ========================================================================
# Input sentence =  What a horrible styling!
#
# Line: What a horrible styling!
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Sentiment(polarity=-1.0, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 3
# ========================================================================
# Input sentence =  Pm
#
# Line: Pm
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 147
# ========================================================================
# Input sentence =  Hi Zalora. Can u check ur inbox?
#
# Line: Hi Zalora.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Can u check ur inbox?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 148
# ========================================================================
# Input sentence =  Dear Zalora, please find this post a request to provide (not the best but at least) essential customer service. This is the first time my order had a snag and the experience had bene an unpleasant one. Not only was I let down for never being able to receive my goods, it became painful to attempt communication with you.
#
# Line: Dear Zalora, please find this post a request to provide (not the best but at least) essential customer service.
# Sentiment(polarity=0.2333333333333333, subjectivity=0.3333333333333333)
# positive
#
# Line: This is the first time my order had a snag and the experience had bene an unpleasant one.
# Sentiment(polarity=-0.19999999999999996, subjectivity=0.6416666666666666)
# Sentiment(polarity=-0.19999999999999996, subjectivity=0.6416666666666666)
# negative
#
# Line: Not only was I let down for never being able to receive my goods, it became painful to attempt communication with you.
# Sentiment(polarity=-0.08888888888888888, subjectivity=0.7034722222222223)
# Sentiment(polarity=-0.08888888888888888, subjectivity=0.7034722222222223)
# negative
#
# THE SENTENCE IS -ve
# 4
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 149
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 150
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 151
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 152
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 153
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 154
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 155
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 156
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 157
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 158
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 159
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 160
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 161
# ========================================================================
# Input sentence =  I have ordered on the 13th (216935972) and yesterday my order was "refunded" in store credits without notice/explanation.
#
# Line: I have ordered on the 13th (216935972) and yesterday my order was "refunded" in store credits without notice/explanation.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 162
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 163
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 164
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 165
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 166
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 167
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 168
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 169
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 170
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 171
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 172
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 173
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 174
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 175
# ========================================================================
# Input sentence =  Customer service answered the phone, couldn't explain what happened and gave me only one option to provide my bank account details. He could not even understand that as a customer the thing I want most is simply my items. He said he will email me for account details immediately. He never sent the email. I wrote in an email to ask for an explanation. It's been a day ago and yet no answer.
#
# Line: Customer service answered the phone, couldn't explain what happened and gave me only one option to provide my bank account details.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: He could not even understand that as a customer the thing I want most is simply my items.
# Sentiment(polarity=0.25, subjectivity=0.4285714285714286)
# positive
#
# Line: He said he will email me for account details immediately.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: He never sent the email.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I wrote in an email to ask for an explanation.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: It's been a day ago and yet no answer.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 24
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 176
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 177
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 178
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 179
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 180
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 181
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 182
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 183
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 184
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 185
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 186
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 187
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 188
# ========================================================================
# Input sentence =  Now, after waiting for more than 24 hours since sending in the email, I am sufficiently disappointed by you. I really do not want anything to do with you anymore. Answer me and I just want my money back please.
#
# Line: Now, after waiting for more than 24 hours since sending in the email, I am sufficiently disappointed by you.
# Sentiment(polarity=-0.125, subjectivity=0.625)
# Sentiment(polarity=-0.125, subjectivity=0.625)
# negative
#
# Line: I really do not want anything to do with you anymore.
# Sentiment(polarity=-0.1, subjectivity=0.2)
# Sentiment(polarity=-0.1, subjectivity=0.2)
# negative
#
# Line: Answer me and I just want my money back please.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS -ve
# 5
# ========================================================================
# Input sentence =  always lying to consumer, the delivery process never happened but they put a lot stories ....... [[STICKER]]
#
# Line: always lying to consumer, the delivery process never happened but they put a lot stories ....... [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 189
# ========================================================================
# Input sentence =  Can’t believe this!   Come on #zalora !!!
#
# Line: Can’t believe this!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Come on #zalora !!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 190
# ========================================================================
# Input sentence =  Same happen to me order 3 item on the 12 of december in early morning
#
# Line: Same happen to me order 3 item on the 12 of december in early morning
# Sentiment(polarity=0.05, subjectivity=0.2125)
# positive
#
# THE SENTENCE IS +ve
# 25
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 191
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 192
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 193
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 194
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 195
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 196
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 197
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 198
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 199
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 200
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 201
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 202
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 203
# ========================================================================
# Input sentence =  Not even 1 item receive...
#
# Line: Not even 1 item receive...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 204
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 205
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 206
# ========================================================================
# ...
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3464
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3465
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3466
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3467
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3468
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3469
# ========================================================================
# Input sentence =  PROMO CODE: ZBAPQSZL
#
# Line: PROMO CODE: ZBAPQSZL
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3470
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3471
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3472
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3473
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3474
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3475
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3476
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3477
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3478
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3479
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3480
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3481
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3482
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3483
# ========================================================================
# Input sentence =  This promocode is valid ONLY FOR NEW CUSTOMER ON THEIR FIRST TIME ORDER at www.zalora.com.my
#
# Line: This promocode is valid ONLY FOR NEW CUSTOMER ON THEIR FIRST TIME ORDER at www.zalora.com.my
# Sentiment(polarity=0.12878787878787878, subjectivity=0.5959595959595959)
# positive
#
# THE SENTENCE IS +ve
# 467
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3484
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3485
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3486
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3487
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3488
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3489
# ========================================================================
# Input sentence =  (its an online store for both male and female)
#
# Line: (its an online store for both male and female)
# Sentiment(polarity=0.0, subjectivity=0.13333333333333333)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3490
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3491
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3492
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3493
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3494
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3495
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3496
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3497
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3498
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3499
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3500
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3501
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3502
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3503
# ========================================================================
# Input sentence =  This promocode can be use by different users who never order at zalora before.
#
# Line: This promocode can be use by different users who never order at zalora before.
# Sentiment(polarity=0.0, subjectivity=0.6)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3504
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3505
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3506
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3507
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3508
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3509
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3510
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3511
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3512
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3513
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3514
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3515
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3516
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3517
# ========================================================================
# Input sentence =  TIPS: make another account again to order if you want to use the promocode over and over again!
#
# Line: TIPS: make another account again to order if you want to use the promocode over and over again!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3518
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3519
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3520
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3521
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3522
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3523
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3524
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3525
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3526
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3527
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3528
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3529
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3530
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3531
# ========================================================================
# Input sentence =  This promocode can be use on anything, including item that's already has sale/discount! But of course, you can only use one promo code at once.
#
# Line: This promocode can be use on anything, including item that's already has sale/discount!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: But of course, you can only use one promo code at once.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3532
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3533
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3534
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3535
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3536
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3537
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3538
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3539
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3540
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3541
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3542
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3543
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3544
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3545
# ========================================================================
# Input sentence =  You can STILL USE this promocode even though its already been used by others.
#
# Line: You can STILL USE this promocode even though its already been used by others.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3546
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3547
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3548
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3549
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3550
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3551
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3552
# ========================================================================
# Input sentence =  So Don't forget to copy paste and share it with your everyone! #sharingiscaring [[SHARE]]
#
# Line: So Don't forget to copy paste and share it with your everyone!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: #sharingiscaring [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3553
# ========================================================================
# Input sentence =  Welcome to Malaysia's finest, reliable dating agency . We have a wonderful influential RICH SUGAR MUMMY/DADDY/ IN MALAYSIA, be among the people to get our exclusive connections. We are reliable and efficient in our job, get the opportunity to meet them. We have sugar mummies all over Malaysia who are willing to lavish money on you, with gifts, cars, house and even contracts connections, and even assist get a job, start calling now to get connected within 24 hours and make more money.Note:Applicant must be 18 years and above and must possesses a well notable personality.a night with your mom is RM4,000 when you are able to satisfy your mom emotionally.
#
# Line: Welcome to Malaysia's finest, reliable dating agency .
# Sentiment(polarity=0.8, subjectivity=0.9)
# positive
#
# Line: We have a wonderful influential RICH SUGAR MUMMY/DADDY/ IN MALAYSIA, be among the people to get our exclusive connections.
# Sentiment(polarity=0.6875, subjectivity=0.875)
# positive
#
# Line: We are reliable and efficient in our job, get the opportunity to meet them.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: We have sugar mummies all over Malaysia who are willing to lavish money on you, with gifts, cars, house and even contracts connections, and even assist get a job, start calling now to get connected within 24 hours and make more money.Note:Applicant must be 18 years and above and must possesses a well notable personality.a night with your mom is RM4,000 when you are able to satisfy your mom emotionally.
# Sentiment(polarity=0.2916666666666667, subjectivity=0.5208333333333334)
# positive
#
# THE SENTENCE IS +ve
# 468
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3554
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3555
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3556
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3557
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3558
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 3559
# ========================================================================
# Input sentence =  (Whatsapp+60143777309) Notable on whatsapp, as your agent can attend to you shortly. contact agent Mrs  Yang.
#
# Line: (Whatsapp+60143777309) Notable on whatsapp, as your agent can attend to you shortly.
# Sentiment(polarity=0.25, subjectivity=0.4)
# positive
#
# Line: contact agent Mrs  Yang.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 469
# ========================================================================
# Sentence Polarity Negative =  66
# Sentence Polarity Neutral =  3560
# Sentence Polarity Positive =  469

# %%
# txt to csv 
with open('SentimentZalora.txt', 'r',encoding ='UTF-8') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split("+;") for line in stripped if line)
    with open('sentiment(Zalora).csv', 'w',encoding ='UTF-8') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('text', 'sentiment'))
        writer.writerows(lines)

# %% [markdown]
# ### WordCloud Sentiment Analysis (Zalora)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split # function for splitting data to train and test sets

import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output

# %%
data = pd.read_csv('sentiment(Zalora).csv')
# Keeping only the neccessary columns
data = data[['text','sentiment']]

# %%
# Splitting the dataset into train and test set
train, test = train_test_split(data,test_size = 0.1)
# Removing neutral sentiments
train = train[train.sentiment != "neutral"]

# %%
train_pos = train[ train['sentiment'] == 'positive']
train_pos = train_pos['text']
train_neg = train[ train['sentiment'] == 'negative']
train_neg = train_neg['text']

def wordcloud_draw(data, color = 'black',name = 'Unknown', titl = 'Netural'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT' 
                            ])
    STOPWORDS = stopwords.words('english') + ['hahaha','much','email','zalora']
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=1800,
                      height=1400
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.title('Zalora'+titl+'Sentiment Analysis')
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.savefig(name, dpi=1000)
    plt.show()
    
print("Positive words")
wordcloud_draw(train_pos,'white','PositiveZalora.png','Positive')
print("Negative words")
wordcloud_draw(train_neg,'black','NegativeZalora.png','Negative')
# Out:
# Positive words
# Negative words

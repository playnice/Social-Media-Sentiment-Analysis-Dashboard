# %%
#convert the csv to txt
import csv
import pandas as pd
f=pd.read_csv("hahanoyume_facebook_comments5.csv")
keep_col = ['comment_message']
new_f = f[keep_col]
new_f.to_csv("hahanoyume_facebook_comments.csv", index=False)
with open('hahanoyumeComment.txt', "w",encoding = "UTF-8") as my_output_file:
    with open('hahanoyume_facebook_comments.csv', "r",encoding = "UTF-8") as my_input_file:
        [ my_output_file.write(" ".join(row)+'\n') for row in csv.reader(my_input_file)]
    my_output_file.close()

# %%
# Sentiment Analysis For HahaNoYume Comment
import matplotlib.pyplot as plt
from textblob import TextBlob
if __name__ == "__main__":
    
    Sentence_polarity_pos =0
    Sentence_polarity_neutral = 0
    Sentence_polarity_neg = 0
    

    inputfile = open("hahanoyumeComment.txt", "r",encoding = "UTF-8")
    outputfile = open("HNYFBTEXTSentimentBySentence.txt", "w",encoding = "UTF-8")


    for line in inputfile:
        try:
            
            Count_neg=0
            Count_neutral=0
            Count_pos=0
            
            #print(line)
            line = TextBlob(line)
           
            print ("Input sentence = ", line.strip() + "\n")
            outputfile.write("Input sentence = " + str(line).strip() +"\n")
            
            for each_line in line.sentences:
                print("Line: " + str(each_line))
                print(each_line.sentiment)
                outputfile.write(str(each_line.sentiment)+"\n")

                if each_line.sentiment.polarity < 0.0:
                    print(each_line.sentiment)
                    print ("negative" + "\n")
                    outputfile.write (str(each_line)+"\n")
                    outputfile.write ("negative\n\n")
                    Count_neg +=1
                elif each_line.sentiment.polarity == 0:
                    print ("neutral" + "\n")
                    outputfile.write (str(each_line)+"\n")
                    outputfile.write ("neutral\n\n")
                    Count_neutral +=1
                else:
                    print ("positive" + "\n")
                    outputfile.write (str(each_line)+"\n")
                    outputfile.write ("positive\n\n")
                    Count_pos +=1

                    
            if Count_pos > Count_neg: 
                print ("THE SENTENCE IS +ve")
                outputfile.write ("The sentence has Positive sentiment\n\n")
                Sentence_polarity_pos += 1
                print (Sentence_polarity_pos)

            elif (Count_pos == Count_neg):  
                print ("THE SENTENCE IS NEUTRAL")
                outputfile.write ("The sentence is Neutral\n\n")
                print (Sentence_polarity_neutral)
                Sentence_polarity_neutral += 1

            else:
                print ("THE SENTENCE IS -ve") 
                outputfile.write ("The sentence has Negative sentiment\n\n")
                Sentence_polarity_neg += 1
                print (Sentence_polarity_neg)
           
            outputfile.write("=============================================================\n")
            print("========================================================================")
        except:
            continue

    print ("Sentence Polarity Negative = ",Sentence_polarity_neg )
    print ("Sentence Polarity Neutral = ",Sentence_polarity_neutral )
    print ("Sentence Polarity Positive = ",Sentence_polarity_pos )
    outputfile.write ("Sentence Polarity Negative = %s \n"%Sentence_polarity_neg )
    outputfile.write ("Sentence Polarity Neutral = %s \n"%Sentence_polarity_neutral )
    outputfile.write ("Sentence Polarity Positive = %s \n"%Sentence_polarity_pos )

    Polarity = [1,3]
    LABELS = ["Positive", "Negative"]
    Count_polarity = [Sentence_polarity_pos, Sentence_polarity_neg]

    plt.xlabel('Polarity')
    plt.ylabel('Count')
    plt.title('HahaNoYume Sentiment Analysis')

    plt.grid(True)
    plt.bar(Polarity, Count_polarity, align='center')
    plt.xticks(Polarity, LABELS)
    plt.savefig('HNYSentiment.png', dpi=1000)
    plt.show()
    
outputfile.close()
# Out:
# Input sentence =  comment_message
#
# Line: comment_message
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 0
# ========================================================================
# Input sentence =  that’s me!
#
# Line: that’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 1
# ========================================================================
# Input sentence =  Hi Jenny! Pls check your inbox :)
#
# Line: Hi Jenny!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 1
# ========================================================================
# Input sentence =  thanks
#
# Line: thanks
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 2
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 2
# ========================================================================
# Input sentence =  Sent to your inbox :)
#
# Line: Sent to your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 3
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3
# ========================================================================
# Input sentence =  Pls check your inbox! :)
#
# Line: Pls check your inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 4
# ========================================================================
# Input sentence =  That's me!
#
# Line: That's me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 4
# ========================================================================
# Input sentence =  Pls check your inbox Patricia :)
#
# Line: Pls check your inbox Patricia :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 5
# ========================================================================
# Input sentence =  That's me!
#
# Line: That's me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 5
# ========================================================================
# Input sentence =  Pls check inbox :)
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 6
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 6
# ========================================================================
# Input sentence =  Sent to your inbox :)
#
# Line: Sent to your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 7
# ========================================================================
# Input sentence =  That's me
#
# Line: That's me
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 7
# ========================================================================
# Input sentence =  Pls check your inbox :)
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 8
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 8
# ========================================================================
# Input sentence =  Sent to your inbox :)
#
# Line: Sent to your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 9
# ========================================================================
# Input sentence =  That's me!
#
# Line: That's me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 9
# ========================================================================
# Input sentence =  Pls check your inbox :)
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 10
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 10
# ========================================================================
# Input sentence =  Pls check inbox :)
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 11
# ========================================================================
# Input sentence =  That’s Me!
#
# Line: That’s Me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 11
# ========================================================================
# Input sentence =  Sent you a message! :)
#
# Line: Sent you a message!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 12
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 12
# ========================================================================
# Input sentence =  Pls check your inbox :)
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 13
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 13
# ========================================================================
# Input sentence =  Pls check your inbox!
#
# Line: Pls check your inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 14
# ========================================================================
# Input sentence =  That's me!
#
# Line: That's me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 15
# ========================================================================
# Input sentence =  Pls check inbox Jeslyn! :)
#
# Line: Pls check inbox Jeslyn!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 14
# ========================================================================
# Input sentence =  That’s me
#
# Line: That’s me
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 16
# ========================================================================
# Input sentence =  Sent! Pls check inbox :)
#
# Line: Sent!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 15
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 17
# ========================================================================
# Input sentence =  Sent to your inbox! :)
#
# Line: Sent to your inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 16
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 18
# ========================================================================
# Input sentence =  Message sent! :)
#
# Line: Message sent!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 17
# ========================================================================
# Input sentence =  Angela Ang
#
# Line: Angela Ang
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 19
# ========================================================================
# Input sentence =  So cute!!
#
# Line: So cute!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 18
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 20
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 21
# ========================================================================
# Input sentence =  That’s me
#
# Line: That’s me
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 22
# ========================================================================
# Input sentence =  Tang Duong
#
# Line: Tang Duong
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 23
# ========================================================================
# Input sentence =  Tang Duong
#
# Line: Tang Duong
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 24
# ========================================================================
# Input sentence =  Gene Ng
#
# Line: Gene Ng
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 25
# ========================================================================
# Input sentence =  Mario Vuong 🤣
#
# Line: Mario Vuong 🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 26
# ========================================================================
# Input sentence =  Baby A: nipple nipple nipple nipple
#
# Line: Baby A: nipple nipple nipple nipple
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 27
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 28
# ========================================================================
# Input sentence =  Baby B: stop sucking my head you blob! Wahhhhhhhhhhhh
#
# Line: Baby B: stop sucking my head you blob!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Wahhhhhhhhhhhh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 29
# ========================================================================
# Input sentence =  Vivian Chua
#
# Line: Vivian Chua
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 30
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 31
# ========================================================================
# Input sentence =  Shop now: https://www.hahanoyume.com/collections/cny-collection [[SHARE]]
#
# Line: Shop now: https://www.hahanoyume.com/collections/cny-collection [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 32
# ========================================================================
# Input sentence =  Nina Zainorin ❤
#
# Line: Nina Zainorin ❤
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 33
# ========================================================================
# Input sentence =  Ouh so much happiness in one vid ❤️
#
# Line: Ouh so much happiness in one vid ❤️
# Sentiment(polarity=0.7, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 19
# ========================================================================
# Input sentence =  Pm me please 😍
#
# Line: Pm me please 😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 34
# ========================================================================
# Input sentence =  Hi Melisar! Pls check your inbox :)
#
# Line: Hi Melisar!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 20
# ========================================================================
# Input sentence =  Wow. Finally. Pm me please.
#
# Line: Wow.
# Sentiment(polarity=0.1, subjectivity=1.0)
# positive
#
# Line: Finally.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: Pm me please.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 21
# ========================================================================
# Input sentence =  Hi! Pls check inbox :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 22
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 35
# ========================================================================
# Input sentence =  Hi! Please check your inbox :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Please check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 23
# ========================================================================
# Input sentence =  Me pls
#
# Line: Me pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 36
# ========================================================================
# Input sentence =  Hi Geraldine! Pls check inbox :)
#
# Line: Hi Geraldine!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 24
# ========================================================================
# Input sentence =  me please
#
# Line: me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 37
# ========================================================================
# Input sentence =  Hi Jenny! Sent you the link. Pls check inbox :)
#
# Line: Hi Jenny!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Sent you the link.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 25
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 38
# ========================================================================
# Input sentence =  Hi Erica! Pls check your inbox :)
#
# Line: Hi Erica!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 26
# ========================================================================
# Input sentence =  Me please!
#
# Line: Me please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 39
# ========================================================================
# Input sentence =  Hi Madelene. Pls check your inbox :)
#
# Line: Hi Madelene.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 27
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 40
# ========================================================================
# Input sentence =  Hi Stanna! Pls check inbox :)
#
# Line: Hi Stanna!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 28
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 41
# ========================================================================
# Input sentence =  Hi! Pls check inbox :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 29
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 42
# ========================================================================
# Input sentence =  Hi Lilian! Please check your inbox! :)
#
# Line: Hi Lilian!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Please check your inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 30
# ========================================================================
# Input sentence =  Me please!
#
# Line: Me please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 43
# ========================================================================
# Input sentence =  Hi Melissa! Pls check inbox :)
#
# Line: Hi Melissa!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 31
# ========================================================================
# Input sentence =  me please!!
#
# Line: me please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 44
# ========================================================================
# Input sentence =  Hi Joyce. Pls check inbox :)
#
# Line: Hi Joyce.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 32
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 45
# ========================================================================
# Input sentence =  Pls check inbox! :)
#
# Line: Pls check inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 33
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 46
# ========================================================================
# Input sentence =  Hi! Please check inbox :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Please check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 34
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 47
# ========================================================================
# Input sentence =  Hi! Pls check inbox! :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 35
# ========================================================================
# Input sentence =  Me pls
#
# Line: Me pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 48
# ========================================================================
# Input sentence =  Hi Mandy! Pls check inbox :)
#
# Line: Hi Mandy!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 36
# ========================================================================
# Input sentence =  Where are these made?
#
# Line: Where are these made?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 49
# ========================================================================
# Input sentence =  Hi Christine! Using the softest cotton handpicked from Japan, these baby kimonos are ethically made in Malaysia ☺️
#
# Line: Hi Christine!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Using the softest cotton handpicked from Japan, these baby kimonos are ethically made in Malaysia ☺️
# Sentiment(polarity=0.2, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 37
# ========================================================================
# Input sentence =  Me please!
#
# Line: Me please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 50
# ========================================================================
# Input sentence =  Hi Tricia! Pls check inbox :)
#
# Line: Hi Tricia!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 38
# ========================================================================
# Input sentence =  Kimmy Dee
#
# Line: Kimmy Dee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 51
# ========================================================================
# Input sentence =  Angela Attente de Miracle
#
# Line: Angela Attente de Miracle
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 52
# ========================================================================
# Input sentence =  Yea! I love identical twins very much!!! They are so cute!!!! 😍😍😍
#
# Line: Yea!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I love identical twins very much!!!
# Sentiment(polarity=0.50390625, subjectivity=0.43)
# positive
#
# Line: They are so cute!!!!
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# Line: 😍😍😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 39
# ========================================================================
# Input sentence =  Right?? How I wish I have twins.... 😭
#
# Line: Right??
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# positive
#
# Line: How I wish I have twins.... 😭
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 40
# ========================================================================
# Input sentence =  Me too me too.. !🙋🏼
#
# Line: Me too me too.. !🙋🏼
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 53
# ========================================================================
# Input sentence =  So adorable!
#
# Line: So adorable!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 41
# ========================================================================
# Input sentence =  Jonathan Lee
#
# Line: Jonathan Lee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 54
# ========================================================================
# Input sentence =  AWESOME!!! 😍Loving it 😘can’t wait to receive mine 😉💋
#
# Line: AWESOME!!!
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# Line: 😍Loving it 😘can’t wait to receive mine 😉💋
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 42
# ========================================================================
# Input sentence =  Sending out on 22 Jan! Just in time for CNY 😘😘
#
# Line: Sending out on 22 Jan!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Just in time for CNY 😘😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 55
# ========================================================================
# Input sentence =  yes finally. waiting for mummy and son!
#
# Line: yes finally.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: waiting for mummy and son!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 56
# ========================================================================
# Input sentence =  Yes ! We do have mommy + son too! 😉
#
# Line: Yes !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: We do have mommy + son too!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😉
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 57
# ========================================================================
# Input sentence =  So nice!!!🌸😘
#
# Line: So nice!!
# Sentiment(polarity=0.9375, subjectivity=1.0)
# positive
#
# Line: !🌸😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 43
# ========================================================================
# Input sentence =  Thank you! 😘
#
# Line: Thank you!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 58
# ========================================================================
# Input sentence =  love it
#
# Line: love it
# Sentiment(polarity=0.5, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 44
# ========================================================================
# Input sentence =  Thank you so much! ❤️
#
# Line: Thank you so much!
# Sentiment(polarity=0.25, subjectivity=0.2)
# positive
#
# Line: ❤️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 45
# ========================================================================
# Input sentence =  Sweet thoughts.
#
# Line: Sweet thoughts.
# Sentiment(polarity=0.35, subjectivity=0.65)
# positive
#
# THE SENTENCE IS +ve
# 46
# ========================================================================
# Input sentence =  Belle Tay soon ~
#
# Line: Belle Tay soon ~
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 59
# ========================================================================
# Input sentence =  Ferris Yeo
#
# Line: Ferris Yeo
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 60
# ========================================================================
# Input sentence =  Tinny Ng
#
# Line: Tinny Ng
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 61
# ========================================================================
# Input sentence =  Beautiful gal
#
# Line: Beautiful gal
# Sentiment(polarity=0.85, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 47
# ========================================================================
# Input sentence =  Wong Xiao Hong Jecelyn Loh
#
# Line: Wong Xiao Hong Jecelyn Loh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 62
# ========================================================================
# Input sentence =  Btw, her eyes so big😲😁
#
# Line: Btw, her eyes so big😲😁
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 63
# ========================================================================
# Input sentence =  Where do i find mommy and son twinning?
#
# Line: Where do i find mommy and son twinning?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 64
# ========================================================================
# Input sentence =  Launching soon! Check your inbox ☺️
#
# Line: Launching soon!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Check your inbox ☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 65
# ========================================================================
# Input sentence =  Haha no yume 母の夢 keen to know too
#
# Line: Haha no yume 母の夢 keen to know too
# Sentiment(polarity=0.2, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 48
# ========================================================================
# Input sentence =  Chong Weiling sent you a pm! :)
#
# Line: Chong Weiling sent you a pm!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 49
# ========================================================================
# Input sentence =  I need to match with my son
#
# Line: I need to match with my son
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 66
# ========================================================================
# Input sentence =  We have mother + son twinning set too! ☺️
#
# Line: We have mother + son twinning set too!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: ☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 67
# ========================================================================
# Input sentence =  Very pretty!
#
# Line: Very pretty!
# Sentiment(polarity=0.40625, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 50
# ========================================================================
# Input sentence =  Shay Carr
#
# Line: Shay Carr
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 68
# ========================================================================
# Input sentence =  Pm!
#
# Line: Pm!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 69
# ========================================================================
# Input sentence =  Angela Ang
#
# Line: Angela Ang
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 70
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 71
# ========================================================================
# Input sentence =  Mother and son set!
#
# Line: Mother and son set!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 72
# ========================================================================
# Input sentence =  Scottie Sue True Have you seen this? So much fun.
#
# Line: Scottie Sue True Have you seen this?
# Sentiment(polarity=0.35, subjectivity=0.65)
# positive
#
# Line: So much fun.
# Sentiment(polarity=0.3, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 51
# ========================================================================
# Input sentence =  Yes please
#
# Line: Yes please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 73
# ========================================================================
# Input sentence =  Ronald Chong I can picture u doing this 😒
#
# Line: Ronald Chong I can picture u doing this 😒
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 74
# ========================================================================
# Input sentence =  :/
#
# Line: :/
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 1
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 75
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 76
# ========================================================================
# Input sentence =  Yes please
#
# Line: Yes please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 77
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 78
# ========================================================================
# Input sentence =  Yes please!!!
#
# Line: Yes please!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 79
# ========================================================================
# Input sentence =  Yes please 😊
#
# Line: Yes please 😊
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 80
# ========================================================================
# Input sentence =  Yes please
#
# Line: Yes please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 81
# ========================================================================
# Input sentence =  Yes please
#
# Line: Yes please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 82
# ========================================================================
# Input sentence =  Yes pls! 💕
#
# Line: Yes pls!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 💕
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 83
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 84
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 85
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 86
# ========================================================================
# Input sentence =  Kelvin George Thomas
#
# Line: Kelvin George Thomas
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 87
# ========================================================================
# Input sentence =  Christopher Taylor Knox
#
# Line: Christopher Taylor Knox
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 88
# ========================================================================
# Input sentence =  No sizes for boy 120-130cm?
#
# Line: No sizes for boy 120-130cm?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 89
# ========================================================================
# Input sentence =  Hi! He can fit in our 3-4T!
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: He can fit in our 3-4T!
# Sentiment(polarity=0.5, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 52
# ========================================================================
# Input sentence =  Haha no yume 母の夢 hi dear.. u mean your 3-4T is for 120-130cm kiddos?
#
# Line: Haha no yume 母の夢 hi dear.. u mean your 3-4T is for 120-130cm kiddos?
# Sentiment(polarity=-0.056249999999999994, subjectivity=0.49375)
# Sentiment(polarity=-0.056249999999999994, subjectivity=0.49375)
# negative
#
# THE SENTENCE IS -ve
# 2
# ========================================================================
# Input sentence =  BiBi yes!
#
# Line: BiBi yes!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 90
# ========================================================================
# Input sentence =  Haha no yume 母の夢 I also want a matching set with my boy... pls keep me posted 😘😍 thx
#
# Line: Haha no yume 母の夢 I also want a matching set with my boy... pls keep me posted 😘😍 thx
# Sentiment(polarity=0.2, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 53
# ========================================================================
# Input sentence =  Hi, can i know where can I view the collection for mommy & me sets for mummy and son? thanks.
#
# Line: Hi, can i know where can I view the collection for mommy & me sets for mummy and son?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: thanks.
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 54
# ========================================================================
# Input sentence =  Yes pls
#
# Line: Yes pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 91
# ========================================================================
# Input sentence =  Yes pls
#
# Line: Yes pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 92
# ========================================================================
# Input sentence =  Yes pls
#
# Line: Yes pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 93
# ========================================================================
# Input sentence =  Alexander Ang
#
# Line: Alexander Ang
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 94
# ========================================================================
# Input sentence =  Lixiang Ong
#
# Line: Lixiang Ong
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 95
# ========================================================================
# Input sentence =  We will be launching Mommy + Me matching sets after the New Year!! Sign up for our newsletter to receive first news (and a discount to shop of coz! 💁🏻)
#
# Line: We will be launching Mommy + Me matching sets after the New Year!!
# Sentiment(polarity=0.2130681818181818, subjectivity=0.45454545454545453)
# positive
#
# Line: Sign up for our newsletter to receive first news (and a discount to shop of coz!
# Sentiment(polarity=0.3125, subjectivity=0.3333333333333333)
# positive
#
# Line: 💁🏻)
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 55
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 96
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 97
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 98
# ========================================================================
# Input sentence =  Sign up for our mailing: http://eepurl.com/btlMH5 [[SHARE]]
#
# Line: Sign up for our mailing: http://eepurl.com/btlMH5 [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 99
# ========================================================================
# Input sentence =  We will be launching Mommy + Me matching sets after the New Year!! Sign up for our newsletter to receive first news (and a discount to shop of coz! 💁🏻)
#
# Line: We will be launching Mommy + Me matching sets after the New Year!!
# Sentiment(polarity=0.2130681818181818, subjectivity=0.45454545454545453)
# positive
#
# Line: Sign up for our newsletter to receive first news (and a discount to shop of coz!
# Sentiment(polarity=0.3125, subjectivity=0.3333333333333333)
# positive
#
# Line: 💁🏻)
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 56
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 100
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 101
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 102
# ========================================================================
# Input sentence =  Sign up for our mailing: http://eepurl.com/btlMH5
#
# Line: Sign up for our mailing: http://eepurl.com/btlMH5
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 103
# ========================================================================
# Input sentence =  so now i know.. im an A hole parent 😂😂
#
# Line: so now i know.. im an A hole parent 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 104
# ========================================================================
# Input sentence =  Perle Kam 😂😂😂
#
# Line: Perle Kam 😂😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 105
# ========================================================================
# Input sentence =  Jessey Ling
#
# Line: Jessey Ling
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 106
# ========================================================================
# Input sentence =  Definitely can relate to this for my boys😂😂 haha..
#
# Line: Definitely can relate to this for my boys😂😂 haha..
# Sentiment(polarity=0.1, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 57
# ========================================================================
# Input sentence =  Jysica Leron Chua Melissa Jonas Kok next time ur gal gal can wear tgt sure v cute!!
#
# Line: Jysica Leron Chua Melissa Jonas Kok next time ur gal gal can wear tgt sure v cute!
# Sentiment(polarity=0.375, subjectivity=0.6296296296296297)
# positive
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 58
# ========================================================================
# Input sentence =  這要去哪裡買啊？
#
# Line: 這要去哪裡買啊？
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 107
# ========================================================================
# Input sentence =  你好！你可以從這裡買: https://www.hahanoyume.com/collections/cny-collection [[SHARE]]
#
# Line: 你好！你可以從這裡買: https://www.hahanoyume.com/collections/cny-collection [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 108
# ========================================================================
# Input sentence =  So expensive 😭
#
# Line: So expensive 😭
# Sentiment(polarity=-0.5, subjectivity=0.7)
# Sentiment(polarity=-0.5, subjectivity=0.7)
# negative
#
# THE SENTENCE IS -ve
# 3
# ========================================================================
# Input sentence =  Hi! Our material is ethically made using premium Japanese cotton.  You may view our satisfied customers’ testimonials on our website and FB ☺️
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Our material is ethically made using premium Japanese cotton.
# Sentiment(polarity=0.1, subjectivity=0.3)
# positive
#
# Line: You may view our satisfied customers’ testimonials on our website and FB ☺️
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 59
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 109
# ========================================================================
# Input sentence =  https://www.hahanoyume.com/pages/customer-reviews
#
# Line: https://www.hahanoyume.com/pages/customer-reviews
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 110
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 111
# ========================================================================
# Input sentence =  You may use code SAVE20 to save 20% off your cart ❤️ Happy Chinese New Year! 😘 [[SHARE]]
#
# Line: You may use code SAVE20 to save 20% off your cart ❤️ Happy Chinese New Year!
# Sentiment(polarity=0.3234848484848485, subjectivity=0.48484848484848486)
# positive
#
# Line: 😘 [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 60
# ========================================================================
# Input sentence =  Mua đi
#
# Line: Mua đi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 112
# ========================================================================
# Input sentence =  60$ lan
#
# Line: 60$ lan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 113
# ========================================================================
# Input sentence =  10$ shipping nua
#
# Line: 10$ shipping nua
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 114
# ========================================================================
# Input sentence =  Thôi dẹp bà nó đi
#
# Line: Thôi dẹp bà nó đi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 115
# ========================================================================
# Input sentence =  Hi! Thanks for dropping by! Remember to use code SAVE20 to save 20% off your purchase! :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Thanks for dropping by!
# Sentiment(polarity=0.25, subjectivity=0.2)
# positive
#
# Line: Remember to use code SAVE20 to save 20% off your purchase!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 61
# ========================================================================
# Input sentence =  Aww cute
#
# Line: Aww cute
# Sentiment(polarity=0.4, subjectivity=0.95)
# positive
#
# THE SENTENCE IS +ve
# 62
# ========================================================================
# Input sentence =  Thank you!
#
# Line: Thank you!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 116
# ========================================================================
# Input sentence =  Michelle Wilson 🎎
#
# Line: Michelle Wilson 🎎
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 117
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 118
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 119
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 120
# ========================================================================
# Input sentence =  I can’t wait until Theo’s one arrives...
#
# Line: I can’t wait until Theo’s one arrives...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 121
# ========================================================================
# Input sentence =  💕 which one did you get for Theo?
#
# Line: 💕 which one did you get for Theo?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 122
# ========================================================================
# Input sentence =  Michelle Wilson Check IG... it’s super cute
#
# Line: Michelle Wilson Check IG... it’s super cute
# Sentiment(polarity=0.41666666666666663, subjectivity=0.8333333333333333)
# positive
#
# THE SENTENCE IS +ve
# 63
# ========================================================================
# Input sentence =  May bộ cho con nit ne Nhu Bui , nhin kung ghe. Bua c thay co đồ cho mẹ và bé luon .
#
# Line: May bộ cho con nit ne Nhu Bui , nhin kung ghe.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Bua c thay co đồ cho mẹ và bé luon .
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 123
# ========================================================================
# Input sentence =  Mary Vang Sang Thao this so cute!!! Check it out
#
# Line: Mary Vang Sang Thao this so cute!!!
# Sentiment(polarity=0.9765625, subjectivity=1.0)
# positive
#
# Line: Check it out
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 64
# ========================================================================
# Input sentence =  I still have one of those.
#
# Line: I still have one of those.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 124
# ========================================================================
# Input sentence =  Vicky Tran Junie would look so cute in one!
#
# Line: Vicky Tran Junie would look so cute in one!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 65
# ========================================================================
# Input sentence =  Yeah, so cute!! I got her some ao dai this tet too 🙂
#
# Line: Yeah, so cute!!
# Sentiment(polarity=0.78125, subjectivity=1.0)
# positive
#
# Line: I got her some ao dai this tet too 🙂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 66
# ========================================================================
# Input sentence =  Pearly Tan Gatab for Ethena!
#
# Line: Pearly Tan Gatab for Ethena!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 125
# ========================================================================
# Input sentence =  Tina Dinh de thuong ko na , muon cho Emma ma Mac quA
#
# Line: Tina Dinh de thuong ko na , muon cho Emma ma Mac quA
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 126
# ========================================================================
# Input sentence =  Mua đi
#
# Line: Mua đi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 127
# ========================================================================
# Input sentence =  OMG Kashia cute!!
#
# Line: OMG Kashia cute!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# ...
#
# Line: Last Friday I measure my boy size.
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# neutral
#
# Line: He seems can fit on the romper.
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# Line: Hopefully can fit him well!
# Sentiment(polarity=0.5, subjectivity=0.4)
# positive
#
# Line: Want him wear for photo shooting at studio.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Lol.
# Sentiment(polarity=0.8, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 297
# ========================================================================
# Input sentence =  You may also drop us a message on our FB page to place order ☺️
#
# Line: You may also drop us a message on our FB page to place order ☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 786
# ========================================================================
# Input sentence =  I hope they hav 4yo size!!!!!!!
#
# Line: I hope they hav 4yo size!!!!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 787
# ========================================================================
# Input sentence =  Hi Xiao Wei! Our 2-3 yo tops and dresses can fit 4 yo very comfortably ☺️
#
# Line: Hi Xiao Wei!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Our 2-3 yo tops and dresses can fit 4 yo very comfortably ☺️
# Sentiment(polarity=0.46, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 298
# ========================================================================
# Input sentence =  18-24mth?
#
# Line: 18-24mth?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 788
# ========================================================================
# Input sentence =  Hi Priscilla. We will launch our 1-3 yo tops and dresses range in sept. Will announce when it'll be available in TriBeCa as well. Stay tuned! ☺️
#
# Line: Hi Priscilla.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: We will launch our 1-3 yo tops and dresses range in sept. Will announce when it'll be available in TriBeCa as well.
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# Line: Stay tuned!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: ☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 299
# ========================================================================
# Input sentence =  Ooh nice! At my friend's shop.
#
# Line: Ooh nice!
# Sentiment(polarity=0.75, subjectivity=1.0)
# positive
#
# Line: At my friend's shop.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 300
# ========================================================================
# Input sentence =  Love them!
#
# Line: Love them!
# Sentiment(polarity=0.625, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 301
# ========================================================================
# Input sentence =  Carmen Yap
#
# Line: Carmen Yap
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 789
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 790
# ========================================================================
# Input sentence =  Loh Sook Kuan
#
# Line: Loh Sook Kuan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 791
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 792
# ========================================================================
# Input sentence =  Cheryl Chin
#
# Line: Cheryl Chin
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 793
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 794
# ========================================================================
# Input sentence =  Cheryl Yaw
#
# Line: Cheryl Yaw
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 795
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 796
# ========================================================================
# Input sentence =  Sandy Ong-Lee
#
# Line: Sandy Ong-Lee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 797
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 798
# ========================================================================
# Input sentence =  Jennics Tan
#
# Line: Jennics Tan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 799
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 800
# ========================================================================
# Input sentence =  Annie Xavier
#
# Line: Annie Xavier
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 801
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 802
# ========================================================================
# Input sentence =  Annie Ngiam
#
# Line: Annie Ngiam
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 803
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 804
# ========================================================================
# Input sentence =  Nathalie Tung
#
# Line: Nathalie Tung
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 805
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 806
# ========================================================================
# Input sentence =  Debbie See
#
# Line: Debbie See
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 807
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 808
# ========================================================================
# Input sentence =  Venus Goh
#
# Line: Venus Goh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 809
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 810
# ========================================================================
# Input sentence =  Cheng Lee
#
# Line: Cheng Lee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 811
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 812
# ========================================================================
# Input sentence =  Chua Ching Yee
#
# Line: Chua Ching Yee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 813
# ========================================================================
# Input sentence =  Ker Sin Gladys
#
# Line: Ker Sin Gladys
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 814
# ========================================================================
# Input sentence =  very enjoying reading each of your blog... and I do feel the same... having 1 kid making different to the relationship.. Emm you're not selfish la.. one is easy to cope compared to 2... especially nowadays everything is just $$$$ ...
#
# Line: very enjoying reading each of your blog... and I do feel the same... having 1 kid making different to the relationship.. Emm you're not selfish la.. one is easy to cope compared to 2... especially nowadays everything is just $$$$ ...
# Sentiment(polarity=0.22222222222222224, subjectivity=0.7230555555555555)
# positive
#
# THE SENTENCE IS +ve
# 302
# ========================================================================
# Input sentence =  Konichiwa  Eva is hijo ni kawaii :) muahhhh
#
# Line: Konichiwa  Eva is hijo ni kawaii :) muahhhh
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 303
# ========================================================================
# Input sentence =  Yes please! Can't wait to order! 😍😍😍
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Can't wait to order!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😍😍😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 815
# ========================================================================
# Input sentence =  You're an awesome lady! Your daughter will grow up seeing you as her role model I believe. Keep up your great work!
#
# Line: You're an awesome lady!
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# Line: Your daughter will grow up seeing you as her role model I believe.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Keep up your great work!
# Sentiment(polarity=1.0, subjectivity=0.75)
# positive
#
# THE SENTENCE IS +ve
# 304
# ========================================================================
# Input sentence =  Good to share....
#
# Line: Good to share....
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
#
# THE SENTENCE IS +ve
# 305
# ========================================================================
# Input sentence =  Hi five to all of us here 👋🏼👋🏼
#
# Line: Hi five to all of us here 👋🏼👋🏼
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 816
# ========================================================================
# Input sentence =  u r a good mama:)
#
# Line: u r a good mama:)
# Sentiment(polarity=0.6, subjectivity=0.8)
# positive
#
# THE SENTENCE IS +ve
# 306
# ========================================================================
# Input sentence =  Pic courtesy of Lee Tze Leong. Thanks for the amazing pic! 😃
#
# Line: Pic courtesy of Lee Tze Leong.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Thanks for the amazing pic!
# Sentiment(polarity=0.4750000000000001, subjectivity=0.55)
# positive
# Line: 😃
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 307
# ========================================================================
# Input sentence =  See you Ruby! 😘
#
# Line: See you Ruby!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 817
# ========================================================================
# Input sentence =  Where is the bazaar
#
# Line: Where is the bazaar
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 818
# ========================================================================
# Input sentence =  Wisma WIM, TTDI. Drive there using Waze: https://waze.to/lr/hw283bsnr9 [[SHARE]]
#
# Line: Wisma WIM, TTDI.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Drive there using Waze: https://waze.to/lr/hw283bsnr9 [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 819
# ========================================================================
# Input sentence =  Tis 1 cute
#
# Line: Tis 1 cute
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 308
# ========================================================================
# Input sentence =  Please bring bigger sizes please. Plan to buy for my 2 y.o daughter. See you guys tomorrow at ttdi! :)
#
# Line: Please bring bigger sizes please.
# Sentiment(polarity=0.0, subjectivity=0.5)
# neutral
#
# Line: Plan to buy for my 2 y.o daughter.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: See you guys tomorrow at ttdi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 309
# ========================================================================
# Input sentence =  Such a cute pic!!
#
# Line: Such a cute pic!
# Sentiment(polarity=0.3125, subjectivity=0.75)
# positive
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 310
# ========================================================================
# Input sentence =  Marcus Wong this is so cute
#
# Line: Marcus Wong this is so cute
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 311
# ========================================================================
# Input sentence =  Veekie Chew
#
# Line: Veekie Chew
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 820
# ========================================================================
# Input sentence =  Superb idea! And those 🎀 are so pretty!
#
# Line: Superb idea!
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# Line: And those 🎀 are so pretty!
# Sentiment(polarity=0.3125, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 312
# ========================================================================
# Input sentence =  So cute!
#
# Line: So cute!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 313
# ========================================================================
# Input sentence =  Thanks Beatrice! 😃
#
# Line: Thanks Beatrice!
# Sentiment(polarity=0.25, subjectivity=0.2)
# positive
#
# Line: 😃
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 314
# ========================================================================
# Input sentence =  Nice
#
# Line: Nice
# Sentiment(polarity=0.6, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 315
# ========================================================================
# Input sentence =  So cute
#
# Line: So cute
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 316
# ========================================================================
# Input sentence =  Melvyn
#
# Line: Melvyn
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 821
# ========================================================================
# Input sentence =  Jasper Maa
#
# Line: Jasper Maa
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 822
# ========================================================================
# Input sentence =  Hi ,may I know u have kimono for girl age 5 n baby boy for age 3?
#
# Line: Hi ,may I know u have kimono for girl age 5 n baby boy for age 3?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 823
# ========================================================================
# Input sentence =  Hi Crystal. We are launching kimono tops and dresses for 1-3 year old in end Aug/ early Sept. ☺️ We don't have any line up for 5 yo at the moment
#
# Line: Hi Crystal.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: We are launching kimono tops and dresses for 1-3 year old in end Aug/ early Sept. ☺️ We don't have any line up for 5 yo at the moment
# Sentiment(polarity=0.1, subjectivity=0.25)
# positive
#
# THE SENTENCE IS +ve
# 317
# ========================================================================
# Input sentence =  In 40 years time, ur child will thank you for it ;)
#
# Line: In 40 years time, ur child will thank you for it ;)
# Sentiment(polarity=0.25, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 318
# ========================================================================
# Input sentence =  Nice Marjorie :) I am in Mrs CEO category also...hehe :)
#
# Line: Nice Marjorie :) I am in Mrs CEO category also...hehe :)
# Sentiment(polarity=0.5333333333333333, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 319
# ========================================================================
# Input sentence =  You're good mama.. hahhaha I didn't prepare anything to Emillie as she only starts her soft food when she was 2 yrs old.. All the while only milk...
#
# Line: You're good mama.. hahhaha I didn't prepare anything to Emillie as she only starts her soft food when she was 2 yrs old.. All the while only milk...
# Sentiment(polarity=0.18, subjectivity=0.6300000000000001)
# positive
#
# THE SENTENCE IS +ve
# 320
# ========================================================================
# Sentence Polarity Negative =  35
# Sentence Polarity Neutral =  824
# Sentence Polarity Positive =  320

# %%
# WordCloud for HahaNoYume Comment
from os import path
from wordcloud import WordCloud
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
convert_wordcloud = 'hahanoyumeComment.txt'

# Read the whole text.
text = open(convert_wordcloud,encoding ="UTF-8").read()

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:

stop_Words = stopwords.words('english') + ['inbox', 'please', 'yes','check', 'hi','https', 'www', 'com',
                                         'pls','check','inbox','hi','that','http','lol','GIF',"That's",'母の夢',
                                         'nipple']
wordcloud = WordCloud(stopwords=stop_Words,
                      background_color='black',
                      width=1800,
                      height=1400).generate(text.lower())
plt.title("HahaNoYume Comment WordCloud")
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig('hahanoyumeCommentWordCloud.png', dpi=1000)
plt.show()

# %%
# Sentiment Analysis For WordCloud (hahanoyume)
import matplotlib.pyplot as plt
from textblob import TextBlob
if __name__ == "__main__":
    
    Sentence_polarity_pos =0
    Sentence_polarity_neutral = 0
    Sentence_polarity_neg = 0
    

    inputfile = open("hahanoyumeComment.txt", "r",encoding = "UTF-8")
    outputfile = open("Sentimenthahanoyume.txt", "w",encoding = "UTF-8")


    for line in inputfile:
        try:
            
            Count_neg=0
            Count_neutral=0
            Count_pos=0
            
            #print(line)
            line = TextBlob(line)
           
            print ("Input sentence = ", line.strip() + "\n")
            
            for each_line in line.sentences:
                print("Line: " + str(each_line))
                print(each_line.sentiment)
                outputfile.write(str(each_line)+"+"+";")

                if each_line.sentiment.polarity < 0.0:
                    print(each_line.sentiment)
                    print ("negative" + "\n")
                    outputfile.write ("negative\n")
                    Count_neg +=1
                elif each_line.sentiment.polarity == 0:
                    print ("neutral" + "\n")
                    outputfile.write ("neutral\n")
                    Count_neutral +=1
                else:
                    print ("positive" + "\n")
                    outputfile.write ("positive\n")
                    Count_pos +=1

                    
            if Count_pos > Count_neg: 
                print ("THE SENTENCE IS +ve")
                Sentence_polarity_pos += 1
                print (Sentence_polarity_pos)

            elif (Count_pos == Count_neg):  
                print ("THE SENTENCE IS NEUTRAL")
                print (Sentence_polarity_neutral)
                Sentence_polarity_neutral += 1

            else:
                print ("THE SENTENCE IS -ve") 
                Sentence_polarity_neg += 1
                print (Sentence_polarity_neg)
           
            print("========================================================================")
        except:
            continue

    print ("Sentence Polarity Negative = ",Sentence_polarity_neg )
    print ("Sentence Polarity Neutral = ",Sentence_polarity_neutral )
    print ("Sentence Polarity Positive = ",Sentence_polarity_pos )
    Polarity = [1,3]
    LABELS = ["Positive", "Negative"]
    Count_polarity = [Sentence_polarity_pos, Sentence_polarity_neg]

    plt.xlabel('Polarity')
    plt.ylabel('Count')
    plt.title('hahanoyume Sentiment Analysis')

    plt.grid(True)
    plt.bar(Polarity, Count_polarity, align='center')
    plt.xticks(Polarity, LABELS)
    plt.savefig('hahanoyumeSentiment.png', dpi=1000)
    plt.show()
    
outputfile.close()
# Out:
# Input sentence =  comment_message
#
# Line: comment_message
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 0
# ========================================================================
# Input sentence =  that’s me!
#
# Line: that’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 1
# ========================================================================
# Input sentence =  Hi Jenny! Pls check your inbox :)
#
# Line: Hi Jenny!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 1
# ========================================================================
# Input sentence =  thanks
#
# Line: thanks
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 2
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 2
# ========================================================================
# Input sentence =  Sent to your inbox :)
#
# Line: Sent to your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 3
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 3
# ========================================================================
# Input sentence =  Pls check your inbox! :)
#
# Line: Pls check your inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 4
# ========================================================================
# Input sentence =  That's me!
#
# Line: That's me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 4
# ========================================================================
# Input sentence =  Pls check your inbox Patricia :)
#
# Line: Pls check your inbox Patricia :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 5
# ========================================================================
# Input sentence =  That's me!
#
# Line: That's me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 5
# ========================================================================
# Input sentence =  Pls check inbox :)
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 6
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 6
# ========================================================================
# Input sentence =  Sent to your inbox :)
#
# Line: Sent to your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 7
# ========================================================================
# Input sentence =  That's me
#
# Line: That's me
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 7
# ========================================================================
# Input sentence =  Pls check your inbox :)
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 8
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 8
# ========================================================================
# Input sentence =  Sent to your inbox :)
#
# Line: Sent to your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 9
# ========================================================================
# Input sentence =  That's me!
#
# Line: That's me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 9
# ========================================================================
# Input sentence =  Pls check your inbox :)
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 10
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 10
# ========================================================================
# Input sentence =  Pls check inbox :)
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 11
# ========================================================================
# Input sentence =  That’s Me!
#
# Line: That’s Me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 11
# ========================================================================
# Input sentence =  Sent you a message! :)
#
# Line: Sent you a message!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 12
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 12
# ========================================================================
# Input sentence =  Pls check your inbox :)
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 13
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 13
# ========================================================================
# Input sentence =  Pls check your inbox!
#
# Line: Pls check your inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 14
# ========================================================================
# Input sentence =  That's me!
#
# Line: That's me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 15
# ========================================================================
# Input sentence =  Pls check inbox Jeslyn! :)
#
# Line: Pls check inbox Jeslyn!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 14
# ========================================================================
# Input sentence =  That’s me
#
# Line: That’s me
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 16
# ========================================================================
# Input sentence =  Sent! Pls check inbox :)
#
# Line: Sent!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 15
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 17
# ========================================================================
# Input sentence =  Sent to your inbox! :)
#
# Line: Sent to your inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 16
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 18
# ========================================================================
# Input sentence =  Message sent! :)
#
# Line: Message sent!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 17
# ========================================================================
# Input sentence =  Angela Ang
#
# Line: Angela Ang
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 19
# ========================================================================
# Input sentence =  So cute!!
#
# Line: So cute!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 18
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 20
# ========================================================================
# Input sentence =  That’s me!
#
# Line: That’s me!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 21
# ========================================================================
# Input sentence =  That’s me
#
# Line: That’s me
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 22
# ========================================================================
# Input sentence =  Tang Duong
#
# Line: Tang Duong
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 23
# ========================================================================
# Input sentence =  Tang Duong
#
# Line: Tang Duong
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 24
# ========================================================================
# Input sentence =  Gene Ng
#
# Line: Gene Ng
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 25
# ========================================================================
# Input sentence =  Mario Vuong 🤣
#
# Line: Mario Vuong 🤣
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 26
# ========================================================================
# Input sentence =  Baby A: nipple nipple nipple nipple
#
# Line: Baby A: nipple nipple nipple nipple
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 27
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 28
# ========================================================================
# Input sentence =  Baby B: stop sucking my head you blob! Wahhhhhhhhhhhh
#
# Line: Baby B: stop sucking my head you blob!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Wahhhhhhhhhhhh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 29
# ========================================================================
# Input sentence =  Vivian Chua
#
# Line: Vivian Chua
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 30
# ========================================================================
# Input sentence =  [[STICKER]]
#
# Line: [[STICKER]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 31
# ========================================================================
# Input sentence =  Shop now: https://www.hahanoyume.com/collections/cny-collection [[SHARE]]
#
# Line: Shop now: https://www.hahanoyume.com/collections/cny-collection [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 32
# ========================================================================
# Input sentence =  Nina Zainorin ❤
#
# Line: Nina Zainorin ❤
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 33
# ========================================================================
# Input sentence =  Ouh so much happiness in one vid ❤️
#
# Line: Ouh so much happiness in one vid ❤️
# Sentiment(polarity=0.7, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 19
# ========================================================================
# Input sentence =  Pm me please 😍
#
# Line: Pm me please 😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 34
# ========================================================================
# Input sentence =  Hi Melisar! Pls check your inbox :)
#
# Line: Hi Melisar!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 20
# ========================================================================
# Input sentence =  Wow. Finally. Pm me please.
#
# Line: Wow.
# Sentiment(polarity=0.1, subjectivity=1.0)
# positive
#
# Line: Finally.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: Pm me please.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 21
# ========================================================================
# Input sentence =  Hi! Pls check inbox :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 22
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 35
# ========================================================================
# Input sentence =  Hi! Please check your inbox :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Please check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 23
# ========================================================================
# Input sentence =  Me pls
#
# Line: Me pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 36
# ========================================================================
# Input sentence =  Hi Geraldine! Pls check inbox :)
#
# Line: Hi Geraldine!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 24
# ========================================================================
# Input sentence =  me please
#
# Line: me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 37
# ========================================================================
# Input sentence =  Hi Jenny! Sent you the link. Pls check inbox :)
#
# Line: Hi Jenny!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Sent you the link.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 25
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 38
# ========================================================================
# Input sentence =  Hi Erica! Pls check your inbox :)
#
# Line: Hi Erica!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 26
# ========================================================================
# Input sentence =  Me please!
#
# Line: Me please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 39
# ========================================================================
# Input sentence =  Hi Madelene. Pls check your inbox :)
#
# Line: Hi Madelene.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check your inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 27
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 40
# ========================================================================
# Input sentence =  Hi Stanna! Pls check inbox :)
#
# Line: Hi Stanna!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 28
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 41
# ========================================================================
# Input sentence =  Hi! Pls check inbox :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 29
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 42
# ========================================================================
# Input sentence =  Hi Lilian! Please check your inbox! :)
#
# Line: Hi Lilian!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Please check your inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 30
# ========================================================================
# Input sentence =  Me please!
#
# Line: Me please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 43
# ========================================================================
# Input sentence =  Hi Melissa! Pls check inbox :)
#
# Line: Hi Melissa!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 31
# ========================================================================
# Input sentence =  me please!!
#
# Line: me please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 44
# ========================================================================
# Input sentence =  Hi Joyce. Pls check inbox :)
#
# Line: Hi Joyce.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 32
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 45
# ========================================================================
# Input sentence =  Pls check inbox! :)
#
# Line: Pls check inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 33
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 46
# ========================================================================
# Input sentence =  Hi! Please check inbox :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Please check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 34
# ========================================================================
# Input sentence =  Me please
#
# Line: Me please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 47
# ========================================================================
# Input sentence =  Hi! Pls check inbox! :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 35
# ========================================================================
# Input sentence =  Me pls
#
# Line: Me pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 48
# ========================================================================
# Input sentence =  Hi Mandy! Pls check inbox :)
#
# Line: Hi Mandy!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 36
# ========================================================================
# Input sentence =  Where are these made?
#
# Line: Where are these made?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 49
# ========================================================================
# Input sentence =  Hi Christine! Using the softest cotton handpicked from Japan, these baby kimonos are ethically made in Malaysia ☺️
#
# Line: Hi Christine!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Using the softest cotton handpicked from Japan, these baby kimonos are ethically made in Malaysia ☺️
# Sentiment(polarity=0.2, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 37
# ========================================================================
# Input sentence =  Me please!
#
# Line: Me please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 50
# ========================================================================
# Input sentence =  Hi Tricia! Pls check inbox :)
#
# Line: Hi Tricia!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Pls check inbox :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 38
# ========================================================================
# Input sentence =  Kimmy Dee
#
# Line: Kimmy Dee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 51
# ========================================================================
# Input sentence =  Angela Attente de Miracle
#
# Line: Angela Attente de Miracle
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 52
# ========================================================================
# Input sentence =  Yea! I love identical twins very much!!! They are so cute!!!! 😍😍😍
#
# Line: Yea!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: I love identical twins very much!!!
# Sentiment(polarity=0.50390625, subjectivity=0.43)
# positive
#
# Line: They are so cute!!!!
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# Line: 😍😍😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 39
# ========================================================================
# Input sentence =  Right?? How I wish I have twins.... 😭
#
# Line: Right??
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# positive
#
# Line: How I wish I have twins.... 😭
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 40
# ========================================================================
# Input sentence =  Me too me too.. !🙋🏼
#
# Line: Me too me too.. !🙋🏼
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 53
# ========================================================================
# Input sentence =  So adorable!
#
# Line: So adorable!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 41
# ========================================================================
# Input sentence =  Jonathan Lee
#
# Line: Jonathan Lee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 54
# ========================================================================
# Input sentence =  AWESOME!!! 😍Loving it 😘can’t wait to receive mine 😉💋
#
# Line: AWESOME!!!
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# Line: 😍Loving it 😘can’t wait to receive mine 😉💋
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 42
# ========================================================================
# Input sentence =  Sending out on 22 Jan! Just in time for CNY 😘😘
#
# Line: Sending out on 22 Jan!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Just in time for CNY 😘😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 55
# ========================================================================
# Input sentence =  yes finally. waiting for mummy and son!
#
# Line: yes finally.
# Sentiment(polarity=0.0, subjectivity=1.0)
# neutral
#
# Line: waiting for mummy and son!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 56
# ========================================================================
# Input sentence =  Yes ! We do have mommy + son too! 😉
#
# Line: Yes !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: We do have mommy + son too!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😉
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 57
# ========================================================================
# Input sentence =  So nice!!!🌸😘
#
# Line: So nice!!
# Sentiment(polarity=0.9375, subjectivity=1.0)
# positive
#
# Line: !🌸😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 43
# ========================================================================
# Input sentence =  Thank you! 😘
#
# Line: Thank you!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 58
# ========================================================================
# Input sentence =  love it
#
# Line: love it
# Sentiment(polarity=0.5, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 44
# ========================================================================
# Input sentence =  Thank you so much! ❤️
#
# Line: Thank you so much!
# Sentiment(polarity=0.25, subjectivity=0.2)
# positive
#
# Line: ❤️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 45
# ========================================================================
# Input sentence =  Sweet thoughts.
#
# Line: Sweet thoughts.
# Sentiment(polarity=0.35, subjectivity=0.65)
# positive
#
# THE SENTENCE IS +ve
# 46
# ========================================================================
# Input sentence =  Belle Tay soon ~
#
# Line: Belle Tay soon ~
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 59
# ========================================================================
# Input sentence =  Ferris Yeo
#
# Line: Ferris Yeo
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 60
# ========================================================================
# Input sentence =  Tinny Ng
#
# Line: Tinny Ng
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 61
# ========================================================================
# Input sentence =  Beautiful gal
#
# Line: Beautiful gal
# Sentiment(polarity=0.85, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 47
# ========================================================================
# Input sentence =  Wong Xiao Hong Jecelyn Loh
#
# Line: Wong Xiao Hong Jecelyn Loh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 62
# ========================================================================
# Input sentence =  Btw, her eyes so big😲😁
#
# Line: Btw, her eyes so big😲😁
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 63
# ========================================================================
# Input sentence =  Where do i find mommy and son twinning?
#
# Line: Where do i find mommy and son twinning?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 64
# ========================================================================
# Input sentence =  Launching soon! Check your inbox ☺️
#
# Line: Launching soon!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Check your inbox ☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 65
# ========================================================================
# Input sentence =  Haha no yume 母の夢 keen to know too
#
# Line: Haha no yume 母の夢 keen to know too
# Sentiment(polarity=0.2, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 48
# ========================================================================
# Input sentence =  Chong Weiling sent you a pm! :)
#
# Line: Chong Weiling sent you a pm!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 49
# ========================================================================
# Input sentence =  I need to match with my son
#
# Line: I need to match with my son
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 66
# ========================================================================
# Input sentence =  We have mother + son twinning set too! ☺️
#
# Line: We have mother + son twinning set too!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: ☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 67
# ========================================================================
# Input sentence =  Very pretty!
#
# Line: Very pretty!
# Sentiment(polarity=0.40625, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 50
# ========================================================================
# Input sentence =  Shay Carr
#
# Line: Shay Carr
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 68
# ========================================================================
# Input sentence =  Pm!
#
# Line: Pm!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 69
# ========================================================================
# Input sentence =  Angela Ang
#
# Line: Angela Ang
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 70
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 71
# ========================================================================
# Input sentence =  Mother and son set!
#
# Line: Mother and son set!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 72
# ========================================================================
# Input sentence =  Scottie Sue True Have you seen this? So much fun.
#
# Line: Scottie Sue True Have you seen this?
# Sentiment(polarity=0.35, subjectivity=0.65)
# positive
#
# Line: So much fun.
# Sentiment(polarity=0.3, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 51
# ========================================================================
# Input sentence =  Yes please
#
# Line: Yes please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 73
# ========================================================================
# Input sentence =  Ronald Chong I can picture u doing this 😒
#
# Line: Ronald Chong I can picture u doing this 😒
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 74
# ========================================================================
# Input sentence =  :/
#
# Line: :/
# Sentiment(polarity=-0.25, subjectivity=1.0)
# Sentiment(polarity=-0.25, subjectivity=1.0)
# negative
#
# THE SENTENCE IS -ve
# 1
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 75
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 76
# ========================================================================
# Input sentence =  Yes please
#
# Line: Yes please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 77
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 78
# ========================================================================
# Input sentence =  Yes please!!!
#
# Line: Yes please!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 79
# ========================================================================
# Input sentence =  Yes please 😊
#
# Line: Yes please 😊
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 80
# ========================================================================
# Input sentence =  Yes please
#
# Line: Yes please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 81
# ========================================================================
# Input sentence =  Yes please
#
# Line: Yes please
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 82
# ========================================================================
# Input sentence =  Yes pls! 💕
#
# Line: Yes pls!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 💕
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 83
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 84
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 85
# ========================================================================
# Input sentence =  Yes please!
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 86
# ========================================================================
# Input sentence =  Kelvin George Thomas
#
# Line: Kelvin George Thomas
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 87
# ========================================================================
# Input sentence =  Christopher Taylor Knox
#
# Line: Christopher Taylor Knox
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 88
# ========================================================================
# Input sentence =  No sizes for boy 120-130cm?
#
# Line: No sizes for boy 120-130cm?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# THE SENTENCE IS NEUTRAL
# 89
# ========================================================================
# Input sentence =  Hi! He can fit in our 3-4T!
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: He can fit in our 3-4T!
# Sentiment(polarity=0.5, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 52
# ========================================================================
# Input sentence =  Haha no yume 母の夢 hi dear.. u mean your 3-4T is for 120-130cm kiddos?
#
# Line: Haha no yume 母の夢 hi dear.. u mean your 3-4T is for 120-130cm kiddos?
# Sentiment(polarity=-0.056249999999999994, subjectivity=0.49375)
# Sentiment(polarity=-0.056249999999999994, subjectivity=0.49375)
# negative
#
# THE SENTENCE IS -ve
# 2
# ========================================================================
# Input sentence =  BiBi yes!
#
# Line: BiBi yes!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 90
# ========================================================================
# Input sentence =  Haha no yume 母の夢 I also want a matching set with my boy... pls keep me posted 😘😍 thx
#
# Line: Haha no yume 母の夢 I also want a matching set with my boy... pls keep me posted 😘😍 thx
# Sentiment(polarity=0.2, subjectivity=0.3)
# positive
#
# THE SENTENCE IS +ve
# 53
# ========================================================================
# Input sentence =  Hi, can i know where can I view the collection for mommy & me sets for mummy and son? thanks.
#
# Line: Hi, can i know where can I view the collection for mommy & me sets for mummy and son?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: thanks.
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
#
# THE SENTENCE IS +ve
# 54
# ========================================================================
# Input sentence =  Yes pls
#
# Line: Yes pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 91
# ========================================================================
# Input sentence =  Yes pls
#
# Line: Yes pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 92
# ========================================================================
# Input sentence =  Yes pls
#
# Line: Yes pls
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 93
# ========================================================================
# Input sentence =  Alexander Ang
#
# Line: Alexander Ang
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 94
# ========================================================================
# Input sentence =  Lixiang Ong
#
# Line: Lixiang Ong
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 95
# ========================================================================
# Input sentence =  We will be launching Mommy + Me matching sets after the New Year!! Sign up for our newsletter to receive first news (and a discount to shop of coz! 💁🏻)
#
# Line: We will be launching Mommy + Me matching sets after the New Year!!
# Sentiment(polarity=0.2130681818181818, subjectivity=0.45454545454545453)
# positive
#
# Line: Sign up for our newsletter to receive first news (and a discount to shop of coz!
# Sentiment(polarity=0.3125, subjectivity=0.3333333333333333)
# positive
#
# Line: 💁🏻)
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 55
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 96
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 97
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 98
# ========================================================================
# Input sentence =  Sign up for our mailing: http://eepurl.com/btlMH5 [[SHARE]]
#
# Line: Sign up for our mailing: http://eepurl.com/btlMH5 [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 99
# ========================================================================
# Input sentence =  We will be launching Mommy + Me matching sets after the New Year!! Sign up for our newsletter to receive first news (and a discount to shop of coz! 💁🏻)
#
# Line: We will be launching Mommy + Me matching sets after the New Year!!
# Sentiment(polarity=0.2130681818181818, subjectivity=0.45454545454545453)
# positive
#
# Line: Sign up for our newsletter to receive first news (and a discount to shop of coz!
# Sentiment(polarity=0.3125, subjectivity=0.3333333333333333)
# positive
#
# Line: 💁🏻)
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 56
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 100
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 101
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 102
# ========================================================================
# Input sentence =  Sign up for our mailing: http://eepurl.com/btlMH5
#
# Line: Sign up for our mailing: http://eepurl.com/btlMH5
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 103
# ========================================================================
# Input sentence =  so now i know.. im an A hole parent 😂😂
#
# Line: so now i know.. im an A hole parent 😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 104
# ========================================================================
# Input sentence =  Perle Kam 😂😂😂
#
# Line: Perle Kam 😂😂😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 105
# ========================================================================
# Input sentence =  Jessey Ling
#
# Line: Jessey Ling
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 106
# ========================================================================
# Input sentence =  Definitely can relate to this for my boys😂😂 haha..
#
# Line: Definitely can relate to this for my boys😂😂 haha..
# Sentiment(polarity=0.1, subjectivity=0.4)
# positive
#
# THE SENTENCE IS +ve
# 57
# ========================================================================
# Input sentence =  Jysica Leron Chua Melissa Jonas Kok next time ur gal gal can wear tgt sure v cute!!
#
# Line: Jysica Leron Chua Melissa Jonas Kok next time ur gal gal can wear tgt sure v cute!
# Sentiment(polarity=0.375, subjectivity=0.6296296296296297)
# positive
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 58
# ========================================================================
# Input sentence =  這要去哪裡買啊？
#
# Line: 這要去哪裡買啊？
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 107
# ========================================================================
# Input sentence =  你好！你可以從這裡買: https://www.hahanoyume.com/collections/cny-collection [[SHARE]]
#
# Line: 你好！你可以從這裡買: https://www.hahanoyume.com/collections/cny-collection [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 108
# ========================================================================
# Input sentence =  So expensive 😭
#
# Line: So expensive 😭
# Sentiment(polarity=-0.5, subjectivity=0.7)
# Sentiment(polarity=-0.5, subjectivity=0.7)
# negative
#
# THE SENTENCE IS -ve
# 3
# ========================================================================
# Input sentence =  Hi! Our material is ethically made using premium Japanese cotton.  You may view our satisfied customers’ testimonials on our website and FB ☺️
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Our material is ethically made using premium Japanese cotton.
# Sentiment(polarity=0.1, subjectivity=0.3)
# positive
#
# Line: You may view our satisfied customers’ testimonials on our website and FB ☺️
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 59
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 109
# ========================================================================
# Input sentence =  https://www.hahanoyume.com/pages/customer-reviews
#
# Line: https://www.hahanoyume.com/pages/customer-reviews
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 110
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 111
# ========================================================================
# Input sentence =  You may use code SAVE20 to save 20% off your cart ❤️ Happy Chinese New Year! 😘 [[SHARE]]
#
# Line: You may use code SAVE20 to save 20% off your cart ❤️ Happy Chinese New Year!
# Sentiment(polarity=0.3234848484848485, subjectivity=0.48484848484848486)
# positive
#
# Line: 😘 [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 60
# ========================================================================
# Input sentence =  Mua đi
#
# Line: Mua đi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 112
# ========================================================================
# Input sentence =  60$ lan
#
# Line: 60$ lan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 113
# ========================================================================
# Input sentence =  10$ shipping nua
#
# Line: 10$ shipping nua
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 114
# ========================================================================
# Input sentence =  Thôi dẹp bà nó đi
#
# Line: Thôi dẹp bà nó đi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 115
# ========================================================================
# Input sentence =  Hi! Thanks for dropping by! Remember to use code SAVE20 to save 20% off your purchase! :)
#
# Line: Hi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Thanks for dropping by!
# Sentiment(polarity=0.25, subjectivity=0.2)
# positive
#
# Line: Remember to use code SAVE20 to save 20% off your purchase!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 61
# ========================================================================
# Input sentence =  Aww cute
#
# Line: Aww cute
# Sentiment(polarity=0.4, subjectivity=0.95)
# positive
#
# THE SENTENCE IS +ve
# 62
# ========================================================================
# Input sentence =  Thank you!
#
# Line: Thank you!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 116
# ========================================================================
# Input sentence =  Michelle Wilson 🎎
#
# Line: Michelle Wilson 🎎
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 117
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 118
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 119
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 120
# ========================================================================
# Input sentence =  I can’t wait until Theo’s one arrives...
#
# Line: I can’t wait until Theo’s one arrives...
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 121
# ========================================================================
# Input sentence =  💕 which one did you get for Theo?
#
# Line: 💕 which one did you get for Theo?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 122
# ========================================================================
# Input sentence =  Michelle Wilson Check IG... it’s super cute
#
# Line: Michelle Wilson Check IG... it’s super cute
# Sentiment(polarity=0.41666666666666663, subjectivity=0.8333333333333333)
# positive
#
# THE SENTENCE IS +ve
# 63
# ========================================================================
# Input sentence =  May bộ cho con nit ne Nhu Bui , nhin kung ghe. Bua c thay co đồ cho mẹ và bé luon .
#
# Line: May bộ cho con nit ne Nhu Bui , nhin kung ghe.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Bua c thay co đồ cho mẹ và bé luon .
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 123
# ========================================================================
# Input sentence =  Mary Vang Sang Thao this so cute!!! Check it out
#
# Line: Mary Vang Sang Thao this so cute!!!
# Sentiment(polarity=0.9765625, subjectivity=1.0)
# positive
#
# Line: Check it out
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 64
# ========================================================================
# Input sentence =  I still have one of those.
#
# Line: I still have one of those.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 124
# ========================================================================
# Input sentence =  Vicky Tran Junie would look so cute in one!
#
# Line: Vicky Tran Junie would look so cute in one!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 65
# ========================================================================
# Input sentence =  Yeah, so cute!! I got her some ao dai this tet too 🙂
#
# Line: Yeah, so cute!!
# Sentiment(polarity=0.78125, subjectivity=1.0)
# positive
#
# Line: I got her some ao dai this tet too 🙂
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 66
# ========================================================================
# Input sentence =  Pearly Tan Gatab for Ethena!
#
# Line: Pearly Tan Gatab for Ethena!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 125
# ========================================================================
# Input sentence =  Tina Dinh de thuong ko na , muon cho Emma ma Mac quA
#
# Line: Tina Dinh de thuong ko na , muon cho Emma ma Mac quA
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 126
# ========================================================================
# Input sentence =  Mua đi
#
# Line: Mua đi
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 127
# ========================================================================
# Input sentence =  OMG Kashia cute!!
#
# Line: OMG Kashia cute!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# ...
#
# Line: Last Friday I measure my boy size.
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# neutral
#
# Line: He seems can fit on the romper.
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# Line: Hopefully can fit him well!
# Sentiment(polarity=0.5, subjectivity=0.4)
# positive
#
# Line: Want him wear for photo shooting at studio.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Lol.
# Sentiment(polarity=0.8, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 297
# ========================================================================
# Input sentence =  You may also drop us a message on our FB page to place order ☺️
#
# Line: You may also drop us a message on our FB page to place order ☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 786
# ========================================================================
# Input sentence =  I hope they hav 4yo size!!!!!!!
#
# Line: I hope they hav 4yo size!!!!!!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 787
# ========================================================================
# Input sentence =  Hi Xiao Wei! Our 2-3 yo tops and dresses can fit 4 yo very comfortably ☺️
#
# Line: Hi Xiao Wei!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Our 2-3 yo tops and dresses can fit 4 yo very comfortably ☺️
# Sentiment(polarity=0.46, subjectivity=0.7)
# positive
#
# THE SENTENCE IS +ve
# 298
# ========================================================================
# Input sentence =  18-24mth?
#
# Line: 18-24mth?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 788
# ========================================================================
# Input sentence =  Hi Priscilla. We will launch our 1-3 yo tops and dresses range in sept. Will announce when it'll be available in TriBeCa as well. Stay tuned! ☺️
#
# Line: Hi Priscilla.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: We will launch our 1-3 yo tops and dresses range in sept. Will announce when it'll be available in TriBeCa as well.
# Sentiment(polarity=0.4, subjectivity=0.4)
# positive
#
# Line: Stay tuned!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: ☺️
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 299
# ========================================================================
# Input sentence =  Ooh nice! At my friend's shop.
#
# Line: Ooh nice!
# Sentiment(polarity=0.75, subjectivity=1.0)
# positive
#
# Line: At my friend's shop.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 300
# ========================================================================
# Input sentence =  Love them!
#
# Line: Love them!
# Sentiment(polarity=0.625, subjectivity=0.6)
# positive
#
# THE SENTENCE IS +ve
# 301
# ========================================================================
# Input sentence =  Carmen Yap
#
# Line: Carmen Yap
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 789
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 790
# ========================================================================
# Input sentence =  Loh Sook Kuan
#
# Line: Loh Sook Kuan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 791
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 792
# ========================================================================
# Input sentence =  Cheryl Chin
#
# Line: Cheryl Chin
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 793
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 794
# ========================================================================
# Input sentence =  Cheryl Yaw
#
# Line: Cheryl Yaw
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 795
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 796
# ========================================================================
# Input sentence =  Sandy Ong-Lee
#
# Line: Sandy Ong-Lee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 797
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 798
# ========================================================================
# Input sentence =  Jennics Tan
#
# Line: Jennics Tan
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 799
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 800
# ========================================================================
# Input sentence =  Annie Xavier
#
# Line: Annie Xavier
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 801
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 802
# ========================================================================
# Input sentence =  Annie Ngiam
#
# Line: Annie Ngiam
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 803
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 804
# ========================================================================
# Input sentence =  Nathalie Tung
#
# Line: Nathalie Tung
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 805
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 806
# ========================================================================
# Input sentence =  Debbie See
#
# Line: Debbie See
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 807
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 808
# ========================================================================
# Input sentence =  Venus Goh
#
# Line: Venus Goh
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 809
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 810
# ========================================================================
# Input sentence =  Cheng Lee
#
# Line: Cheng Lee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 811
# ========================================================================
# Input sentence =
#
# THE SENTENCE IS NEUTRAL
# 812
# ========================================================================
# Input sentence =  Chua Ching Yee
#
# Line: Chua Ching Yee
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 813
# ========================================================================
# Input sentence =  Ker Sin Gladys
#
# Line: Ker Sin Gladys
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 814
# ========================================================================
# Input sentence =  very enjoying reading each of your blog... and I do feel the same... having 1 kid making different to the relationship.. Emm you're not selfish la.. one is easy to cope compared to 2... especially nowadays everything is just $$$$ ...
#
# Line: very enjoying reading each of your blog... and I do feel the same... having 1 kid making different to the relationship.. Emm you're not selfish la.. one is easy to cope compared to 2... especially nowadays everything is just $$$$ ...
# Sentiment(polarity=0.22222222222222224, subjectivity=0.7230555555555555)
# positive
#
# THE SENTENCE IS +ve
# 302
# ========================================================================
# Input sentence =  Konichiwa  Eva is hijo ni kawaii :) muahhhh
#
# Line: Konichiwa  Eva is hijo ni kawaii :) muahhhh
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 303
# ========================================================================
# Input sentence =  Yes please! Can't wait to order! 😍😍😍
#
# Line: Yes please!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Can't wait to order!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😍😍😍
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 815
# ========================================================================
# Input sentence =  You're an awesome lady! Your daughter will grow up seeing you as her role model I believe. Keep up your great work!
#
# Line: You're an awesome lady!
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# Line: Your daughter will grow up seeing you as her role model I believe.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Keep up your great work!
# Sentiment(polarity=1.0, subjectivity=0.75)
# positive
#
# THE SENTENCE IS +ve
# 304
# ========================================================================
# Input sentence =  Good to share....
#
# Line: Good to share....
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# positive
#
# THE SENTENCE IS +ve
# 305
# ========================================================================
# Input sentence =  Hi five to all of us here 👋🏼👋🏼
#
# Line: Hi five to all of us here 👋🏼👋🏼
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 816
# ========================================================================
# Input sentence =  u r a good mama:)
#
# Line: u r a good mama:)
# Sentiment(polarity=0.6, subjectivity=0.8)
# positive
#
# THE SENTENCE IS +ve
# 306
# ========================================================================
# Input sentence =  Pic courtesy of Lee Tze Leong. Thanks for the amazing pic! 😃
#
# Line: Pic courtesy of Lee Tze Leong.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Thanks for the amazing pic!
# Sentiment(polarity=0.4750000000000001, subjectivity=0.55)
# positive
#
# Line: 😃
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 307
# ========================================================================
# Input sentence =  See you Ruby! 😘
#
# Line: See you Ruby!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: 😘
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 817
# ========================================================================
# Input sentence =  Where is the bazaar
#
# Line: Where is the bazaar
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 818
# ========================================================================
# Input sentence =  Wisma WIM, TTDI. Drive there using Waze: https://waze.to/lr/hw283bsnr9 [[SHARE]]
#
# Line: Wisma WIM, TTDI.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: Drive there using Waze: https://waze.to/lr/hw283bsnr9 [[SHARE]]
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 819
# ========================================================================
# Input sentence =  Tis 1 cute
#
# Line: Tis 1 cute
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 308
# ========================================================================
# Input sentence =  Please bring bigger sizes please. Plan to buy for my 2 y.o daughter. See you guys tomorrow at ttdi! :)
#
# Line: Please bring bigger sizes please.
# Sentiment(polarity=0.0, subjectivity=0.5)
# neutral
#
# Line: Plan to buy for my 2 y.o daughter.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: See you guys tomorrow at ttdi!
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: :)
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 309
# ========================================================================
# Input sentence =  Such a cute pic!!
#
# Line: Such a cute pic!
# Sentiment(polarity=0.3125, subjectivity=0.75)
# positive
#
# Line: !
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 310
# ========================================================================
# Input sentence =  Marcus Wong this is so cute
#
# Line: Marcus Wong this is so cute
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 311
# ========================================================================
# Input sentence =  Veekie Chew
#
# Line: Veekie Chew
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 820
# ========================================================================
# Input sentence =  Superb idea! And those 🎀 are so pretty!
#
# Line: Superb idea!
# Sentiment(polarity=1.0, subjectivity=1.0)
# positive
#
# Line: And those 🎀 are so pretty!
# Sentiment(polarity=0.3125, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 312
# ========================================================================
# Input sentence =  So cute!
#
# Line: So cute!
# Sentiment(polarity=0.625, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 313
# ========================================================================
# Input sentence =  Thanks Beatrice! 😃
#
# Line: Thanks Beatrice!
# Sentiment(polarity=0.25, subjectivity=0.2)
# positive
#
# Line: 😃
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS +ve
# 314
# ========================================================================
# Input sentence =  Nice
#
# Line: Nice
# Sentiment(polarity=0.6, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 315
# ========================================================================
# Input sentence =  So cute
#
# Line: So cute
# Sentiment(polarity=0.5, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 316
# ========================================================================
# Input sentence =  Melvyn
#
# Line: Melvyn
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 821
# ========================================================================
# Input sentence =  Jasper Maa
#
# Line: Jasper Maa
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 822
# ========================================================================
# Input sentence =  Hi ,may I know u have kimono for girl age 5 n baby boy for age 3?
#
# Line: Hi ,may I know u have kimono for girl age 5 n baby boy for age 3?
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# THE SENTENCE IS NEUTRAL
# 823
# ========================================================================
# Input sentence =  Hi Crystal. We are launching kimono tops and dresses for 1-3 year old in end Aug/ early Sept. ☺️ We don't have any line up for 5 yo at the moment
#
# Line: Hi Crystal.
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
#
# Line: We are launching kimono tops and dresses for 1-3 year old in end Aug/ early Sept. ☺️ We don't have any line up for 5 yo at the moment
# Sentiment(polarity=0.1, subjectivity=0.25)
# positive
#
# THE SENTENCE IS +ve
# 317
# ========================================================================
# Input sentence =  In 40 years time, ur child will thank you for it ;)
#
# Line: In 40 years time, ur child will thank you for it ;)
# Sentiment(polarity=0.25, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 318
# ========================================================================
# Input sentence =  Nice Marjorie :) I am in Mrs CEO category also...hehe :)
#
# Line: Nice Marjorie :) I am in Mrs CEO category also...hehe :)
# Sentiment(polarity=0.5333333333333333, subjectivity=1.0)
# positive
#
# THE SENTENCE IS +ve
# 319
# ========================================================================
# Input sentence =  You're good mama.. hahhaha I didn't prepare anything to Emillie as she only starts her soft food when she was 2 yrs old.. All the while only milk...
#
# Line: You're good mama.. hahhaha I didn't prepare anything to Emillie as she only starts her soft food when she was 2 yrs old.. All the while only milk...
# Sentiment(polarity=0.18, subjectivity=0.6300000000000001)
# positive
#
# THE SENTENCE IS +ve
# 320
# ========================================================================
# Sentence Polarity Negative =  35
# Sentence Polarity Neutral =  824
# Sentence Polarity Positive =  320

# %%
# txt to csv 
with open('Sentimenthahanoyume.txt', 'r',encoding ='UTF-8') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split("+;") for line in stripped if line)
    with open('sentiment(hahanoyume).csv', 'w',encoding ='UTF-8') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('text', 'sentiment'))
        writer.writerows(lines)

# %% [markdown]
# ### WordCloud Sentiment Analysis (HahaNoYume)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split # function for splitting data to train and test sets

import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output

# %%
data = pd.read_csv('sentiment(hahanoyume).csv')
# Keeping only the neccessary columns
data = data[['text','sentiment']]

# %%
# Splitting the dataset into train and test set
train, test = train_test_split(data,test_size = 0.1)
# Removing neutral sentiments
train = train[train.sentiment != "neutral"]

# %%
train_pos = train[ train['sentiment'] == 'positive']
train_pos = train_pos['text']
train_neg = train[ train['sentiment'] == 'negative']
train_neg = train_neg['text']
def wordcloud_draw(data, color = 'black',name = 'Unknown', titl = 'Netural'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT' 
                            ])
    STOPWORDS = stopwords.words('english') + ['inbox', 'please', 'yes','check', 'hi','https', 'www', 'com',
                                         'pls','check','inbox','hi','that','http','lol','GIF',"That's",'母の夢',
                                         'nipple']
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=1800,
                      height=1400
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.title('HahaNoYume'+titl+'Sentiment Analysis')
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.savefig(name, dpi=1000)
    plt.show()
    
print("Positive words")
wordcloud_draw(train_pos,'white','Positivehahanoyume.png','Positive')
print("Negative words")
wordcloud_draw(train_neg,'black','Negativehahanoyume.png','Negative')
# Out:
# Positive words
# Negative words

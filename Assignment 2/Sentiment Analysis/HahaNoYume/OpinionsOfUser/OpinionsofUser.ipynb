# %%
# !pip install module pygal
# Out:
# Requirement already satisfied: module in /Users/Goof/anaconda3/lib/python3.6/site-packages
# Collecting pygal
#   Downloading pygal-2.4.0-py2.py3-none-any.whl (127kB)
#     100% |████████████████████████████████| 133kB 258kB/s ta 0:00:01
# Installing collected packages: pygal
# Successfully installed pygal-2.4.0

# %%
import nltk
import ast
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
from nltk.corpus import sentiwordnet

_ReviewDataset = 'reviewsHahanoyume.txt'
_PreProcessedData= 'PreProcessedData.txt'
_TokenizedReviews= 'TokenizedReviews.txt'
_PosTaggedReviews= 'PosTaggedReviews.txt'
_Opinions= 'OpinionsOfUser.txt'


def preProcessing(inputFileStr,outputFileStr,printResult):
    inputFile = open(inputFileStr,"r").read()
    outputFile=open (outputFileStr,"w+")
    cachedStopWords = nltk.corpus.stopwords.words("english")
    cachedStopWords.append('OMG')
    cachedStopWords.append('HI')
    cachedStopWords.append('HELLO')
    cachedStopWords.append('THANK')
    cachedStopWords.append('KIDDO')
    cachedStopWords.append('HAHA')
    cachedStopWords.append('CA')
    cachedStopWords.append(':-(')
    cachedStopWords.append(':-)')
    result=(' '.join([word for word in inputFile.split() if word not in cachedStopWords]))
    if(printResult):
        print('Following are the Stop Words')
        print(cachedStopWords)
        print(str(result))
    outputFile.write(str(result))
    outputFile.close()
    
def tokenizeReviews(inputFileStr,outputFileStr,printResult):
    tokenizedReviews={}
    inputFile = open(inputFileStr,"r").read()
    outputFile=open (outputFileStr,"w")
    tokenizer = nltk.tokenize.punkt.PunktSentenceTokenizer()
    uniqueId=1;
    cachedStopWords = nltk.corpus.stopwords.words("english")
    for sentence in tokenizer.tokenize(inputFile):      
        tokenizedReviews[uniqueId]=sentence
        uniqueId+=1
    outputFile.write(str(tokenizedReviews))
    if(printResult):
        for key,value in tokenizedReviews.items():
            print(key,' ',value)
    outputFile.close()
    
def posTagging(inputFileStr,outputFileStr,printResult):
    inputFile = open(inputFileStr,"r").read()
    outputFile=open (outputFileStr,"w")
    inputTupples=ast.literal_eval(inputFile)
    outputPost={}
    for key,value in inputTupples.items():
        outputPost[key]=nltk.pos_tag(nltk.word_tokenize(value))
    if(printResult):
        for key,value in outputPost.items():
            print(key,' ',value)
    outputFile.write(str(outputPost))
    outputFile.close()
    
def opinionExtraction(inputFileStr,outputFileStr,printResult):
    inputFile = open(inputFileStr,"r").read()
    outputFile=open (outputFileStr,"w")
    inputTupples=ast.literal_eval(inputFile)
    prevWord=''
    prevTag=''
    currWord=''
    aspectList=[]
    outputDict={}
    #Extracting Aspects
    for key,value in inputTupples.items():
        for word,tag in value:
            if(tag=='JJ' or tag=='JJR' or tag=='JJS'or tag== 'RB' or tag== 'RBR'or tag== 'RBS'):
                if(prevTag=='NN' or prevTag=='NNP'):
                    currWord= prevWord + ' ' + word
                else:
                    aspectList.append(prevWord.upper())
                    currWord= word
            prevWord=currWord
            prevTag=tag
    #Eliminating aspect which has 1 or less count
    for aspect in aspectList:
            if(aspectList.count(aspect)>1):
                    if(outputDict.keys()!=aspect):
                            outputDict[aspect]=aspectList.count(aspect)
    outputAspect=sorted(outputDict.items(), key=lambda x: x[1],reverse = True)
    if(printResult):
        print(outputAspect)
    outputFile.write(str(outputAspect))
    outputFile.close()

def printResultChoice():
    userChoice = str(input('\nDo you want to print the result on output window? (Y/N) :'))
    if(userChoice=='Y' or userChoice=='y'):
        return True
    else:
        return False
        
if __name__ == '__main__':
    print("\n\n\n\n\n\nPREPROCESSING DATA")
    preProcessing(_ReviewDataset,_PreProcessedData,printResultChoice())
    print("\n\n\n\n\n\nTOKENIZING REVIEW")
    tokenizeReviews(_ReviewDataset,_TokenizedReviews,printResultChoice())
    print("\n\n\n\n\n\nPOS TAGGING")
    posTagging(_TokenizedReviews,_PosTaggedReviews,printResultChoice())
    print("\nOPINIONS OF USERS")
    opinionExtraction(_PosTaggedReviews,_Opinions,printResultChoice())
# Out:
# PREPROCESSING DATA
#
# Do you want to print the result on output window? (Y/N) :y
# Following are the Stop Words
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'OMG', 'HI', 'HELLO', 'THANK', 'KIDDO', 'HAHA', 'CA', ':-(', ':-)']
# "Love comfortable cute kimonos are!!! They’re super adorable baby!! " good material nice . im excited receive beautiful kimono eventhough im one wears . hahaha . Superb material workmanship, attention last detail packaging. "Beautiful package reminds japan handwritten message box. Majorie responsive accommodating. Rompers excellent quality definitely great SG weather! Thanks Majorie!" Very good quality affordable price. Respond fast good service. Love it. Totally love quality clothes.Real fast delivery.Simply pretty! Will defintely order again! I bought recently put onto daughter last night. Gorgeous! Pretty fabric good workmanship. Love worth every penny imo Thanks complimentary present daughter. She happy. Very thoughtful you. The wrapping dress box lovely too.. The rompers came nicely packaged I surprised find handwritten message box! The owner provides personal service accommodating.The rompers good quality cooling! My baby loves them! Hope see designs coming up! This really Haha yume (mummy's dream) coming true! Loving nice Japanese cotton! We love love love shop- kimonos well made & owner pleasant! Happy support ! Thank u Excellent & efficient service. Most important quality kimono superb (soft) & airy. We love u Majorie ! Hope u also sell kimono adult like Really love shop Haha yume. Very responsive message. Love quality costume really kawaii boy I've recommended friends well definitely continue support Haha yume Love much.. fast respond nice seller All OK ! Majorie great seller Really happy purchase. It's noticed love puts details. Very good comunication fast delivery. Europeans interested, save customs expenses choosing free shipping. Hi Majorie, I received parcel! Can't wait dress baby girl baby rompers! Thank personalised message great service! Bought 2 baby rompers kiddo, plus gifts form baby romper pack, plus two dresses 2 little girls! They absolutely lovely! Thanks, Majorie! "After seeing gorgeous outfit Instagram I immediately fell love!then ordered 2 gorgeous kimono rompers baby daughter, great communication throughout items delivered beautifully wrapped super fast delivery! Very well made we've loads compliments!! Thankyou much xxxx" Unique beautiful kimono rompers. Fabric print great quality. The snaps great ease access changing. Love traditional look little one! Can't wait next orders!! Hi Majorie, received parcel today. Love much! It fits daughter perfectly! Mahalo Marjorie! Got package quickly! Love packaging cute note left. Will definitely order future recommend everyone. Received kimono romper! So excited can't wait see kiddo wearing them! So comfortable nice! Will definitely come back shop! Have bought 3 rompers top recently: Maru, Hiroshi Kitsune. These 3 pieces lovely high quality. Suits boys well. The packaging nice packed much love. Prompt replies excellent customer service!! I highly recommend shop everyone!! Thank much. "Hi Majorie, received Kimono top hour ago. The lovely packaging note left awe.. Reminds much I miss Japan.. Excellent customer service. Will definitely come back recommend shop friends." Just received rompers today!! Its soooo pretty!! Thank much lovely packaging well!! I highly recommend shop everyone!! Prompt replies excellent customer service!! Thanks again!! My daughter fit My toddler I love kimono comfortable easy wear. Cool ! Good design Good material Bought "Mon" romper son, definitely cute piece! The fabric soft good quality. Nicely wrapped I thought I got present haha. Launch bigger size ok? Will surely buy again! Thumbs nice service, good quality beautiful packaging! much! My 2 months old boy fit nicely newborn sized rompers, looked really good them. Thank Hahanoyume wonderful looking outfits little boy. A must babies definitely perfect gift friend's babies. Keep good work I look forward wonderful products boy guys near future It special n unique romper baby. Very soft piece feel hot him. My baby Tze love much…
#
#
#
#
#
#
# TOKENIZING REVIEW
#
# Do you want to print the result on output window? (Y/N) :y
# 1   "Love how comfortable and cute these kimonos are!!!
# 2   They’re super adorable on my baby!!
# "
# 3   very good material and very nice .
# 4   im so excited to receive this beautiful kimono eventhough im not the one who wears it .
# 5   hahaha .
# 6   Superb material and workmanship, with attention to the last detail in packaging.
# 7   "Beautiful package reminds me of japan with a handwritten message in the box.
# 8   Majorie was responsive and accommodating.
# 9   Rompers of excellent quality and it's definitely great for SG weather!
# 10   Thanks Majorie!"
# 11   Very good quality with affordable price.
# 12   Respond fast and good service.
# 13   Love it.
# 14   Totally love the quality of the clothes.Real fast delivery.Simply too pretty!
# 15   Will defintely order again!
# 16   I bought a few recently and put it onto my daughter last night.
# 17   Gorgeous!
# 18   Pretty fabric good workmanship.
# 19   Love it and worth every penny imo
# Thanks for the complimentary present for my daughter.
# 20   She is so happy.
# 21   Very thoughtful of you.
# 22   The wrapping of the dress in the box is very lovely too..
# The rompers came very nicely packaged and I was surprised to find a handwritten message in the box!
# 23   The owner provides very personal service and is accommodating.The rompers are of good quality and it's cooling!
# 24   My baby loves them!
# 25   Hope to see more designs coming up!
# 26   This is really Haha no yume (mummy's dream) coming true!
# 27   Loving the nice Japanese cotton!
# 28   We love love love this shop- the kimonos are so well made & the owner is so pleasant!
# 29   Happy to support !
# 30   Thank u
# Excellent & efficient service.
# 31   Most important the quality of the kimono is superb (soft) & airy.
# 32   We love u Majorie !
# 33   Hope that u can also sell kimono for adult like me
# Really love to shop with Haha no yume.
# 34   Very responsive in message.
# 35   Love the quality of the costume and it's really kawaii on my boy  I've recommended to my friends as well and definitely will continue to support Haha no yume
# Love it so much.. fast respond and nice seller
# All was OK !
# 36   Majorie is a great seller
# Really happy with my purchase.
# 37   It's noticed the love she puts in the details.
# 38   Very good comunication and fast delivery.
# 39   Europeans interested, you can save in customs expenses by choosing free shipping.
# 40   Hi Majorie, I just received the parcel!
# 41   Can't wait to dress my baby girl in the baby rompers!
# 42   Thank you for the personalised message and the great service!
# 43   Bought 2 baby rompers for my kiddo, plus gifts in form of a baby romper pack, plus two other dresses for 2 little girls!
# 44   They are absolutely lovely!
# 45   Thanks, Majorie!
# 46   "After seeing a gorgeous outfit on Instagram I immediately fell in love!then ordered 2 of these gorgeous kimono rompers for my baby daughter, great communication throughout and items delivered beautifully wrapped and super fast delivery!
# 47   Very well made and we've had loads of compliments!!
# 48   Thankyou so much xxxx"
# Unique and beautiful kimono rompers.
# 49   Fabric and print are of great quality.
# 50   The snaps are great for ease of access when changing.
# 51   Love the traditional look on my little one!
# 52   Can't wait for my next orders!!
# 53   Hi Majorie, just received the parcel today.
# 54   Love it so much!
# 55   It just fits my daughter perfectly!
# 56   Mahalo Marjorie!
# 57   Got the package so quickly!
# 58   Love the packaging and the cute note you left.
# 59   Will definitely order again in the future and recommend to everyone.
# 60   Received both the kimono and romper!
# 61   So excited and can't wait to see both my kiddo wearing them!
# 62   So comfortable and nice!
# 63   Will definitely come back and shop!
# 64   Have bought 3 rompers and top recently: Maru, Hiroshi and Kitsune.
# 65   These 3 pieces are so lovely and in high quality.
# 66   Suits my boys so well.
# 67   The packaging is so so nice and it's packed with so much love.
# 68   Prompt replies and excellent customer service!!
# 69   I will highly recommend your shop to everyone!!
# 70   Thank you very much.
# 71   "Hi Majorie, received the Kimono top an hour ago.
# 72   The lovely packaging and note left me in awe.. Reminds me of how much I miss Japan..
# Excellent customer service.
# 73   Will definitely come back for more and recommend your shop to my friends."
# 74   Just received both the rompers today!!
# 75   Its soooo pretty!!
# 76   Thank you so much for the lovely packaging as well!!
# 77   I highly recommend your shop to everyone!!
# 78   Prompt replies and excellent customer service!!
# 79   Thanks once again!!
# 80   My daughter fit with it
# My toddler and I love the kimono as its too comfortable and easy to wear.
# 81   Cool !
# 82   Good design and Good material
# Bought a "Mon" romper for my son, definitely a cute piece!
# 83   The fabric is soft and very good quality.
# 84   Nicely wrapped and I thought I got a present haha.
# 85   Launch more bigger size ok?
# 86   Will surely buy again!
# 87   Thumbs up for the nice service, good quality and the beautiful packaging!
# 88   it so much!
# 89   My 2 months old boy fit nicely into the newborn sized rompers, and he looked really good on them.
# 90   Thank you Hahanoyume for these wonderful looking outfits for our little boy.
# 91   A must have for your babies and definitely a perfect gift for your friend's babies.
# 92   Keep up the good work and I look forward to more wonderful products for my boy from you guys in the near future
# It is very special n unique romper for my baby.
# 93   Very soft piece and do not feel hot for him.
# 94   My baby Tze love it so much…
#
#
#
#
#
#
# POS TAGGING
# Do you want to print the result on output window? (Y/N) :y
# 1   [('``', '``'), ('Love', 'VB'), ('how', 'WRB'), ('comfortable', 'JJ'), ('and', 'CC'), ('cute', 'JJ'), ('these', 'DT'), ('kimonos', 'NNS'), ('are', 'VBP'), ('!', '.'), ('!', '.'), ('!', '.')]
# 2   [('They', 'PRP'), ('’', 'VBP'), ('re', 'JJ'), ('super', 'JJ'), ('adorable', 'NN'), ('on', 'IN'), ('my', 'PRP$'), ('baby', 'NN'), ('!', '.'), ('!', '.'), ("''", "''")]
# 3   [('very', 'RB'), ('good', 'JJ'), ('material', 'NN'), ('and', 'CC'), ('very', 'RB'), ('nice', 'JJ'), ('.', '.')]
# 4   [('im', 'NNS'), ('so', 'RB'), ('excited', 'JJ'), ('to', 'TO'), ('receive', 'VB'), ('this', 'DT'), ('beautiful', 'JJ'), ('kimono', 'FW'), ('eventhough', 'RB'), ('im', 'NN'), ('not', 'RB'), ('the', 'DT'), ('one', 'NN'), ('who', 'WP'), ('wears', 'VBZ'), ('it', 'PRP'), ('.', '.')]
# 5   [('hahaha', 'NN'), ('.', '.')]
# 6   [('Superb', 'NNP'), ('material', 'NN'), ('and', 'CC'), ('workmanship', 'NN'), (',', ','), ('with', 'IN'), ('attention', 'NN'), ('to', 'TO'), ('the', 'DT'), ('last', 'JJ'), ('detail', 'NN'), ('in', 'IN'), ('packaging', 'NN'), ('.', '.')]
# 7   [('``', '``'), ('Beautiful', 'JJ'), ('package', 'NN'), ('reminds', 'VBZ'), ('me', 'PRP'), ('of', 'IN'), ('japan', 'NN'), ('with', 'IN'), ('a', 'DT'), ('handwritten', 'JJ'), ('message', 'NN'), ('in', 'IN'), ('the', 'DT'), ('box', 'NN'), ('.', '.')]
# 8   [('Majorie', 'NNP'), ('was', 'VBD'), ('responsive', 'JJ'), ('and', 'CC'), ('accommodating', 'VBG'), ('.', '.')]
# 9   [('Rompers', 'NNS'), ('of', 'IN'), ('excellent', 'JJ'), ('quality', 'NN'), ('and', 'CC'), ('it', 'PRP'), ("'s", 'VBZ'), ('definitely', 'RB'), ('great', 'JJ'), ('for', 'IN'), ('SG', 'NNP'), ('weather', 'NN'), ('!', '.')]
# 10   [('Thanks', 'NNS'), ('Majorie', 'NNP'), ('!', '.'), ("''", "''")]
# 11   [('Very', 'RB'), ('good', 'JJ'), ('quality', 'NN'), ('with', 'IN'), ('affordable', 'JJ'), ('price', 'NN'), ('.', '.')]
# 12   [('Respond', 'NNP'), ('fast', 'NN'), ('and', 'CC'), ('good', 'JJ'), ('service', 'NN'), ('.', '.')]
# 13   [('Love', 'VB'), ('it', 'PRP'), ('.', '.')]
# 14   [('Totally', 'RB'), ('love', 'VB'), ('the', 'DT'), ('quality', 'NN'), ('of', 'IN'), ('the', 'DT'), ('clothes.Real', 'NN'), ('fast', 'RB'), ('delivery.Simply', 'VB'), ('too', 'RB'), ('pretty', 'RB'), ('!', '.')]
# 15   [('Will', 'MD'), ('defintely', 'RB'), ('order', 'NN'), ('again', 'RB'), ('!', '.')]
# 16   [('I', 'PRP'), ('bought', 'VBD'), ('a', 'DT'), ('few', 'JJ'), ('recently', 'RB'), ('and', 'CC'), ('put', 'VB'), ('it', 'PRP'), ('onto', 'IN'), ('my', 'PRP$'), ('daughter', 'NN'), ('last', 'JJ'), ('night', 'NN'), ('.', '.')]
# 17   [('Gorgeous', 'JJ'), ('!', '.')]
# 18   [('Pretty', 'NNP'), ('fabric', 'JJ'), ('good', 'JJ'), ('workmanship', 'NN'), ('.', '.')]
# 19   [('Love', 'VB'), ('it', 'PRP'), ('and', 'CC'), ('worth', 'JJ'), ('every', 'DT'), ('penny', 'NN'), ('imo', 'NN'), ('Thanks', 'NNP'), ('for', 'IN'), ('the', 'DT'), ('complimentary', 'JJ'), ('present', 'NN'), ('for', 'IN'), ('my', 'PRP$'), ('daughter', 'NN'), ('.', '.')]
# 20   [('She', 'PRP'), ('is', 'VBZ'), ('so', 'RB'), ('happy', 'JJ'), ('.', '.')]
# 21   [('Very', 'RB'), ('thoughtful', 'JJ'), ('of', 'IN'), ('you', 'PRP'), ('.', '.')]
# 22   [('The', 'DT'), ('wrapping', 'NN'), ('of', 'IN'), ('the', 'DT'), ('dress', 'NN'), ('in', 'IN'), ('the', 'DT'), ('box', 'NN'), ('is', 'VBZ'), ('very', 'RB'), ('lovely', 'RB'), ('too..', 'VB'), ('The', 'DT'), ('rompers', 'NNS'), ('came', 'VBD'), ('very', 'RB'), ('nicely', 'RB'), ('packaged', 'VBN'), ('and', 'CC'), ('I', 'PRP'), ('was', 'VBD'), ('surprised', 'VBN'), ('to', 'TO'), ('find', 'VB'), ('a', 'DT'), ('handwritten', 'JJ'), ('message', 'NN'), ('in', 'IN'), ('the', 'DT'), ('box', 'NN'), ('!', '.')]
# 23   [('The', 'DT'), ('owner', 'NN'), ('provides', 'VBZ'), ('very', 'RB'), ('personal', 'JJ'), ('service', 'NN'), ('and', 'CC'), ('is', 'VBZ'), ('accommodating.The', 'JJ'), ('rompers', 'NNS'), ('are', 'VBP'), ('of', 'IN'), ('good', 'JJ'), ('quality', 'NN'), ('and', 'CC'), ('it', 'PRP'), ("'s", 'VBZ'), ('cooling', 'VBG'), ('!', '.')]
# 24   [('My', 'PRP$'), ('baby', 'NN'), ('loves', 'VBZ'), ('them', 'PRP'), ('!', '.')]
# 25   [('Hope', 'NN'), ('to', 'TO'), ('see', 'VB'), ('more', 'JJR'), ('designs', 'NNS'), ('coming', 'VBG'), ('up', 'RP'), ('!', '.')]
# 26   [('This', 'DT'), ('is', 'VBZ'), ('really', 'RB'), ('Haha', 'NNP'), ('no', 'DT'), ('yume', 'NN'), ('(', '('), ('mummy', 'NN'), ("'s", 'POS'), ('dream', 'NN'), (')', ')'), ('coming', 'VBG'), ('true', 'JJ'), ('!', '.')]
# 27   [('Loving', 'VBG'), ('the', 'DT'), ('nice', 'JJ'), ('Japanese', 'JJ'), ('cotton', 'NN'), ('!', '.')]
# 28   [('We', 'PRP'), ('love', 'VBP'), ('love', 'RB'), ('love', 'VB'), ('this', 'DT'), ('shop-', 'JJ'), ('the', 'DT'), ('kimonos', 'NNS'), ('are', 'VBP'), ('so', 'RB'), ('well', 'RB'), ('made', 'VBN'), ('&', 'CC'), ('the', 'DT'), ('owner', 'NN'), ('is', 'VBZ'), ('so', 'RB'), ('pleasant', 'JJ'), ('!', '.')]
# 29   [('Happy', 'JJ'), ('to', 'TO'), ('support', 'VB'), ('!', '.')]
# 30   [('Thank', 'NNP'), ('u', 'JJ'), ('Excellent', 'NNP'), ('&', 'CC'), ('efficient', 'JJ'), ('service', 'NN'), ('.', '.')]
# 31   [('Most', 'RBS'), ('important', 'JJ'), ('the', 'DT'), ('quality', 'NN'), ('of', 'IN'), ('the', 'DT'), ('kimono', 'NN'), ('is', 'VBZ'), ('superb', 'JJ'), ('(', '('), ('soft', 'JJ'), (')', ')'), ('&', 'CC'), ('airy', 'NN'), ('.', '.')]
# 32   [('We', 'PRP'), ('love', 'VBP'), ('u', 'JJ'), ('Majorie', 'NNP'), ('!', '.')]
# 33   [('Hope', 'NN'), ('that', 'IN'), ('u', 'NN'), ('can', 'MD'), ('also', 'RB'), ('sell', 'VB'), ('kimono', 'NN'), ('for', 'IN'), ('adult', 'NN'), ('like', 'IN'), ('me', 'PRP'), ('Really', 'RB'), ('love', 'VB'), ('to', 'TO'), ('shop', 'VB'), ('with', 'IN'), ('Haha', 'NNP'), ('no', 'DT'), ('yume', 'NN'), ('.', '.')]
# 34   [('Very', 'RB'), ('responsive', 'JJ'), ('in', 'IN'), ('message', 'NN'), ('.', '.')]
# 35   [('Love', 'VB'), ('the', 'DT'), ('quality', 'NN'), ('of', 'IN'), ('the', 'DT'), ('costume', 'NN'), ('and', 'CC'), ('it', 'PRP'), ("'s", 'VBZ'), ('really', 'RB'), ('kawaii', 'VBN'), ('on', 'IN'), ('my', 'PRP$'), ('boy', 'NN'), ('I', 'PRP'), ("'ve", 'VBP'), ('recommended', 'VBN'), ('to', 'TO'), ('my', 'PRP$'), ('friends', 'NNS'), ('as', 'RB'), ('well', 'RB'), ('and', 'CC'), ('definitely', 'RB'), ('will', 'MD'), ('continue', 'VB'), ('to', 'TO'), ('support', 'VB'), ('Haha', 'NNP'), ('no', 'DT'), ('yume', 'NN'), ('Love', 'VB'), ('it', 'PRP'), ('so', 'RB'), ('much..', 'JJ'), ('fast', 'JJ'), ('respond', 'NN'), ('and', 'CC'), ('nice', 'JJ'), ('seller', 'NN'), ('All', 'DT'), ('was', 'VBD'), ('OK', 'JJ'), ('!', '.')]
# 36   [('Majorie', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('great', 'JJ'), ('seller', 'NN'), ('Really', 'NNP'), ('happy', 'JJ'), ('with', 'IN'), ('my', 'PRP$'), ('purchase', 'NN'), ('.', '.')]
# 37   [('It', 'PRP'), ("'s", 'VBZ'), ('noticed', 'VBN'), ('the', 'DT'), ('love', 'NN'), ('she', 'PRP'), ('puts', 'VBZ'), ('in', 'IN'), ('the', 'DT'), ('details', 'NNS'), ('.', '.')]
# 38   [('Very', 'RB'), ('good', 'JJ'), ('comunication', 'NN'), ('and', 'CC'), ('fast', 'JJ'), ('delivery', 'NN'), ('.', '.')]
# 39   [('Europeans', 'NNS'), ('interested', 'JJ'), (',', ','), ('you', 'PRP'), ('can', 'MD'), ('save', 'VB'), ('in', 'IN'), ('customs', 'NNS'), ('expenses', 'NNS'), ('by', 'IN'), ('choosing', 'VBG'), ('free', 'JJ'), ('shipping', 'NN'), ('.', '.')]
# 40   [('Hi', 'NNP'), ('Majorie', 'NNP'), (',', ','), ('I', 'PRP'), ('just', 'RB'), ('received', 'VBD'), ('the', 'DT'), ('parcel', 'NN'), ('!', '.')]
# 41   [('Ca', 'NNP'), ("n't", 'RB'), ('wait', 'VBD'), ('to', 'TO'), ('dress', 'VB'), ('my', 'PRP$'), ('baby', 'NN'), ('girl', 'NN'), ('in', 'IN'), ('the', 'DT'), ('baby', 'NN'), ('rompers', 'NNS'), ('!', '.')]
# 42   [('Thank', 'NNP'), ('you', 'PRP'), ('for', 'IN'), ('the', 'DT'), ('personalised', 'JJ'), ('message', 'NN'), ('and', 'CC'), ('the', 'DT'), ('great', 'JJ'), ('service', 'NN'), ('!', '.')]
# 43   [('Bought', 'VBD'), ('2', 'CD'), ('baby', 'NN'), ('rompers', 'NNS'), ('for', 'IN'), ('my', 'PRP$'), ('kiddo', 'NN'), (',', ','), ('plus', 'CC'), ('gifts', 'NNS'), ('in', 'IN'), ('form', 'NN'), ('of', 'IN'), ('a', 'DT'), ('baby', 'NN'), ('romper', 'NN'), ('pack', 'NN'), (',', ','), ('plus', 'CC'), ('two', 'CD'), ('other', 'JJ'), ('dresses', 'NNS'), ('for', 'IN'), ('2', 'CD'), ('little', 'JJ'), ('girls', 'NNS'), ('!', '.')]
# 44   [('They', 'PRP'), ('are', 'VBP'), ('absolutely', 'RB'), ('lovely', 'RB'), ('!', '.')]
# 45   [('Thanks', 'NNS'), (',', ','), ('Majorie', 'NNP'), ('!', '.')]
# 46   [('``', '``'), ('After', 'IN'), ('seeing', 'VBG'), ('a', 'DT'), ('gorgeous', 'JJ'), ('outfit', 'NN'), ('on', 'IN'), ('Instagram', 'NNP'), ('I', 'PRP'), ('immediately', 'RB'), ('fell', 'VBD'), ('in', 'IN'), ('love', 'NN'), ('!', '.'), ('then', 'RB'), ('ordered', 'VBD'), ('2', 'CD'), ('of', 'IN'), ('these', 'DT'), ('gorgeous', 'JJ'), ('kimono', 'NN'), ('rompers', 'NNS'), ('for', 'IN'), ('my', 'PRP$'), ('baby', 'NN'), ('daughter', 'NN'), (',', ','), ('great', 'JJ'), ('communication', 'NN'), ('throughout', 'IN'), ('and', 'CC'), ('items', 'NNS'), ('delivered', 'VBN'), ('beautifully', 'RB'), ('wrapped', 'VBN'), ('and', 'CC'), ('super', 'JJ'), ('fast', 'NN'), ('delivery', 'NN'), ('!', '.')]
# 47   [('Very', 'RB'), ('well', 'RB'), ('made', 'VBN'), ('and', 'CC'), ('we', 'PRP'), ("'ve", 'VBP'), ('had', 'VBD'), ('loads', 'NNS'), ('of', 'IN'), ('compliments', 'NNS'), ('!', '.'), ('!', '.')]
# 48   [('Thankyou', 'NNP'), ('so', 'RB'), ('much', 'JJ'), ('xxxx', 'NN'), ("''", "''"), ('Unique', 'NNP'), ('and', 'CC'), ('beautiful', 'JJ'), ('kimono', 'NN'), ('rompers', 'NNS'), ('.', '.')]
# 49   [('Fabric', 'NNP'), ('and', 'CC'), ('print', 'NN'), ('are', 'VBP'), ('of', 'IN'), ('great', 'JJ'), ('quality', 'NN'), ('.', '.')]
# 50   [('The', 'DT'), ('snaps', 'NNS'), ('are', 'VBP'), ('great', 'JJ'), ('for', 'IN'), ('ease', 'NN'), ('of', 'IN'), ('access', 'NN'), ('when', 'WRB'), ('changing', 'NN'), ('.', '.')]
# 51   [('Love', 'VB'), ('the', 'DT'), ('traditional', 'JJ'), ('look', 'NN'), ('on', 'IN'), ('my', 'PRP$'), ('little', 'JJ'), ('one', 'CD'), ('!', '.')]
# 52   [('Ca', 'NNP'), ("n't", 'RB'), ('wait', 'VBD'), ('for', 'IN'), ('my', 'PRP$'), ('next', 'JJ'), ('orders', 'NNS'), ('!', '.'), ('!', '.')]
# 53   [('Hi', 'NNP'), ('Majorie', 'NNP'), (',', ','), ('just', 'RB'), ('received', 'VBD'), ('the', 'DT'), ('parcel', 'NN'), ('today', 'NN'), ('.', '.')]
# 54   [('Love', 'VB'), ('it', 'PRP'), ('so', 'RB'), ('much', 'JJ'), ('!', '.')]
# 55   [('It', 'PRP'), ('just', 'RB'), ('fits', 'VBZ'), ('my', 'PRP$'), ('daughter', 'NN'), ('perfectly', 'RB'), ('!', '.')]
# 56   [('Mahalo', 'NNP'), ('Marjorie', 'NNP'), ('!', '.')]
# 57   [('Got', 'NNP'), ('the', 'DT'), ('package', 'NN'), ('so', 'RB'), ('quickly', 'RB'), ('!', '.')]
# 58   [('Love', 'VB'), ('the', 'DT'), ('packaging', 'NN'), ('and', 'CC'), ('the', 'DT'), ('cute', 'JJ'), ('note', 'NN'), ('you', 'PRP'), ('left', 'VBD'), ('.', '.')]
# 59   [('Will', 'MD'), ('definitely', 'RB'), ('order', 'NN'), ('again', 'RB'), ('in', 'IN'), ('the', 'DT'), ('future', 'NN'), ('and', 'CC'), ('recommend', 'VB'), ('to', 'TO'), ('everyone', 'NN'), ('.', '.')]
# 60   [('Received', 'VBN'), ('both', 'DT'), ('the', 'DT'), ('kimono', 'NN'), ('and', 'CC'), ('romper', 'NN'), ('!', '.')]
# 61   [('So', 'RB'), ('excited', 'JJ'), ('and', 'CC'), ('ca', 'MD'), ("n't", 'RB'), ('wait', 'VB'), ('to', 'TO'), ('see', 'VB'), ('both', 'DT'), ('my', 'PRP$'), ('kiddo', 'NN'), ('wearing', 'VBG'), ('them', 'PRP'), ('!', '.')]
# 62   [('So', 'RB'), ('comfortable', 'JJ'), ('and', 'CC'), ('nice', 'JJ'), ('!', '.')]
# 63   [('Will', 'MD'), ('definitely', 'RB'), ('come', 'VB'), ('back', 'RB'), ('and', 'CC'), ('shop', 'NN'), ('!', '.')]
# 64   [('Have', 'NNP'), ('bought', 'VBD'), ('3', 'CD'), ('rompers', 'NNS'), ('and', 'CC'), ('top', 'JJ'), ('recently', 'RB'), (':', ':'), ('Maru', 'NNP'), (',', ','), ('Hiroshi', 'NNP'), ('and', 'CC'), ('Kitsune', 'NNP'), ('.', '.')]
# 65   [('These', 'DT'), ('3', 'CD'), ('pieces', 'NNS'), ('are', 'VBP'), ('so', 'RB'), ('lovely', 'RB'), ('and', 'CC'), ('in', 'IN'), ('high', 'JJ'), ('quality', 'NN'), ('.', '.')]
# 66   [('Suits', 'NNS'), ('my', 'PRP$'), ('boys', 'NNS'), ('so', 'RB'), ('well', 'RB'), ('.', '.')]
# 67   [('The', 'DT'), ('packaging', 'NN'), ('is', 'VBZ'), ('so', 'RB'), ('so', 'RB'), ('nice', 'JJ'), ('and', 'CC'), ('it', 'PRP'), ("'s", 'VBZ'), ('packed', 'VBN'), ('with', 'IN'), ('so', 'RB'), ('much', 'JJ'), ('love', 'NN'), ('.', '.')]
# 68   [('Prompt', 'JJ'), ('replies', 'NNS'), ('and', 'CC'), ('excellent', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('!', '.'), ('!', '.')]
# 69   [('I', 'PRP'), ('will', 'MD'), ('highly', 'RB'), ('recommend', 'VB'), ('your', 'PRP$'), ('shop', 'NN'), ('to', 'TO'), ('everyone', 'NN'), ('!', '.'), ('!', '.')]
# 70   [('Thank', 'NNP'), ('you', 'PRP'), ('very', 'RB'), ('much', 'RB'), ('.', '.')]
# 71   [('``', '``'), ('Hi', 'NNP'), ('Majorie', 'NNP'), (',', ','), ('received', 'VBD'), ('the', 'DT'), ('Kimono', 'NNP'), ('top', 'VBD'), ('an', 'DT'), ('hour', 'NN'), ('ago', 'RB'), ('.', '.')]
# 72   [('The', 'DT'), ('lovely', 'JJ'), ('packaging', 'NN'), ('and', 'CC'), ('note', 'NN'), ('left', 'VBD'), ('me', 'PRP'), ('in', 'IN'), ('awe..', 'NN'), ('Reminds', 'NNP'), ('me', 'PRP'), ('of', 'IN'), ('how', 'WRB'), ('much', 'JJ'), ('I', 'PRP'), ('miss', 'VBP'), ('Japan..', 'NNP'), ('Excellent', 'NNP'), ('customer', 'NN'), ('service', 'NN'), ('.', '.')]
# 73   [('Will', 'MD'), ('definitely', 'RB'), ('come', 'VB'), ('back', 'RB'), ('for', 'IN'), ('more', 'JJR'), ('and', 'CC'), ('recommend', 'VB'), ('your', 'PRP$'), ('shop', 'NN'), ('to', 'TO'), ('my', 'PRP$'), ('friends', 'NNS'), ('.', '.'), ("''", "''")]
# 74   [('Just', 'RB'), ('received', 'VBN'), ('both', 'PDT'), ('the', 'DT'), ('rompers', 'NNS'), ('today', 'NN'), ('!', '.'), ('!', '.')]
# 75   [('Its', 'PRP$'), ('soooo', 'NN'), ('pretty', 'NN'), ('!', '.'), ('!', '.')]
# 76   [('Thank', 'NNP'), ('you', 'PRP'), ('so', 'RB'), ('much', 'RB'), ('for', 'IN'), ('the', 'DT'), ('lovely', 'JJ'), ('packaging', 'NN'), ('as', 'RB'), ('well', 'RB'), ('!', '.'), ('!', '.')]
# 77   [('I', 'PRP'), ('highly', 'RB'), ('recommend', 'VB'), ('your', 'PRP$'), ('shop', 'NN'), ('to', 'TO'), ('everyone', 'NN'), ('!', '.'), ('!', '.')]
# 78   [('Prompt', 'JJ'), ('replies', 'NNS'), ('and', 'CC'), ('excellent', 'JJ'), ('customer', 'NN'), ('service', 'NN'), ('!', '.'), ('!', '.')]
# 79   [('Thanks', 'NNS'), ('once', 'RB'), ('again', 'RB'), ('!', '.'), ('!', '.')]
# 80   [('My', 'PRP$'), ('daughter', 'NN'), ('fit', 'NN'), ('with', 'IN'), ('it', 'PRP'), ('My', 'NNP'), ('toddler', 'NN'), ('and', 'CC'), ('I', 'PRP'), ('love', 'VBP'), ('the', 'DT'), ('kimono', 'NN'), ('as', 'IN'), ('its', 'PRP$'), ('too', 'RB'), ('comfortable', 'JJ'), ('and', 'CC'), ('easy', 'JJ'), ('to', 'TO'), ('wear', 'VB'), ('.', '.')]
# 81   [('Cool', 'NN'), ('!', '.')]
# 82   [('Good', 'JJ'), ('design', 'NN'), ('and', 'CC'), ('Good', 'JJ'), ('material', 'NN'), ('Bought', 'VBD'), ('a', 'DT'), ('``', '``'), ('Mon', 'NNP'), ("''", "''"), ('romper', 'NN'), ('for', 'IN'), ('my', 'PRP$'), ('son', 'NN'), (',', ','), ('definitely', 'RB'), ('a', 'DT'), ('cute', 'JJ'), ('piece', 'NN'), ('!', '.')]
# 83   [('The', 'DT'), ('fabric', 'NN'), ('is', 'VBZ'), ('soft', 'JJ'), ('and', 'CC'), ('very', 'RB'), ('good', 'JJ'), ('quality', 'NN'), ('.', '.')]
# 84   [('Nicely', 'RB'), ('wrapped', 'VBN'), ('and', 'CC'), ('I', 'PRP'), ('thought', 'VBD'), ('I', 'PRP'), ('got', 'VBD'), ('a', 'DT'), ('present', 'JJ'), ('haha', 'NN'), ('.', '.')]
# 85   [('Launch', 'NNP'), ('more', 'JJR'), ('bigger', 'JJR'), ('size', 'NN'), ('ok', 'NN'), ('?', '.')]
# 86   [('Will', 'MD'), ('surely', 'RB'), ('buy', 'VB'), ('again', 'RB'), ('!', '.')]
# 87   [('Thumbs', 'NNP'), ('up', 'RP'), ('for', 'IN'), ('the', 'DT'), ('nice', 'JJ'), ('service', 'NN'), (',', ','), ('good', 'JJ'), ('quality', 'NN'), ('and', 'CC'), ('the', 'DT'), ('beautiful', 'JJ'), ('packaging', 'NN'), ('!', '.')]
# 88   [('it', 'PRP'), ('so', 'RB'), ('much', 'JJ'), ('!', '.')]
# 89   [('My', 'PRP$'), ('2', 'CD'), ('months', 'NNS'), ('old', 'JJ'), ('boy', 'JJ'), ('fit', 'NN'), ('nicely', 'RB'), ('into', 'IN'), ('the', 'DT'), ('newborn', 'JJ'), ('sized', 'JJ'), ('rompers', 'NNS'), (',', ','), ('and', 'CC'), ('he', 'PRP'), ('looked', 'VBD'), ('really', 'RB'), ('good', 'JJ'), ('on', 'IN'), ('them', 'PRP'), ('.', '.')]
# 90   [('Thank', 'NNP'), ('you', 'PRP'), ('Hahanoyume', 'VBP'), ('for', 'IN'), ('these', 'DT'), ('wonderful', 'JJ'), ('looking', 'VBG'), ('outfits', 'NNS'), ('for', 'IN'), ('our', 'PRP$'), ('little', 'JJ'), ('boy', 'NN'), ('.', '.')]
# 91   [('A', 'DT'), ('must', 'MD'), ('have', 'VB'), ('for', 'IN'), ('your', 'PRP$'), ('babies', 'NNS'), ('and', 'CC'), ('definitely', 'RB'), ('a', 'DT'), ('perfect', 'JJ'), ('gift', 'NN'), ('for', 'IN'), ('your', 'PRP$'), ('friend', 'NN'), ("'s", 'POS'), ('babies', 'NNS'), ('.', '.')]
# 92   [('Keep', 'VB'), ('up', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('work', 'NN'), ('and', 'CC'), ('I', 'PRP'), ('look', 'VBP'), ('forward', 'RB'), ('to', 'TO'), ('more', 'RBR'), ('wonderful', 'JJ'), ('products', 'NNS'), ('for', 'IN'), ('my', 'PRP$'), ('boy', 'NN'), ('from', 'IN'), ('you', 'PRP'), ('guys', 'VBP'), ('in', 'IN'), ('the', 'DT'), ('near', 'JJ'), ('future', 'NN'), ('It', 'PRP'), ('is', 'VBZ'), ('very', 'RB'), ('special', 'JJ'), ('n', 'NN'), ('unique', 'JJ'), ('romper', 'NN'), ('for', 'IN'), ('my', 'PRP$'), ('baby', 'NN'), ('.', '.')]
# 93   [('Very', 'RB'), ('soft', 'JJ'), ('piece', 'NN'), ('and', 'CC'), ('do', 'VBP'), ('not', 'RB'), ('feel', 'VB'), ('hot', 'JJ'), ('for', 'IN'), ('him', 'PRP'), ('.', '.')]
# 94   [('My', 'PRP$'), ('baby', 'NN'), ('Tze', 'NNP'), ('love', 'VBD'), ('it', 'PRP'), ('so', 'RB'), ('much…', 'JJ')]
#
# OPINIONS OF USERS
# Do you want to print the result on output window? (Y/N) :y
# [('SO', 16), ('VERY', 14), ('GOOD', 12), ('NICE', 6), ('DEFINITELY', 6), ('MUCH', 6), ('GREAT', 5), ('BEAUTIFUL', 4), ('LOVELY', 4), ('REALLY', 4), ('WELL', 4), ('COMFORTABLE', 3), ('CUTE', 3), ('EXCELLENT', 3), ('MORE', 3), ('SOFT', 3), ('SUPER', 2), ('EXCITED', 2), ('HANDWRITTEN', 2), ('RESPONSIVE', 2), ('TOO', 2), ('NICELY', 2), ('FAST', 2), ('LITTLE', 2), ('GORGEOUS', 2), ('JUST', 2), ('BACK', 2), ('PROMPT', 2), ('HIGHLY', 2), ('AGAIN', 2), ('WONDERFUL', 2)]
